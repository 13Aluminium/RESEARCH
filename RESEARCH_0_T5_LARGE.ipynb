# %% [markdown]
# <a href="https://colab.research.google.com/github/13Aluminium/RESEARCH/blob/main/RESEARCH_0_T5_LARGE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/google-research-datasets/Hinglish-TOP-Dataset
# Out:
# Cloning into 'Hinglish-TOP-Dataset'...
# remote: Enumerating objects: 31, done.
# remote: Counting objects: 100% (31/31), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 31 (delta 11), reused 10 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (31/31), 10.02 MiB | 8.46 MiB/s, done.
# Resolving deltas: 100% (11/11), done.

# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-3.4.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.12.0,>=2023.1.0 (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.14)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.29.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.2.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading datasets-3.4.1-py3-none-any.whl (487 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 487.4/487.4 kB 17.6 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 7.2 MB/s eta 0:00:00
# Downloading fsspec-2024.12.0-py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 17.1 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 3.6 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 4.6 MB/s eta 0:00:00
# Installing collected packages: xxhash, fsspec, dill, multiprocess, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.0
#     Uninstalling fsspec-2025.3.0:
#       Successfully uninstalled fsspec-2025.3.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.6.0+cu124 requires nvidia-cublas-cu12==12.4.5.8; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cublas-cu12 12.5.3.2 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-cupti-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-cupti-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-nvrtc-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-nvrtc-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-runtime-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-runtime-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cudnn-cu12==9.1.0.70; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cudnn-cu12 9.3.0.75 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cufft-cu12==11.2.1.3; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cufft-cu12 11.2.3.61 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-curand-cu12==10.3.5.147; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-curand-cu12 10.3.6.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusolver-cu12==11.6.1.9; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusolver-cu12 11.6.3.83 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusparse-cu12==12.3.1.170; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusparse-cu12 12.5.1.3 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-nvjitlink-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-nvjitlink-cu12 12.5.82 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2024.12.0 which is incompatible.
# Successfully installed datasets-3.4.1 dill-0.3.8 fsspec-2024.12.0 multiprocess-0.70.16 xxhash-3.5.0

# %%
import pandas as pd
import torch
from datasets import Dataset, DatasetDict
from transformers import (
    T5Tokenizer,
    T5ForConditionalGeneration,
    DataCollatorForSeq2Seq,
    Trainer,
    TrainingArguments
)

# Load datasets
train_df = pd.read_csv('/content/Hinglish-TOP-Dataset/Dataset/Human Annotated Data/train.tsv', sep='\t')
valid_df = pd.read_csv('/content/Hinglish-TOP-Dataset/Dataset/Human Annotated Data/validation.tsv', sep='\t')
test_df = pd.read_csv('/content/Hinglish-TOP-Dataset/Dataset/Human Annotated Data/test.tsv', sep='\t')

# Convert pandas DataFrame to Hugging Face Dataset
data = DatasetDict({
    'train': Dataset.from_pandas(train_df),
    'validation': Dataset.from_pandas(valid_df),
    'test': Dataset.from_pandas(test_df)
})

# Load T5 tokenizer and model
model_name = "t5-large"
tokenizer = T5Tokenizer.from_pretrained(model_name)
model = T5ForConditionalGeneration.from_pretrained(model_name)

# Enable gradient checkpointing for memory optimization
model.gradient_checkpointing_enable()

# Define preprocessing function
def preprocess_function(examples):
    inputs = ["translate English to Hinglish: " + ex for ex in examples["en_query"]]
    model_inputs = tokenizer(inputs, max_length=64, truncation=True)  # Reduced max_length

    # Tokenize targets
    with tokenizer.as_target_tokenizer():
        labels = tokenizer(examples["cs_query"], max_length=64, truncation=True)
    model_inputs["labels"] = labels["input_ids"]

    return model_inputs

# Tokenize dataset
tokenized_data = data.map(preprocess_function, batched=True)

# Training arguments (GPU training)
training_args = TrainingArguments(
    output_dir="./results",
    eval_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=8,   # Lower batch size to avoid OOM
    per_device_eval_batch_size=8,    # Lower batch size
    gradient_accumulation_steps=2,   # Accumulate gradients for effective batch size of 16
    weight_decay=0.01,
    save_total_limit=3,
    num_train_epochs=15,
    logging_dir='./logs',
    logging_steps=50,
    report_to=[]
)

# Data collator for dynamic padding
data_collator = DataCollatorForSeq2Seq(tokenizer, model=model)

# Initialize Trainer (GPU training)
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_data["train"],
    eval_dataset=tokenized_data["validation"],
    tokenizer=tokenizer,
    data_collator=data_collator,
)

# Training on GPU
trainer.train()

# Save the trained model
trainer.save_model("./final_model")

# Clear CUDA Cache
torch.cuda.empty_cache()

# Print completion message
print("Model training and saving completed successfully.")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# model.safetensors:   0%|          | 0.00/2.95G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# Map:   0%|          | 0/2993 [00:00<?, ? examples/s]
# /usr/local/lib/python3.11/dist-packages/transformers/tokenization_utils_base.py:3980: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   warnings.warn(
# Map:   0%|          | 0/1390 [00:00<?, ? examples/s]
# Map:   0%|          | 0/6513 [00:00<?, ? examples/s]
# <ipython-input-3-3a74e8890ea9>:67: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# `use_cache=True` is incompatible with gradient checkpointing. Setting `use_cache=False`...
#     <div>
#
#       <progress value='2805' max='2805' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2805/2805 1:19:24, Epoch 14/15]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.998600</td>
#       <td>1.619507</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.580500</td>
#       <td>1.331256</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.389700</td>
#       <td>1.195374</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.242900</td>
#       <td>1.095705</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.169000</td>
#       <td>1.031489</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.077700</td>
#       <td>0.992077</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.970100</td>
#       <td>0.966935</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.943900</td>
#       <td>0.942918</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.914900</td>
#       <td>0.917708</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.894800</td>
#       <td>0.913071</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.830100</td>
#       <td>0.905118</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.837800</td>
#       <td>0.897494</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.805000</td>
#       <td>0.892284</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.823100</td>
#       <td>0.889529</td>
#     </tr>
#   </tbody>
# </table><p>
# Passing a tuple of `past_key_values` is deprecated and will be removed in Transformers v4.48.0. You should pass an instance of `EncoderDecoderCache` instead, e.g. `past_key_values=EncoderDecoderCache.from_legacy_cache(past_key_values)`.
# Model training and saving completed successfully.

# %%
import torch
import pandas as pd
import sys
import traceback
from transformers import T5Tokenizer, T5ForConditionalGeneration

def minimal_debug_inference(model_path, test_file_path):
    print("Starting minimal debug inference...")

    try:
        # Print Python and library versions
        print(f"Python Version: {sys.version}")
        print(f"PyTorch Version: {torch.__version__}")
        print(f"Transformers Version: {torch.__version__}")

        # Load test data with verbose error handling
        print("Attempting to load test dataset...")
        try:
            test_df = pd.read_csv(test_file_path, sep='\t')
            print(f"Loaded dataset: {len(test_df)} samples")
            print(f"Columns: {list(test_df.columns)}")
        except Exception as data_error:
            print(f"❌ DATA LOADING ERROR: {data_error}")
            print(traceback.format_exc())
            return

        # Validate required columns
        if 'en_query' not in test_df.columns:
            print("❌ ERROR: 'en_query' column not found in dataset!")
            print("Available columns:", list(test_df.columns))
            return

        # Load tokenizer with verbose error handling
        print("Attempting to load tokenizer...")
        try:
            tokenizer = T5Tokenizer.from_pretrained("t5-large")
        except Exception as tokenizer_error:
            print(f"❌ TOKENIZER LOADING ERROR: {tokenizer_error}")
            print(traceback.format_exc())
            return

        # Load model with verbose error handling
        print("Attempting to load model...")
        try:
            model = T5ForConditionalGeneration.from_pretrained(model_path)
        except Exception as model_error:
            print(f"❌ MODEL LOADING ERROR: {model_error}")
            print(traceback.format_exc())

            # Check model directory contents
            import os
            print("\nChecking model directory contents:")
            try:
                print(os.listdir(model_path))
            except Exception as dir_error:
                print(f"Could not list directory: {dir_error}")
            return

        # Prepare device
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        print(f"Running on device: {device}")
        model.to(device)
        model.eval()

        # Prepare inputs
        print("Preparing model inputs...")
        inputs = ["translate English to Hinglish: " + str(ex) for ex in test_df["en_query"][:5]]

        # Tokenize
        print("Tokenizing inputs...")
        encodings = tokenizer(
            inputs,
            max_length=64,
            truncation=True,
            padding=True,
            return_tensors="pt"
        )

        # Inference
        print("Starting inference...")
        with torch.no_grad():
            outputs = model.generate(
                input_ids=encodings['input_ids'].to(device),
                max_length=64,
                num_beams=4,
                early_stopping=True
            )

        # Decode predictions
        predictions = tokenizer.batch_decode(outputs, skip_special_tokens=True)

        # Print results
        print("\n=== SAMPLE PREDICTIONS ===")
        for orig, trans in zip(inputs, predictions):
            print(f"Original: {orig}")
            print(f"Translation: {trans}")
            print("---")

        print("Inference completed successfully!")

    except Exception as e:
        print(f"❌ UNEXPECTED ERROR: {e}")
        print(traceback.format_exc())

# Main execution
if __name__ == "__main__":
    minimal_debug_inference(
        model_path="/content/final_model",
        test_file_path='/content/Hinglish-TOP-Dataset/Dataset/Human Annotated Data/test.tsv'
    )
# Out:
# Starting minimal debug inference...
# Python Version: 3.11.11 (main, Dec  4 2024, 08:55:07) [GCC 11.4.0]
# PyTorch Version: 2.6.0+cu124
# Transformers Version: 2.6.0+cu124
# Attempting to load test dataset...
# Loaded dataset: 6513 samples
# Columns: ['en_query', 'cs_query', 'en_parse', 'cs_parse', 'domain']
# Attempting to load tokenizer...
# Attempting to load model...
# Running on device: cuda
# Preparing model inputs...
# Tokenizing inputs...
# Starting inference...
#
# === SAMPLE PREDICTIONS ===
# Original: translate English to Hinglish: Pause my timer .
# Translation: mere timer ko pause kare
# ---
# Original: translate English to Hinglish: Is it raining in Hawaii ?
# Translation: kya Hawaii me baarish hogi ?
# ---
# Original: translate English to Hinglish: Set a reminder for me to wake up at 630 am tomorrow .
# Translation: mujhe kal 630 am ke liye ek reminder set kare
# ---
# Original: translate English to Hinglish: Please pause timer
# Translation: Please timer ko pause kare
# ---
# Original: translate English to Hinglish: play the first album for killswitch engaged
# Translation: killswitch engaged ke liye first album bajao
# ---
# Inference completed successfully!

# %%
# !pip install sacrebleu
# Out:
# Collecting sacrebleu
#   Downloading sacrebleu-2.5.1-py3-none-any.whl.metadata (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 3.1 MB/s eta 0:00:00
# Collecting portalocker (from sacrebleu)
#   Downloading portalocker-3.1.1-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (from sacrebleu) (2024.11.6)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.11/dist-packages (from sacrebleu) (0.9.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from sacrebleu) (2.0.2)
# Collecting colorama (from sacrebleu)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/dist-packages (from sacrebleu) (5.3.1)
# Downloading sacrebleu-2.5.1-py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.1/104.1 kB 9.9 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading portalocker-3.1.1-py3-none-any.whl (19 kB)
# Installing collected packages: portalocker, colorama, sacrebleu
# Successfully installed colorama-0.4.6 portalocker-3.1.1 sacrebleu-2.5.1

# %%
import torch
import pandas as pd
import sacrebleu

from transformers import T5Tokenizer, T5ForConditionalGeneration

def compute_bleu_metric(predictions, references):
    """
    Compute BLEU score using sacreBLEU.

    Args:
        predictions (list of str): Model-generated translations
        references (list of str): Ground-truth translations

    Returns:
        float: BLEU score
    """
    # sacreBLEU expects references in a list of lists
    bleu_score = sacrebleu.corpus_bleu(predictions, [references]).score
    return bleu_score

def evaluate_model(
    model_path,
    data_file,
    row_limit=500,
    max_length=64,
    num_beams=4
):
    """
    Load the model and dataset, generate translations, and compute BLEU metric.

    Args:
        model_path (str): Path to the saved T5 model directory
        data_file (str): Path to the TSV file with columns [en_query, cs_query, ...]
        row_limit (int): Maximum number of rows to use from the dataset
        max_length (int): Max length for generated translations
        num_beams (int): Number of beams for beam search
    """
    print("Loading dataset for evaluation...")
    df = pd.read_csv(data_file, sep='\t')

    # We need 'en_query' as input and 'cs_query' as reference
    if 'en_query' not in df.columns or 'cs_query' not in df.columns:
        raise ValueError("Data file must contain 'en_query' and 'cs_query' columns!")

    # Limit rows for faster evaluation
    df = df.head(row_limit)

    # Prepare model & tokenizer
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    tokenizer = T5Tokenizer.from_pretrained("t5-large")
    model = T5ForConditionalGeneration.from_pretrained(model_path)
    model.to(device)
    model.eval()

    # Generate predictions
    predictions = []
    references = []

    print(f"Generating translations for up to {len(df)} rows...")

    for _, row in df.iterrows():
        # Prepare input text
        input_text = "translate English to Hinglish: " + str(row['en_query'])

        # Tokenize
        encodings = tokenizer(
            input_text,
            max_length=max_length,
            truncation=True,
            return_tensors="pt"
        ).to(device)

        # Generate
        with torch.no_grad():
            outputs = model.generate(
                input_ids=encodings['input_ids'],
                attention_mask=encodings['attention_mask'],
                max_length=max_length,
                num_beams=num_beams,
                early_stopping=True
            )

        # Decode prediction
        pred_text = tokenizer.decode(outputs[0], skip_special_tokens=True)

        # Append prediction and reference
        predictions.append(pred_text)
        references.append(str(row['cs_query']))

    print("Done generating translations. Now computing BLEU metric...")

    # Compute BLEU metric
    bleu_score = compute_bleu_metric(predictions, references)

    # Print metric
    print("\n=== Evaluation Metric ===")
    print(f"BLEU Score: {bleu_score:.4f}")

    return bleu_score

def main():
    # Example usage
    model_path = "/content/final_model"  # Adjust if needed
    data_file = "/content/Hinglish-TOP-Dataset/Dataset/Synthetically Generated Data/train.tsv"  # Adjust path if needed

    # Evaluate on up to 500 rows from the train file
    evaluate_model(
        model_path=model_path,
        data_file=data_file,
        row_limit=500,       # Adjust as needed (200, 500, 1000, etc.)
        max_length=64,
        num_beams=4
    )

if __name__ == "__main__":
    main()
# Out:
# Loading dataset for evaluation...
# Generating translations for up to 500 rows...
# Done generating translations. Now computing BLEU metric...
#
# === Evaluation Metric ===
# BLEU Score: 38.7641

# %%
import torch
import pandas as pd
import numpy as np
import sacrebleu
from transformers import T5Tokenizer, T5ForConditionalGeneration, AutoModel, AutoTokenizer

def levenshtein_distance(s1, s2):
    """
    Compute Levenshtein distance between two strings
    Supports both word and character-level distance
    """
    # If input is string, convert to list of characters/words
    if isinstance(s1, str):
        s1 = list(s1)
    if isinstance(s2, str):
        s2 = list(s2)

    # Create distance matrix
    rows, cols = len(s1) + 1, len(s2) + 1
    dist = [[0 for x in range(cols)] for x in range(rows)]

    # Initialize first row and column
    for i in range(1, rows):
        dist[i][0] = i
    for j in range(1, cols):
        dist[0][j] = j

    # Compute Levenshtein distance
    for col in range(1, cols):
        for row in range(1, rows):
            if s1[row-1] == s2[col-1]:
                cost = 0
            else:
                cost = 1
            dist[row][col] = min(
                dist[row-1][col] + 1,      # deletion
                dist[row][col-1] + 1,      # insertion
                dist[row-1][col-1] + cost  # substitution
            )

    return dist[rows-1][cols-1]

def word_error_rate(reference, hypothesis):
    """
    Compute Word Error Rate (WER)
    Lower is better (0 is perfect match)
    """
    # Split into words
    r = reference.split()
    h = hypothesis.split()

    # Compute Levenshtein distance
    return levenshtein_distance(r, h) / len(r)

def character_error_rate(reference, hypothesis):
    """
    Compute Character Error Rate (CER)
    Lower is better (0 is perfect match)
    """
    return levenshtein_distance(reference, hypothesis) / len(reference)

def compute_embedding_similarity(reference, hypothesis, model_name='distilbert-base-uncased'):
    """
    Compute cosine similarity between sentence embeddings
    Higher is better (1 is perfect similarity)
    """
    try:
        # Load pre-trained model and tokenizer
        tokenizer = AutoTokenizer.from_pretrained(model_name)
        model = AutoModel.from_pretrained(model_name)

        # Tokenize and get embeddings
        inputs_ref = tokenizer(reference, return_tensors='pt', truncation=True, max_length=512)
        inputs_hyp = tokenizer(hypothesis, return_tensors='pt', truncation=True, max_length=512)

        # Generate embeddings
        with torch.no_grad():
            outputs_ref = model(**inputs_ref)
            outputs_hyp = model(**inputs_hyp)

        # Mean pooling
        ref_embedding = outputs_ref.last_hidden_state.mean(dim=1)
        hyp_embedding = outputs_hyp.last_hidden_state.mean(dim=1)

        # Compute cosine similarity
        return 1 - torch.nn.functional.cosine_similarity(ref_embedding, hyp_embedding).item()
    except Exception as e:
        print(f"Error in embedding similarity: {e}")
        return None

def evaluate_model_metrics(
    model_path,
    data_file,
    row_limit=500,
    max_length=64,
    num_beams=4
):
    """
    Comprehensive model evaluation with multiple metrics
    """
    print("Loading dataset for evaluation...")
    df = pd.read_csv(data_file, sep='\t')

    # Validate columns
    if 'en_query' not in df.columns or 'cs_query' not in df.columns:
        raise ValueError("Data file must contain 'en_query' and 'cs_query' columns!")

    # Limit rows
    df = df.head(row_limit)

    # Prepare model & tokenizer
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    tokenizer = T5Tokenizer.from_pretrained("t5-small")
    model = T5ForConditionalGeneration.from_pretrained(model_path)
    model.to(device)
    model.eval()

    # Metrics storage
    metrics = {
        'bleu_scores': [],
        'wer_scores': [],
        'cer_scores': [],
        'embedding_similarities': []
    }

    print(f"Generating translations for up to {len(df)} rows...")

    for _, row in df.iterrows():
        # Prepare input text
        input_text = "translate English to Hinglish: " + str(row['en_query'])
        reference = str(row['cs_query'])

        # Tokenize
        encodings = tokenizer(
            input_text,
            max_length=max_length,
            truncation=True,
            return_tensors="pt"
        ).to(device)

        # Generate
        with torch.no_grad():
            outputs = model.generate(
                input_ids=encodings['input_ids'],
                attention_mask=encodings['attention_mask'],
                max_length=max_length,
                num_beams=num_beams,
                early_stopping=True
            )

        # Decode prediction
        hypothesis = tokenizer.decode(outputs[0], skip_special_tokens=True)

        # Compute metrics
        # BLEU
        bleu_score = sacrebleu.sentence_bleu(hypothesis, [reference]).score
        metrics['bleu_scores'].append(bleu_score)

        # Word Error Rate
        wer = word_error_rate(reference, hypothesis)
        metrics['wer_scores'].append(wer)

        # Character Error Rate
        cer = character_error_rate(reference, hypothesis)
        metrics['cer_scores'].append(cer)

        # Embedding Similarity
        emb_sim = compute_embedding_similarity(reference, hypothesis)
        if emb_sim is not None:
            metrics['embedding_similarities'].append(emb_sim)

        # Optional: print individual sample results
        print(f"\nReference: {reference}")
        print(f"Hypothesis: {hypothesis}")
        print(f"BLEU: {bleu_score:.4f}, WER: {wer:.4f}, CER: {cer:.4f}")

    # Compute average metrics
    print("\n=== Evaluation Metrics ===")
    print(f"Average BLEU Score: {np.mean(metrics['bleu_scores']):.4f}")
    print(f"Average Word Error Rate: {np.mean(metrics['wer_scores']):.4f}")
    print(f"Average Character Error Rate: {np.mean(metrics['cer_scores']):.4f}")
    if metrics['embedding_similarities']:
        print(f"Average Embedding Similarity: {np.mean(metrics['embedding_similarities']):.4f}")

    return metrics

def main():
    # Example usage
    model_path = "/content/final_model"  # Adjust if needed
    data_file = "/content/Hinglish-TOP-Dataset/Dataset/Synthetically Generated Data/train.tsv"  # Adjust path if needed

    # Evaluate on up to 500 rows from the train file
    evaluate_model_metrics(
        model_path=model_path,
        data_file=data_file,
        row_limit=500,
        max_length=64,
        num_beams=4
    )

if __name__ == "__main__":
    main()
# Out:
# Loading dataset for evaluation...
# tokenizer_config.json:   0%|          | 0.00/2.32k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# Generating translations for up to 500 rows...
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Reference: Is Saturday night The Grand Ole Opry me featured performer kya hai
# Hypothesis: Is Saturday raat The Grand Ole Opry mei featured performer kya hai
# BLEU: 46.5954, WER: 0.1667, CER: 0.0758
#
# Reference: mujhe 12 am ko meri meeting ke baare me yaad dilaayen
# Hypothesis: mujhe 12 am ko mere meeting ke liye yaad dilaye
# BLEU: 29.3772, WER: 0.3636, CER: 0.1887
#
# Reference: subha 5 baje ke liye ek alarm set karen
# Hypothesis: 5 am ke liye alarm set kare
# BLEU: 14.7596, WER: 0.4444, CER: 0.3333
#
# Reference: dopaher 2 baje Sydney me mausam kaisa hoga
# Hypothesis: Sydney me 2 pm ko mausam kaisa hai
# BLEU: 16.5158, WER: 0.7500, CER: 0.5238
#
# Reference: Canada me mausam kaisa hai ?
# Hypothesis: Canada me mausam kaisa hai
# BLEU: 81.8731, WER: 0.1667, CER: 0.0714
#
# Reference: weekend alarm ko delete karo
# Hypothesis: weekend alarm ko delete kare
# BLEU: 66.8740, WER: 0.2000, CER: 0.0357
#
# Reference: abhi ka temperature kya hai
# Hypothesis: abhi temperature kya hai
# BLEU: 49.7609, WER: 0.2000, CER: 0.1111
#
# Reference: Interstate 90 ke zariye yaha se Cades Cove TN tak drive karke jaane me kitna samay lagega ?
# Hypothesis: mujhe Interstate 90 se Cades Cove TN tak drive karne me kitna time lagega?
# BLEU: 35.4542, WER: 0.5000, CER: 0.3516
#
# Reference: 30 may ke midnight ke liye alarm set kare
# Hypothesis: 30th may ke midnight ke liye alarm set kare
# BLEU: 86.3340, WER: 0.1111, CER: 0.0488
#
# Reference: please wo song ko phir se bajao
# Hypothesis: please that song ko replay kare
# BLEU: 15.2072, WER: 0.5714, CER: 0.4839
#
# Reference: Please aaj raat ke liye wo alarm cancel kare
# Hypothesis: please aj raat ke alarm ko cancel kare
# BLEU: 14.5752, WER: 0.5556, CER: 0.2955
#
# Reference: channel ko Spotify me badal do
# Hypothesis: channel ko Spotify par change kare
# BLEU: 30.2138, WER: 0.5000, CER: 0.4000
#
# Reference: kal 5 pm ko mujhe Perth ke liye weather update de ?
# Hypothesis: Muje kal 5 pm ko Perth ke liye weather update dikhayen?
# BLEU: 54.5247, WER: 0.3333, CER: 0.3333
#
# Reference: mere weather app ke liye Tokyo ko delete kardo
# Hypothesis: mere weather app par Tokyo ko delete kare
# BLEU: 30.5098, WER: 0.3333, CER: 0.1957
#
# Reference: agle Monday 9 : 15 AM ke liye ek alert time set karen .
# Hypothesis: agle Monday 9 : 15 AM ke liye alert time set kare
# BLEU: 62.2070, WER: 0.2143, CER: 0.1091
#
# Reference: snooze alarm band kare
# Hypothesis: snooze alarm band kare
# BLEU: 100.0000, WER: 0.0000, CER: 0.0000
#
# Reference: kal subha kuch bacchon ke liye events kya hai
# Hypothesis: kal subah morning ke liye kya koi kid friendly events hai
# BLEU: 9.8647, WER: 0.8889, CER: 0.7556
#
# Reference: aaj kitni damn garmi honi chahiye ?
# Hypothesis: aj kitni garmi hone wali hai?
# BLEU: 8.6430, WER: 0.7143, CER: 0.4000
#
# Reference: Mujhe har dusre Tuesday ko recycling ko curb me le jane ke liye yaad dilaayen .
# Hypothesis: Muje remind karaye to take the recycling to the curb every other Tuesday.
# BLEU: 3.4815, WER: 1.0000, CER: 0.6582
#
# Reference: is mahine steak dinner ke sabhi reminders me Brian aur Matt ko add karen .
# Hypothesis: Brian aur Matt ko saarey reminders steak dinner ke liye yaad dilaye
# BLEU: 24.6898, WER: 0.9333, CER: 0.6622
#
# Reference: mujhe I 95 par Houston pahuchne mei kitni der lagegi .
# Hypothesis: I 95 par mujhe Houston tak pahuchne mei yaad dilaye
# BLEU: 19.3313, WER: 0.6364, CER: 0.5370
#
# Reference: Aaj ke liye highest expected temperature kya hai ?
# Hypothesis: aj ke liye expected temperature kya hai?
# BLEU: 52.4736, WER: 0.4444, CER: 0.2000
#
# Reference: mere jog ke liye 20 - minute timer set kare
# Hypothesis: mere jog ke liye 20 minute timer set kare
# BLEU: 66.9048, WER: 0.1000, CER: 0.0465
#
# Reference: Kya aaj mujhe raincoat pehenna chahiye ?
# Hypothesis: Kya mujhe aaj raincoat pehenna chahiye?
# BLEU: 47.2871, WER: 0.5714, CER: 0.2250
#
# Reference: please mujhe Friday 1 : 00 pm se pehle mera job application mail karne ke liye yaad dilayen
# Hypothesis: Please mujhe Friday ko 1 : 00 pm ke liye mere job application mail karne ke liye yaad dilaye
# BLEU: 47.0277, WER: 0.3333, CER: 0.1209
#
# Reference: friday ke liye humidity kya hai
# Hypothesis: friday ke liye humidity kya hai
# BLEU: 100.0000, WER: 0.0000, CER: 0.0000
#
# Reference: mere alarms kya time ke liye set kare gaye hai
# Hypothesis: mere alarm kya time bacha hai?
# BLEU: 10.1753, WER: 0.7000, CER: 0.4565
#
# Reference: is season ke liye average climatic condition
# Hypothesis: is season ke liye climatic condition
# BLEU: 51.1508, WER: 0.1429, CER: 0.1818
#
# Reference: kya aj raat koi shooting stars hone wale hai
# Hypothesis: Kya aaj raat koi shooting stars hai
# BLEU: 32.6683, WER: 0.4444, CER: 0.2727
#
# Reference: saturday dopahar ko Samantha ke liye cake pick up karne ke liye reminder set kare
# Hypothesis: Samantha ko saturday noon ko cake pick up karne ke liye reminder set kare
# BLEU: 59.5933, WER: 0.3333, CER: 0.3210
#
# Reference: mujhe Skype par unread chats dikhao
# Hypothesis: mujhe Skype par unread chats dikhao
# BLEU: 100.0000, WER: 0.0000, CER: 0.0000
#
# Reference: kya aap iheartradio par 107 . 9 bajaa sakte hai
# Hypothesis: kya aap iheartradio par 107. 9 bajao
# BLEU: 65.4891, WER: 0.5000, CER: 0.2553
#
# Reference: kya bahar sweater weather hai ?
# Hypothesis: kya bahar sweater weather hai?
# BLEU: 100.0000, WER: 0.3333, CER: 0.0323
#
# Reference: kaam ku jaane ke raaste me wrecks
# Hypothesis: work ke liye wrecks hai
# BLEU: 8.5153, WER: 0.8571, CER: 0.7273
#
# Reference: mujhe new york city mein kal ka forecast bataiye
# Hypothesis: mujhe new york city me kal ke forecast bataye
# BLEU: 33.0316, WER: 0.3333, CER: 0.0833
#
# Reference: Pam ka Thumbs up message
# Hypothesis: Pam ka Thumbs up message
# BLEU: 100.0000, WER: 0.0000, CER: 0.0000
#
# Reference: mere subah 7 bajhe ke alarm ko cancel kare
# Hypothesis: mere 7 am ke alarm ko cancel kare
# BLEU: 49.6264, WER: 0.2222, CER: 0.2381
#
# Reference: Monday through Friday ka subah 5 baje ke liye alarm set kare
# Hypothesis: Monday to Friday subah 5 baje ke liye alarm set kare
# BLEU: 65.5228, WER: 0.1667, CER: 0.1333
#
# Reference: meri wedding ka theme kya hona chahiye
# Hypothesis: aaj wedding ke liye theme kya hai
# BLEU: 14.5358, WER: 0.7143, CER: 0.5000
#
# Reference: agar mai ek ghante me nikal jaoon to mujhe sams ghar pahunchne me kitna samay lagega ?
# Hypothesis: agar mai ek ghante se nikalta hoon toh mujhe sams house pahuchne mei kitni der lagegi?
# BLEU: 17.6950, WER: 0.6471, CER: 0.2442
#
# Reference: kya palo alto me 28 degree fahrenheit se upar hai
# Hypothesis: kya palo alto me 28 degree fahrenheit ke liye hai
# BLEU: 66.0633, WER: 0.2000, CER: 0.1020
#
# Reference: is weekend Santa Claus locations
# Hypothesis: Is weekend Santa Claus locations
# BLEU: 66.8740, WER: 0.2000, CER: 0.0312
#
# Reference: maine alarm kis liye set kiya tha
# Hypothesis: mujhe alarm set karne ki zarurat hai
# BLEU: 7.8098, WER: 0.8571, CER: 0.6364
#
# Reference: Mere timer par kitna time bacha he ?
# Hypothesis: mere timer par kitna time bacha hai?
# BLEU: 54.1082, WER: 0.3750, CER: 0.0833
#
# Reference: marketing team ko kal subah 9 bajhe conference room me milne ke liye yaad dilaye
# Hypothesis: marketing team ko kal subha 9 baje conference room me meet karne ke liye yaad dilaye
# BLEU: 38.5032, WER: 0.2667, CER: 0.1250
#
# Reference: Currently windham me traffic kaisa hai
# Hypothesis: windham me current traffic kya hai
# BLEU: 19.3049, WER: 0.5000, CER: 0.5526
#
# Reference: mujhe Highway 84 par Flowers Hospital se Wiregrass Commons Mall tak ke liye Directions de .
# Hypothesis: mujhe Flowers Hospital se Highway 84 par Wiregrass Commons Mall ke Directions batao
# BLEU: 22.3617, WER: 0.6250, CER: 0.4835
#
# Reference: Aaj raat mujhe kaam ke baad milk pick karne ke liye yaad dilaayen
# Hypothesis: Aaj raat mujhe work ke liye milk pick karne ke liye yaad dilaye
# BLEU: 49.7357, WER: 0.2308, CER: 0.1538
#
# Reference: Kya muje aaj raat coat pehen na padega .
# Hypothesis: Kya mujhe aaj raat coat pehenna chahiye
# BLEU: 19.7406, WER: 0.5556, CER: 0.2500
#
# Reference: mere roast timer ko 20 minutes tak kam karna chahiye
# Hypothesis: Mere roast timer ko 20 minutes ke liye decrease kare
# BLEU: 39.2815, WER: 0.5000, CER: 0.3654
#
# Reference: kya agle hafte bahar 72 Celsius se niche hai
# Hypothesis: kya agle hafte 72 Celsius tak subah hai
# BLEU: 23.8752, WER: 0.3333, CER: 0.3182
#
# Reference: mujhe kal subah 10 bajhe meri girlfriend ko jagaane ke liye uske appointment ke liye yaad dilaye
# Hypothesis: Muje remind karaye to wake up my girlfriend tomorrow at 10:00 am for her appointment
# BLEU: 3.0098, WER: 1.0000, CER: 0.6979
#
# Reference: timer par kitna time bacha hai ?
# Hypothesis: timer par kitna time bacha hai?
# BLEU: 100.0000, WER: 0.2857, CER: 0.0312
#
# Reference: mai yaha se car dealership par Commercial me kaise jaa sakta hoon ?
# Hypothesis: mujhe Commercial se car dealership tak pahuchne ke liye mujhe meri car kharidne ke liye kitna chahiye?
# BLEU: 9.0836, WER: 1.0769, CER: 0.9104
#
# Reference: aj ke liye mere sarey alarms cancel kare
# Hypothesis: aaj ke liye mere saarey alarms cancel kare
# BLEU: 34.5721, WER: 0.2500, CER: 0.0500
#
# Reference: har 10 minutes ke liye alarm set kare
# Hypothesis: har 10 minutes ke liye alarm set kare
# BLEU: 100.0000, WER: 0.0000, CER: 0.0000
#
# Reference: please kuch relaxation music play kare
# Hypothesis: please kuch relaxation music bajao
# BLEU: 54.7518, WER: 0.3333, CER: 0.1842
#
# Reference: mujhe Sunday 7 pm ko mere tutoring session ke baare me yaad dilaayen .
# Hypothesis: Muje remind karaye about my tutoring session on Sunday at 7 pm.
# BLEU: 8.9534, WER: 0.8571, CER: 0.6000
#
# Reference: kya aaj shaam traffic kharab hai
# Hypothesis: kya aj shaam traffic kaisa hai
# BLEU: 19.3049, WER: 0.3333, CER: 0.1562
#
# Reference: 7 am tak alarm par kitna time bakhi hai ?
# Hypothesis: 7 am ke alarm ke liye kitna time bacha hai?
# BLEU: 13.4928, WER: 0.6000, CER: 0.3171
#
# Reference: please mujhe Providence aur New York City ke beech ki doori batayen
# Hypothesis: please mujhe Providence aur New York City ke liye distance bataye
# BLEU: 61.9676, WER: 0.3333, CER: 0.1940
#
# Reference: aj dopaher ke liye alarm set kare
# Hypothesis: aj noon ke liye alarm set kare
# BLEU: 64.3459, WER: 0.1429, CER: 0.1818
#
# Reference: Aaj ki traffic report kya he
# Hypothesis: aj traffic report kya hai
# BLEU: 32.5556, WER: 0.5000, CER: 0.2143
#
# Reference: Atlantic City se Edison tak traffic driving kya hai
# Hypothesis: Atlantic City se Edison tak traffic driving kya hai
# BLEU: 100.0000, WER: 0.0000, CER: 0.0000
#
# Reference: agle mahine mere area mei Beyonce ke concerts hai
# Hypothesis: agley mahine Beyonce ke concerts in my area
# BLEU: 20.6124, WER: 0.7778, CER: 0.4898
#
# Reference: Jackie Chan dwara Beauty and the Beast bajaye
# Hypothesis: Jackie Chan ko Beauty and the Beast ko bajao
# BLEU: 35.4948, WER: 0.3750, CER: 0.2222
#
# Reference: kya aj yaha 79 degree f ke aas paas rahega
# Hypothesis: Kya aaj aaj 79 degree f ke liye yaad dilaye
# BLEU: 26.2691, WER: 0.6000, CER: 0.4048
#
# Reference: 11 am aur 4 pm ke liye alarm lagaye
# Hypothesis: 11 am aur 4 pm ke liye alarm set kare
# BLEU: 75.9836, WER: 0.2222, CER: 0.1714
#
# Reference: Kya kal cloudy hone wala he ?
# Hypothesis: Kya kal cloudy hone wali hai?
# BLEU: 43.4721, WER: 0.4286, CER: 0.1034
#
# Reference: track ko skip kare
# Hypothesis: track ko skip kare
# BLEU: 100.0000, WER: 0.0000, CER: 0.0000
#
# Reference: Farenheit me mausam kya hai
# Hypothesis: Farenheit me mausam kaisa hai
# BLEU: 42.7287, WER: 0.2000, CER: 0.1111
#
# Reference: Charlotte aur Tampa ke beech ka distance kitna hai
# Hypothesis: Charlotte aur Tampa ke liye distance kya hai
# BLEU: 33.7646, WER: 0.3333, CER: 0.2200
#
# Reference: Kya mere paas aaj ke liye work ke baare me koi reminders hai ?
# Hypothesis: Kya mere aaj ke liye work ke liye koi reminders hai?
# BLEU: 48.8716, WER: 0.3571, CER: 0.2097
#
# Reference: monday ke reminders ko hata den
# Hypothesis: monday ke reminders hata do
# BLEU: 34.9833, WER: 0.3333, CER: 0.1613
#
# Reference: kya is weekend koi concert hai
# Hypothesis: kya is weekend koi concert hai
# BLEU: 100.0000, WER: 0.0000, CER: 0.0000
#
# Reference: Temecula me traffic kaisi dikh rahi hai
# Hypothesis: Temecula me traffic kaisa hai
# BLEU: 28.6419, WER: 0.4286, CER: 0.2564
#
# Reference: kya agle hafte New Albany Ohio me koi Christmas events hone wale hai
# Hypothesis: kya agle hafte New Albany Ohio me koi Christmas events hai
# BLEU: 76.2626, WER: 0.1538, CER: 0.1471
#
# Reference: kal ka mousam kaisa hoga
# Hypothesis: Kal mausam kaisa hai?
# BLEU: 10.6822, WER: 0.8000, CER: 0.3333
#
# Reference: accounting staff ke liye ek weekly reminder set karen meet 1st thing in the morning
# Hypothesis: accounting staff ke liye ek weekly reminder set kare to meet 1st thing in the morning
# BLEU: 74.4782, WER: 0.1333, CER: 0.0361
#
# Reference: har 15 minutes ke liye timer set kare
# Hypothesis: har 15 minutes ke liye timer set kare
# BLEU: 100.0000, WER: 0.0000, CER: 0.0000
#
# Reference: Kya is week me garm weather hone wala he
# Hypothesis: kya is haftey warm weather hone wali hai
# BLEU: 10.7868, WER: 0.6667, CER: 0.3000
#
# Reference: Mujhe agle Wednesday ko Mom ke birthday ke bare me yaad dilaayen .
# Hypothesis: Muje agle Wednesday ko Mom ke birthday ke liye yaad dilaye
# BLEU: 49.1953, WER: 0.3846, CER: 0.1667
#
# Reference: agar mai abhi nikalta hun toh mujhe yaha se Shun ke ghar drive karke jane me kitna samay lagega
# Hypothesis: Agar mai abhi nikalta hoon toh mujhe Shun ke ghar drive karne me kitna samay lagega
# BLEU: 33.5387, WER: 0.3158, CER: 0.1684
#
# Reference: kya aap Jeff ko ek video message send karsakte hai ?
# Hypothesis: kya aap Jeff ko ek video message bhejo?
# BLEU: 60.1053, WER: 0.3636, CER: 0.3269
#
# Reference: sunrise kab hai
# Hypothesis: sunrise ka time kya hai
# BLEU: 12.7033, WER: 1.0000, CER: 0.6000
#
# Reference: agley track par
# Hypothesis: agle track
# BLEU: 30.3265, WER: 0.6667, CER: 0.3333
#
# Reference: agla song please
# Hypothesis: agle song ko please
# BLEU: 18.9959, WER: 0.6667, CER: 0.2500
#
# Reference: mujhe kal meri interview ke baare me yaad dilaye
# Hypothesis: Muje mera interview ke liye yaad dilaye
# BLEU: 13.9587, WER: 0.5556, CER: 0.2917
#
# Reference: mujhe Tuesday 3 pm tak library books return karne ke liye yaad dilaye
# Hypothesis: mujhe Tuesday 3 pm ko library books return karne ke liye yaad dilaye
# BLEU: 76.1161, WER: 0.0769, CER: 0.0435
#
# Reference: agle monday ko temperature kitna hone wala hai ?
# Hypothesis: agle monday ka temperature kya hai?
# BLEU: 14.7596, WER: 0.6667, CER: 0.3125
#
# Reference: sabhi alarms aur timers ko hata do .
# Hypothesis: saare alarms aur timers delete kare
# BLEU: 21.6491, WER: 0.6250, CER: 0.3611
#
# Reference: Agar mai turnpike leta hoon toh mujhe Florida Keys pahuchne mei kitni der lagegi ?
# Hypothesis: Agar mai turnpike par Florida Keys tak pahunchne me kitni der lagegi?
# BLEU: 26.7261, WER: 0.6000, CER: 0.3049
#
# Reference: kal ka expected low kya hai ?
# Hypothesis: kal expected low kya hai?
# BLEU: 67.3182, WER: 0.4286, CER: 0.1379
#
# Reference: Pennsylvania se the Catskills tak drive kitni lambi hai
# Hypothesis: Pennsylvania se the Catskills tak drive kitni lambi hai
# BLEU: 100.0000, WER: 0.0000, CER: 0.0000
#
# Reference: Bob Michaels ko ek message bhejo jo kehta he ki thank you for the game
# Hypothesis: Bob Michaels ko message bhejo ki thank you for the game.
# BLEU: 44.9641, WER: 0.3333, CER: 0.2286
#
# Reference: Mere stoped timer ke sath chalu kare
# Hypothesis: mere stopped timer ke liye shuru kare
# BLEU: 14.5358, WER: 0.5714, CER: 0.2500
#
# Reference: Frank aur Bob ke wedding ke liye September 3rd ko reminder set kare ; mujhe ek week pehle gift khareedne ke liye yaad dilaayen .
# Hypothesis: Frank and Bob ke wedding ke liye reminder set kare on September 3rd ; remind me to buy a gift a week in advance.
# BLEU: 22.9348, WER: 0.7200, CER: 0.5000
#
# Reference: Kya ghar ke raste me koi traffic delays hai
# Hypothesis: Kya mere aas paas koi traffic delays hai
# BLEU: 32.2601, WER: 0.4444, CER: 0.2558
#
# Reference: FRIDAY ko TRAFFIC KAISA HOGA
# Hypothesis: Friday ko traffic kaisa hai
# BLEU: 10.6822, WER: 0.8000, CER: 0.7500
#
# Reference: Kya waha koi accidents he
# Hypothesis: kya koi accidents hai
# BLEU: 24.8805, WER: 0.6000, CER: 0.3200
#
# Reference: kya mujhe kal dopahar apni umbrella ki zarurat padegi ?
# Hypothesis: Kya mujhe kal subah mujhe umbrella chahiye?
# BLEU: 10.2292, WER: 0.7000, CER: 0.4909
#
# Reference: Hawai me abhi mausam kaisa hai ?
# Hypothesis: Hawaii me abhi weather kaisa hai?
# BLEU: 30.7394, WER: 0.5714, CER: 0.2500
#
# Reference: Agle Saturday ko San Antonio me Travis Park me jazz concert kab hai
# Hypothesis: Next Saturday San Antonio me Travis Park me Jazz concert kya times hai
# BLEU: 42.1181, WER: 0.3846, CER: 0.2239
#
# Reference: kya aaj ole girne wale hai ?
# Hypothesis: Kya aaj baarish hogi?
# BLEU: 8.5153, WER: 0.8571, CER: 0.6071
#
# Reference: ek ghante ke liye classical music bajao
# Hypothesis: ek ghante ke classical music bajao
# BLEU: 43.0125, WER: 0.1429, CER: 0.1282
#
# Reference: weekend ke liye mausam kaisa dikh raha hai ?
# Hypothesis: weekend ke liye weather kaisa hai?
# BLEU: 24.1772, WER: 0.5556, CER: 0.3864
#
# Reference: Is song ko phir se shuru karen
# Hypothesis: Is song ko restart kare
# BLEU: 26.6543, WER: 0.5714, CER: 0.3333
#
# Reference: Kansas City me traffic ki conditions kya he
# Hypothesis: Kansas City me traffic conditions kaisa hai
# BLEU: 37.6850, WER: 0.3750, CER: 0.1860
#
# Reference: mere sabhi weekend reminders Max ke sath pahunchne
# Hypothesis: Max par mere weekend ke liye saare reminders ko get kare
# BLEU: 5.6042, WER: 1.2500, CER: 0.7800
#
# Reference: mujhe kal ke reminders bataye
# Hypothesis: mujhe kal ke reminders batao
# BLEU: 66.8740, WER: 0.2000, CER: 0.0690
#
# Reference: Mera 5 am ka alarm har 10 minute me snooze kare
# Hypothesis: mere 5 am ke alarm ko har 10 minutes me snooze kare
# BLEU: 19.1569, WER: 0.3636, CER: 0.1489
#
# Reference: kya aaj toofan aane wala hai ?
# Hypothesis: Kya aaj storm hone wali hai?
# BLEU: 14.5358, WER: 0.8571, CER: 0.3333
#
# Reference: Agar mai is afternoon 3 : 00 baje nikal jaoon to mujhe yaha se Fayetteville me the mall tak pahunchne me kitna samay lagega ?
# Hypothesis: agar mai is afternoon 3 : 00 baje nikalta hoon toh mujhe to Fayetteville me mall pahuchne me kitni der lagegi?
# BLEU: 28.3619, WER: 0.5200, CER: 0.2400
#
# Reference: mujhe Bruno Mars ko sunna hai
# Hypothesis: mujhe Bruno Mars ko sunna chahiye
# BLEU: 75.9836, WER: 0.1667, CER: 0.1379
#
# Reference: Is saturday subah 10 bajhe team meeting ke liye reminder set kare
# Hypothesis: Is Saturday 10 am ko team meeting ke liye reminder set kare
# BLEU: 54.9100, WER: 0.3333, CER: 0.1846
#
# Reference: Mai pandora par Justin Bieber ko sunna chahta hu
# Hypothesis: mujhe pandora par Justin Bieber sunna chahta hoon
# BLEU: 36.2824, WER: 0.3333, CER: 0.2292
#
# Reference: 5 minutes me timer ko on karo
# Hypothesis: 5 minutes me timer ko band kare
# BLEU: 61.4788, WER: 0.2857, CER: 0.1379
#
# Reference: subha walk ke liye reminder set karen
# Hypothesis: morning walk ke liye reminder set kare
# BLEU: 61.4788, WER: 0.2857, CER: 0.2162
#
# Reference: kal ke alarm cancel kardo
# Hypothesis: kal ke alarm cancel kare
# BLEU: 66.8740, WER: 0.2000, CER: 0.0800
#
# Reference: is weekend par family events kya hai
# Hypothesis: is weekend kya family events hone wala hai
# BLEU: 17.2860, WER: 0.4286, CER: 0.3056
#
# Reference: is haftey ka sabse coldest day kya hai ?
# Hypothesis: Is week ka coldest day kya hai?
# BLEU: 47.7503, WER: 0.5556, CER: 0.3250
#
# Reference: is mahine hone wale Kendrick Lamar ke concerts
# Hypothesis: is mahine Kendrick Lamar ke concerts hone wala hai
# BLEU: 36.8894, WER: 0.6250, CER: 0.5217
#
# Reference: Kya seattle me abhi baarish horahi hai ?
# Hypothesis: kya seattle me current baarish hone wali hai?
# BLEU: 14.2588, WER: 0.6250, CER: 0.3500
#
# Reference: har do ghante ke liye alarm set kare
# Hypothesis: har two hours ke liye alarm set kare
# BLEU: 54.1082, WER: 0.2500, CER: 0.1944
#
# Reference: LAX ke aas paas traffic kaisa hai
# Hypothesis: LAX me traffic kaisa hai
# BLEU: 28.6419, WER: 0.4286, CER: 0.3030
#
# Reference: Mt . Hood tak current drive time kya hai
# Hypothesis: Mt. Hood ke liye current drive time kya hai
# BLEU: 52.5382, WER: 0.4444, CER: 0.2000
#
# Reference: aaj cairo me traffic kaisa hai
# Hypothesis: Aaj cairo me traffic kaisa hai
# BLEU: 75.9836, WER: 0.1667, CER: 0.0333
#
# Reference: current traffic ke sath mai ghar se safeway kab tak pahunch sakta hu
# Hypothesis: current traffic par mujhe safeway tak pahuchne ke liye kitna time bacha hai
# BLEU: 7.7686, WER: 0.8462, CER: 0.6324
#
# Reference: mai sam hunt sunna chahta hoon
# Hypothesis: mujhe sam hunt sunna chahta hu
# BLEU: 50.8133, WER: 0.3333, CER: 0.2333
#
# Reference: is coming Monday 2 pm , 3 pm aur 4 pm ke liye ek naya alarm banayen
# Hypothesis: Is coming Monday 2 pm, 3 pm aur 4 pm ke liye ek naya alarm banaye
# BLEU: 87.0240, WER: 0.2353, CER: 0.0448
#
# Reference: mujhe is friday subah 9 bajhe ke liye alarm chahiye .
# Hypothesis: mujhe is friday subah 9 baje ke liye alarm chahiye
# BLEU: 59.5417, WER: 0.1818, CER: 0.0566
#
# Reference: Mere paas abhi kitne alarms set hai
# Hypothesis: mujhe abhi kitne alarms set hai
# BLEU: 64.3187, WER: 0.2857, CER: 0.2571
#
# Reference: aaj Lake Ontario me water temperature kya he
# Hypothesis: aj Lake Ontario me water temperature kya hai
# BLEU: 68.0375, WER: 0.2500, CER: 0.0682
#
# Reference: mujhe Tuesday ko adhe ghante pehle mail alarm banaye
# Hypothesis: Tuesday ko mere mail alarm ko ek ghante pehle ghante pehle ke liye earlier
# BLEU: 9.8375, WER: 1.2222, CER: 0.8846
#
# Reference: Jin aur Sop ko message bhejo ki I am on the way home .
# Hypothesis: Jin aur Sop ko message bhejo ki I am on the way home
# BLEU: 92.5961, WER: 0.0714, CER: 0.0370
#
# Reference: Please clock par 1 minute add kare
# Hypothesis: please 1 minute ke liye clock
# BLEU: 15.2072, WER: 0.8571, CER: 0.6765
#
# Reference: 6 pm ke liye alarm lagaye
# Hypothesis: 6 pm ke liye alarm set kare
# BLEU: 61.4788, WER: 0.3333, CER: 0.2400
#
# Reference: agley 10 din ka forecast kya hai
# Hypothesis: agle 10 day ka forecast kya hai
# BLEU: 43.4721, WER: 0.2857, CER: 0.0938
#
# Reference: Is weekend Paris ke paas kitna cold hone wala he in degree Fahrenheit
# Hypothesis: Paris ke liye is weekend degree Fahrenheit me kitni garmi hai
# BLEU: 9.3451, WER: 0.8462, CER: 0.7246
#
# Reference: Please mere liye ek flight incoming alarm fix kare for today at 6 pm .
# Hypothesis: Please mujhe aj 6 pm ke liye ek flight incoming alarm fix karen.
# BLEU: 38.7392, WER: 0.8000, CER: 0.4571
#
# Reference: alarm par kitna time bakhi hai
# Hypothesis: alarm par kitna time bacha hai
# BLEU: 53.7285, WER: 0.1667, CER: 0.0667
#
# Reference: 95 . 1 bajaana shuru karo
# Hypothesis: 95. 1 ko bajao
# BLEU: 32.5556, WER: 0.8333, CER: 0.6400
#
# Reference: mujhe dopahar tak St . Paul pahuchne ke liye kab nikalna chahiye ?
# Hypothesis: mujhe noon se St. Paul tak pahuchne ke liye kitna samay lagega?
# BLEU: 19.6750, WER: 0.6923, CER: 0.4545
#
# Reference: kya area mei koi free Christmas parties hai
# Hypothesis: kya area me koi free Christmas parties hai
# BLEU: 59.4604, WER: 0.1250, CER: 0.0233
#
# Reference: mujhe 8 am ko school ke liye tayyar hone ke liye yaad dilaye
# Hypothesis: mujhe 8 am ko school ke liye yaad dilaye
# BLEU: 61.2611, WER: 0.3077, CER: 0.3333
#
# Reference: Tuesday ko kitni garmi hone wali hai ?
# Hypothesis: Tuesday ko kitni garmi hai?
# BLEU: 43.2982, WER: 0.5000, CER: 0.2895
#
# Reference: har Friday 1 pm ko housekeeper ke liye paise bachne ke liye reminder set kare
# Hypothesis: housekeeper ke liye har friday 1 pm ko money leave karne ke liye reminder set kare
# BLEU: 38.5032, WER: 0.6000, CER: 0.5455
#
# Reference: road trip ke bare mei yaad dilaye
# Hypothesis: road trip ke liye yaad dilaye
# BLEU: 32.1594, WER: 0.2857, CER: 0.2121
#
# Reference: mujhe har Sunday 10 am ko mere alarm ke zariye uthane ke liye bolo .
# Hypothesis: mujhe har Sunday 10 am ko mere alarm par mujhe yaad dilaayen
# BLEU: 47.7584, WER: 0.4667, CER: 0.3676
#
# Reference: agle hafte ke concerts
# Hypothesis: agle haftey concerts
# BLEU: 24.8408, WER: 0.5000, CER: 0.1364
#
# Reference: dentist ke liye mere reminder ko delete karo
# Hypothesis: dentist ke liye mere reminder delete kare
# BLEU: 55.7800, WER: 0.2500, CER: 0.0909
#
# Reference: Muje Australia ke mausam ke baarey me bataye
# Hypothesis: mujhe Australia me mausam batao
# BLEU: 7.7155, WER: 0.7500, CER: 0.4091
#
# Reference: Joyce ke ghar se AT & T center jaate samay traffic se bachne ke liye sabse acha detour konsa hai ?
# Hypothesis: Joyce ke ghar se AT & T center tak traffic avoid karne ke liye best detour he?
# BLEU: 38.4302, WER: 0.4286, CER: 0.3469
#
# Reference: Kya bahar baarish ho rahi hai ?
# Hypothesis: kya baarish hone wali hai?
# BLEU: 15.2072, WER: 0.8571, CER: 0.3871
#
# Reference: mai mere reminders edit karna chahta hoon
# Hypothesis: mujhe mere reminders edit kardo
# BLEU: 26.6543, WER: 0.5714, CER: 0.4146
#
# Reference: mai chahta hu ki time 15th May ko 10 baje band hojaye
# Hypothesis: mujhe 15th May ko 10 bajhe time ko bajao
# BLEU: 22.6136, WER: 0.7500, CER: 0.5472
#
# Reference: song ko repeat par rakho
# Hypothesis: song ko repeat kare
# BLEU: 46.3078, WER: 0.4000, CER: 0.2917
#
# Reference: construction kaha hai
# Hypothesis: construction kaha hai
# BLEU: 100.0000, WER: 0.0000, CER: 0.0000
#
# Reference: Kya mere area ke liye koi hurricanes predicted he ?
# Hypothesis: Kya mere area par predicted hurricanes hai?
# BLEU: 19.0387, WER: 0.6000, CER: 0.4706
#
# Reference: mai Tuesday April 18th ko kaam par vapas jaunga , us din subah 7 baje ke liye mere liye alarm banao
# Hypothesis: mujhe Tuesday April 18th ko work karne ke liye yaad dilaye, mujhe 7 am ke liye ek alarm banao
# BLEU: 16.6823, WER: 0.5714, CER: 0.4545
#
# Reference: Kya aaj mujhe skirt pehenna chahiye ?
# Hypothesis: Kya mujhe aaj skirt pehenna chahiye?
# BLEU: 47.2871, WER: 0.5714, CER: 0.2432
#
# Reference: abhi nahi !
# Hypothesis: abhi ke liye
# BLEU: 27.5161, WER: 0.6667, CER: 0.5455
#
# Reference: Agar mai 5 minutes mei nikalta hu aur detours leta hu toh downtown pahunchne me kitna samay lagega ?
# Hypothesis: agar mai 5 minutes se nikalta hoon to downtown pahuchne me kitna time lagega?
# BLEU: 11.7266, WER: 0.6316, CER: 0.3000
#
# Reference: Mere paas thursday ke liye kitne reminders he ?
# Hypothesis: Thursday ke liye kitne reminders hai?
# BLEU: 32.6683, WER: 0.5556, CER: 0.2766
#
# Reference: mujhe 16 July ke liye alarm chahiye
# Hypothesis: mujhe 16 July ke liye alarm chahiye
# BLEU: 100.0000, WER: 0.0000, CER: 0.0000
#
# Reference: Aerosmith play kariye
# Hypothesis: Aerosmith ko bajao
# BLEU: 27.5161, WER: 0.6667, CER: 0.4286
#
# Reference: haircut karne ke liye mere reminder ko delete kare since i had one today
# Hypothesis: Mere reminder ko delete kare to get a haircut since i had one today
# BLEU: 45.7231, WER: 0.6429, CER: 0.5139
#
# Reference: waha bahar kaisa hai
# Hypothesis: abhi kaisa hai
# BLEU: 39.4322, WER: 0.5000, CER: 0.3500
#
# Reference: temperature kya hai
# Hypothesis: temperature kya hai
# BLEU: 100.0000, WER: 0.0000, CER: 0.0000
#
# Reference: Texas me abhi mausam kaisa hai
# Hypothesis: Texas me abhi weather kya hai
# BLEU: 32.4668, WER: 0.3333, CER: 0.3000
#
# Reference: Mujhe game par time se pohochne ke liye konsa route mujhe time se pahuch sakta hai
# Hypothesis: mujhe game tak pahuchne ke liye yaad dilaye
# BLEU: 4.8319, WER: 0.8125, CER: 0.6220
#
# Reference: snow kab forecast kia gaya tha
# Hypothesis: snow ka forecast kya hai
# BLEU: 10.4006, WER: 0.6667, CER: 0.2667
#
# Reference: ek naya timer add karo
# Hypothesis: naya timer add kare
# BLEU: 46.3078, WER: 0.4000, CER: 0.1818
#
# Reference: mai ek minute ke liye set kiya hua ek timer chahiye
# Hypothesis: mujhe ek minute ke liye timer set kijiye
# BLEU: 26.2959, WER: 0.6364, CER: 0.4706
#
# Reference: Fri ke liye swim team ke liye alerts ko 4 : 45 ke liye badlein aur sat ko 9 : 45 ke liye badlein
# Hypothesis: swim team ke liye fri ke alerts change kare to 4 : 45 and sat ke liye change kare to 9 : 45
# BLEU: 20.8727, WER: 0.7083, CER: 0.6667
#
# Reference: thunderstorm kab shuru hoga ?
# Hypothesis: thunderstorm kab shuru hoga?
# BLEU: 100.0000, WER: 0.4000, CER: 0.0345
#
# Reference: aj ke liye 10 mins ka timer set kare
# Hypothesis: aaj ke liye 10 minutes timer ko band kare
# BLEU: 20.1649, WER: 0.5556, CER: 0.3333
#
# Reference: kya Salem me koi concerts aane wala hai
# Hypothesis: Salem me kya koi concerts hone wala hai
# BLEU: 19.8818, WER: 0.3750, CER: 0.2564
#
# Reference: forecast kya hai ?
# Hypothesis: forecast kya hai?
# BLEU: 100.0000, WER: 0.5000, CER: 0.0556
#
# Reference: groceries ke liye ek weekly reminder set karen .
# Hypothesis: groceries ke liye weekly reminder set kare
# BLEU: 30.8958, WER: 0.3333, CER: 0.1250
#
# Reference: New Mexico se Texas tak kitne miles hai
# Hypothesis: New Mexico se Texas tak kitne miles hai
# BLEU: 100.0000, WER: 0.0000, CER: 0.0000
#
# Reference: Kate se pucho ki kya she is going to be late .
# Hypothesis: Kate ko pucho ki she is going to be late.
# BLEU: 59.2065, WER: 0.3333, CER: 0.1522
#
# Reference: Kya abhi Pittsburgh me traffic slow he
# Hypothesis: kya Pittsburgh me abhi traffic slow hai
# BLEU: 19.6407, WER: 0.5714, CER: 0.3421
#
# Reference: kya mujhe sun glasses pehnna chahiye ya Jacket ?
# Hypothesis: Kya mujhe sun glasses ki zarurat chahiye?
# BLEU: 20.6124, WER: 0.6667, CER: 0.4375
#
# Reference: New York city me is weekend hone wale gaming events ki list
# Hypothesis: Is weekend New York city mei gaming events list hai
# BLEU: 17.4917, WER: 0.7500, CER: 0.6102
#
# Reference: is sunday ko Boat parade kis time par shuru hogi
# Hypothesis: Is Sunday ko Boat parade kab shuru kardo
# BLEU: 17.2034, WER: 0.6000, CER: 0.3542
#
# Reference: traffic jam kitne miles tak he
# Hypothesis: traffic jam kitne miles hai
# BLEU: 54.7518, WER: 0.3333, CER: 0.1667
#
# Reference: mai dad ke sath mere breakfast ke liye ek reminder chahiye .
# Hypothesis: mujhe dad ke liye mere breakfast ke liye reminder chahiye
# BLEU: 29.0607, WER: 0.3333, CER: 0.2167
#
# Reference: mere alarm ko 5 ghante me vibrate karne ke liye set kare
# Hypothesis: 5 hours ke liye mere alarm vibrate karne ke liye set kare
# BLEU: 48.3270, WER: 0.5000, CER: 0.3929
#
# Reference: meri Aunt ko message bhejo
# Hypothesis: mere aunt ko message bhejo
# BLEU: 39.7635, WER: 0.4000, CER: 0.0769
#
# Reference: kuch instrumental music bajao
# Hypothesis: kuch instrumental music bajao
# BLEU: 100.0000, WER: 0.0000, CER: 0.0000
#
# Reference: mere meeting alert ka samay Monday 830 pm ke liye badlein
# Hypothesis: Monday ko mere meeting alert ke time ko change kare to 830 pm
# BLEU: 15.7278, WER: 0.9091, CER: 0.6842
#
# Reference: last song ko phir se bajao .
# Hypothesis: last song ko bajao
# BLEU: 30.1815, WER: 0.4286, CER: 0.3571
#
# Reference: is weekend mai kya kar sakta hu
# Hypothesis: Is weekend kya mujhe kya karne ke liye
# BLEU: 6.5673, WER: 0.8571, CER: 0.5806
#
# Reference: Muje aaj subah 11 baje freezer se chicken nikalane ke liye remind karaye .
# Hypothesis: Muje aj 11 AM ko chicken ko freezer se shuru karne ke liye yaad dilaye
# BLEU: 8.5492, WER: 0.7857, CER: 0.5000
#
# Reference: aj dopahar ko work ke liye order plac karne ke liye reminder set kare
# Hypothesis: Aaj noon ko work ke liye order place karne ke liye reminder set kare
# BLEU: 61.6261, WER: 0.2143, CER: 0.1159
#
# Reference: Salt Lake City se Spokane tak drive karne mei kitni der lagegi
# Hypothesis: Salt Lake City se Spokane drive karne me kitni der lagegi
# BLEU: 47.0852, WER: 0.1667, CER: 0.0806
#
# Reference: Celsius me temperature kya hai ?
# Hypothesis: Celsius me temperature kya hai?
# BLEU: 100.0000, WER: 0.3333, CER: 0.0312
#
# Reference: Agle hafte San Francisco ke paas temperature F me
# Hypothesis: next week San Francisco ke liye temperature F he
# BLEU: 22.3162, WER: 0.4444, CER: 0.2857
#
# Reference: kuch New Years parties kaha hai
# Hypothesis: kya aaj New Years parties hai
# BLEU: 32.4668, WER: 0.5000, CER: 0.3548
#
# Reference: New York me abhi mausam kaisa hai
# Hypothesis: abhi New York me mausam kaisa hai
# BLEU: 42.7287, WER: 0.2857, CER: 0.3030
#
# Reference: Mujhe kal tak sabhi emails ko reply karne ke liye yaad dilaayen .
# Hypothesis: Muje kal ke liye sabhi emails reply karne ke liye yaad dilaye
# BLEU: 34.6863, WER: 0.4615, CER: 0.2308
#
# Reference: Kya aaj raat mujhe store se emergency supplies kharidne chahiye
# Hypothesis: Kya mujhe aaj raat store par emergency supplies kharidne ke liye yaad dilaye
# BLEU: 16.2617, WER: 0.7000, CER: 0.4603
#
# Reference: Agar mai abhi nikal jaoon to mujhe Carpenter par imax tak pahunchne me kitna samay lagega .
# Hypothesis: Agar mai abhi nikalta hoon toh mujhe Carpenter se imax pahuchne mei kitni der lagegi.
# BLEU: 11.6972, WER: 0.6471, CER: 0.2418
#
# Reference: Please mujhe taxes file karne ke liye yaad dilaye
# Hypothesis: Please mujhe taxes file karne ke liye yaad dilaye
# BLEU: 100.0000, WER: 0.0000, CER: 0.0000
#
# Reference: alarm ko 7 am se 6 am tak badal do
# Hypothesis: 7 am ke alarm ko 6 am ke liye badlein
# BLEU: 14.5358, WER: 0.8000, CER: 0.5882
#
# Reference: aaj kitni thand hogi ?
# Hypothesis: aj kitni garmi hone wali hai?
# BLEU: 7.8098, WER: 1.0000, CER: 0.6818
#
# Reference: abhi work se Joe tak pohochne me kitna time lagega ?
# Hypothesis: Abhi work se Joe ke liye abhi pahunchne me kitni der lagegi?
# BLEU: 13.6744, WER: 0.8182, CER: 0.4231
#
# Reference: har hafte alarm ko repeat kare
# Hypothesis: har haftey alarm ko repeat kare
# BLEU: 53.7285, WER: 0.1667, CER: 0.0333
#
# Reference: aj kitni garmi hai
# Hypothesis: aj kitni garmi hai
# BLEU: 100.0000, WER: 0.0000, CER: 0.0000
#
# Reference: Is weekend chicago me kitni barf padegi ?
# Hypothesis: Is weekend Chicago me kitna snow hai?
# BLEU: 13.1345, WER: 0.6250, CER: 0.2683
#
# Reference: 3 00 pm ko 10 minutes ke liye daily timer set kare
# Hypothesis: 3 00 pm ko 10 minutes ke liye daily timer set kare
# BLEU: 100.0000, WER: 0.0000, CER: 0.0000
#
# Reference: Kya Minneapolis me is weekend koi naye nightclubs khul rahe he
# Hypothesis: kya is weekend Minneapolis me koi naye nightclubs opening hai
# BLEU: 20.7728, WER: 0.7273, CER: 0.5484
#
# Reference: Mere timer par kitna time bacha he ?
# Hypothesis: mere timer par kitna time bacha hai?
# BLEU: 54.1082, WER: 0.3750, CER: 0.0833
#
# Reference: mere current playlist me kendrick lamar ka album DAMN ko add karen .
# Hypothesis: meri current playlist me kendrick lamar album DAMN. ko add kare
# BLEU: 38.3867, WER: 0.3846, CER: 0.1176
#
# Reference: is week ke liye sun kab forecast me hai ?
# Hypothesis: Is week ke liye forecast par sun kab hai?
# BLEU: 23.7368, WER: 0.7000, CER: 0.4634
#
# Reference: mere bhai ko bolo ki Mentor Library is hosting a Dahmer reading tonight .
# Hypothesis: mere bhai ko bolo ki Mentor Library hosting a Dahmer reading tonight.
# BLEU: 78.8193, WER: 0.2143, CER: 0.0548
#
# Reference: Aaj ki wind speed kya hogi ?
# Hypothesis: aj wind speed kya hai?
# BLEU: 27.4825, WER: 0.5714, CER: 0.2500
#
# Reference: Muje Legoland tak pohochne me kitna time lagega
# Hypothesis: Legoland tak pahuchne mei kitni der lagegi
# BLEU: 11.3861, WER: 0.7500, CER: 0.2979
#
# Reference: Kya aap aaj raat ke liye mera alarm cancel karsakte hai ?
# Hypothesis: kya aap raat ke liye mere alarm cancel kare?
# BLEU: 17.4917, WER: 0.5000, CER: 0.2632
#
# Reference: Please agla song play kare
# Hypothesis: Please agle song bajao
# BLEU: 14.7940, WER: 0.6000, CER: 0.3077
#
# Reference: kal Orlando me karne ke liye chize
# Hypothesis: Orlando me kal kya hone wala hai
# BLEU: 14.5358, WER: 0.8571, CER: 0.5882
#
# Reference: mujhe library se kitne baje nikal na chahiye 6PM tak work par pahunchne ke liye
# Hypothesis: mujhe library par kitna time ko pahuchne ke liye 6pm tak work tak pahuchne ke liye
# BLEU: 8.8046, WER: 0.6667, CER: 0.3165
#
# Reference: Do minutes ke liye har 30 second me alarm set kare
# Hypothesis: alarm set kare for every 30 seconds for two minutes.
# BLEU: 15.8512, WER: 0.9091, CER: 0.7000
#
# Reference: mere timer me ek aur 2 hours add kare
# Hypothesis: mere timer me ek 2 hours add kare
# BLEU: 61.0195, WER: 0.1111, CER: 0.1081
#
# Reference: Mere paas monday , August 20th ke liye konse reminders he ?
# Hypothesis: Monday, August 20th ke liye mere liye reminders kya hai?
# BLEU: 34.4844, WER: 0.6667, CER: 0.4237
#
# Reference: Miami me karne ke liye cheeze
# Hypothesis: Miami me general me karne ke liye cheeze
# BLEU: 57.2125, WER: 0.3333, CER: 0.3793
#
# Reference: mujhe 9 am se pehle coffee pot band karne ke liye yaad dilaye
# Hypothesis: mujhe subah 9 baje coffee pot band karne ke liye yaad dilaye
# BLEU: 59.6567, WER: 0.3077, CER: 0.1639
#
# Reference: Mera alarm kab tak band rahega ?
# Hypothesis: mere alarm ko band karne ke liye kitni der lagegi?
# BLEU: 4.9324, WER: 1.2857, CER: 0.9062
#
# Reference: Annie ko ek response bhejo
# Hypothesis: Annie ko response bhejo
# BLEU: 35.1863, WER: 0.2000, CER: 0.1154
#
# Reference: alarm ko on karo
# Hypothesis: alarm ko on kare
# BLEU: 59.4604, WER: 0.2500, CER: 0.0625
#
# Reference: 2 min 30 sec ke liye timer set karo
# Hypothesis: 2 min 30 sec ke liye timer set kare
# BLEU: 86.3340, WER: 0.1111, CER: 0.0286
#
# Reference: kya aap proofing ke liye timer ko pause karsakte hai
# Hypothesis: kya aap proofing ke liye timer pause kare
# BLEU: 55.0695, WER: 0.3000, CER: 0.2115
#
# Reference: aas paas kuch mazedaar chizein chal rahe hai
# Hypothesis: nearby par koi fun things kya hai
# BLEU: 5.6930, WER: 0.8750, CER: 0.7045
#
# Reference: reminder location badlein
# Hypothesis: reminder location ko change kare
# BLEU: 21.3644, WER: 1.0000, CER: 0.4800
#
# Reference: 16th ko 1 am ke liye ek alarm set karen .
# Hypothesis: alarm set kare for the 16th at 1 a. m.
# BLEU: 8.5166, WER: 1.0000, CER: 0.8049
#
# Reference: running timer ko pause karo
# Hypothesis: running timer ko pause kare
# BLEU: 66.8740, WER: 0.2000, CER: 0.0370
#
# Reference: rest of the year ke liye moms group meetings ke sarey reminders pull up kare
# Hypothesis: moms group meetings ke liye sabhi reminders pull kare for the rest of the year
# BLEU: 39.1295, WER: 0.9333, CER: 0.7237
#
# Reference: thursday ka weather kya hai ?
# Hypothesis: Thursday ke mausam kaisa hai?
# BLEU: 16.2334, WER: 1.0000, CER: 0.4138
#
# Reference: Los Angeles me traffic
# Hypothesis: Los Angeles me Traffic
# BLEU: 59.4604, WER: 0.2500, CER: 0.0455
#
# Reference: kya aj barish hogi
# Hypothesis: Kya aaj baarish hogi
# BLEU: 15.9736, WER: 0.7500, CER: 0.1667
#
# Reference: traffic kaisa delay causing hai
# Hypothesis: traffic kaisa delay kya hai
# BLEU: 42.7287, WER: 0.2000, CER: 0.2258
#
# Reference: Phoenix mei Family events hai
# Hypothesis: Phoenix me Family events
# BLEU: 27.5348, WER: 0.4000, CER: 0.1724
#
# Reference: kal library books return karne ke liye reminder add karen
# Hypothesis: kal library books return karne ke liye reminder add kare
# BLEU: 88.0112, WER: 0.1000, CER: 0.0175
#
# Reference: mere pati ko bolo ki maine saturday subah 10 bajhe ke liye spa date booked kar diya hai
# Hypothesis: meri wife ko bataiye ki I have booked the spa date for us on Saturday at 10 am
# BLEU: 5.6530, WER: 0.8889, CER: 0.6552
#
# Reference: middlebury aur chicago ke beech ka distance kitna hai
# Hypothesis: middlebury aur chicago ke liye kitna distance hai
# BLEU: 35.0912, WER: 0.3333, CER: 0.2642
#
# Reference: Please Julie ko message bhejkar pucho ki where the festival is at this weekend .
# Hypothesis: Julie ko message karo aur pucho ki where the festival is at this weekend.
# BLEU: 72.4158, WER: 0.3333, CER: 0.1750
#
# Reference: Hawai me sunset kab hai
# Hypothesis: Hawaii me sunset kab hai
# BLEU: 66.8740, WER: 0.2000, CER: 0.0435
#
# Reference: Mere liye mom ka last message padker sunaiye
# Hypothesis: mujhe mom ke liye last message dikhaye
# BLEU: 13.5404, WER: 0.7500, CER: 0.5455
#
# Reference: New South Wales ke liye weather Outlook kya hai ?
# Hypothesis: New South Wales ke liye weather outlook?
# BLEU: 55.0695, WER: 0.4000, CER: 0.2041
#
# Reference: mere timer ko restart kare
# Hypothesis: mere timer ko restart kare
# BLEU: 100.0000, WER: 0.0000, CER: 0.0000
#
# Reference: London me teen din me mausam kaisa hone wala hai ?
# Hypothesis: London mei three days ke liye weather kaisa hai?
# BLEU: 9.0304, WER: 0.9091, CER: 0.5200
#
# Reference: please holiday bash ke reminder ko cancel kardo
# Hypothesis: holiday bash ke liye reminder cancel kare please
# BLEU: 24.4462, WER: 0.6250, CER: 0.4894
#
# Reference: agla song
# Hypothesis: agle song
# BLEU: 50.0000, WER: 0.5000, CER: 0.1111
#
# Reference: Mark ko text bheje
# Hypothesis: Mark ko text kare
# BLEU: 59.4604, WER: 0.2500, CER: 0.2222
#
# Reference: kya aap kuch bhi karsakte hai jo mujhe laugh karne ke liye motive kare
# Hypothesis: kya aap mujhe kuch kuch kuch kuch kuch kuch kuch karna chahiye
# BLEU: 6.8180, WER: 0.8571, CER: 0.6429
#
# Reference: egg timer ko drop kare
# Hypothesis: egg timer ko drop kare
# BLEU: 100.0000, WER: 0.0000, CER: 0.0000
#
# Reference: music ko on karo please
# Hypothesis: music ko band kare please
# BLEU: 23.6435, WER: 0.4000, CER: 0.1739
#
# Reference: mere music ko rok do
# Hypothesis: mere music ko rok do
# BLEU: 100.0000, WER: 0.0000, CER: 0.0000
#
# Reference: mere time ko resume kardo
# Hypothesis: mere time ko tracking ko resume kare
# BLEU: 29.0715, WER: 0.6000, CER: 0.5600
#
# Reference: Kya aaj flooding hone ke chances he ?
# Hypothesis: Kya aaj koi flash flooding hone wali hai?
# BLEU: 14.2588, WER: 0.7500, CER: 0.5676
#
# Reference: Aaj event se 1 ghanta pehle ke liye reminders ko dikhayen
# Hypothesis: Aaj event ke liye 1 ghante pehle reminders set kare
# BLEU: 12.3516, WER: 0.6364, CER: 0.4035
#
# Reference: September 1st ke liye mujhe mere saarey reminders dikhao .
# Hypothesis: mujhe September 1st ke liye mere sabhi reminders dikhao
# BLEU: 34.1307, WER: 0.4000, CER: 0.3103
#
# Reference: is saal maine kachra baahar nikalne ke liye kitne reminders gehae hai ?
# Hypothesis: Is year me kitne reminders for setting out the trash hai?
# BLEU: 8.8126, WER: 1.0000, CER: 0.6761
#
# Reference: last track ko fir se chalaye please
# Hypothesis: please last track ko phir se repeat kare
# BLEU: 23.3569, WER: 0.5714, CER: 0.5429
#
# Reference: 10 minutes ke liye timer ko set kare
# Hypothesis: 10 minutes ke liye mere phone timer set kare
# BLEU: 36.8894, WER: 0.3750, CER: 0.3611
#
# Reference: please abhi chats ko dikhao
# Hypothesis: please abhi chats ko phir se shuru kare
# BLEU: 34.5721, WER: 0.8000, CER: 0.5556
#
# Reference: Bournemouth me kal ke liye mausam kaisa hai
# Hypothesis: Bournemouth me kal ke liye weather kaisa hoga
# BLEU: 54.1082, WER: 0.2500, CER: 0.2093
#
# Reference: Kya humko ice storm milne wala he
# Hypothesis: kya aap ice storm hone wali hai
# BLEU: 13.1345, WER: 0.7143, CER: 0.3636
#
# Reference: mere playlist me track ko add karen
# Hypothesis: mere playlist me track ko add kare
# BLEU: 80.9107, WER: 0.1429, CER: 0.0286
#
# Reference: kal kya ho raha he
# Hypothesis: Kal kya hone wala hai
# BLEU: 10.6822, WER: 0.8000, CER: 0.3889
#
# Reference: 45 seconds ke liye timer set karen .
# Hypothesis: 45 seconds ke liye timer set kare
# BLEU: 70.1397, WER: 0.2500, CER: 0.0833
#
# Reference: yaha se Niagara Falls , Canada tak kitne miles hai
# Hypothesis: here se Niagara Falls, Canada tak kitne miles hai
# BLEU: 88.0112, WER: 0.3000, CER: 0.1000
#
# Reference: kya mujhe current traffic me Tracy ke ghar pahunchne me ek ghante se zyada lagega ?
# Hypothesis: kya current traffic par Tracy ke ghar tak pahuchne ke liye kitna samay lagega?
# BLEU: 13.9072, WER: 0.6250, CER: 0.3735
#
# Reference: meeting ke liye reminder ko delete kare
# Hypothesis: meeting ke liye reminder delete kare
# BLEU: 51.1508, WER: 0.1429, CER: 0.0769
#
# Reference: 10 30 second intervals ke liye timer set kare
# Hypothesis: 10 30 second intervals ke liye timer set kare
# BLEU: 100.0000, WER: 0.0000, CER: 0.0000
#
# Reference: grocery list reminder me Spinach aur onions ko add karen
# Hypothesis: spinach aur onions ko grocery list reminder me add kare
# BLEU: 39.2815, WER: 0.9000, CER: 0.7321
#
# Reference: classical music play karo
# Hypothesis: classical music bajao
# BLEU: 39.4322, WER: 0.5000, CER: 0.2400
#
# Reference: agla song bajao
# Hypothesis: agle song bajao
# BLEU: 55.0321, WER: 0.3333, CER: 0.0667
#
# Reference: Monday 18th June ko subah 9 bajhe ke liye ek naye alarm ko create karen
# Hypothesis: Monday 18th of June at 9 am ke liye ek naya alarm banao
# BLEU: 13.9428, WER: 0.5333, CER: 0.3944
#
# Reference: is gaaney ko restart kare
# Hypothesis: Is song ko restart kare
# BLEU: 39.7635, WER: 0.4000, CER: 0.2400
#
# Reference: kya aaj roads wet hone wale hai ?
# Hypothesis: kya aaj roads naye hai?
# BLEU: 27.2223, WER: 0.6250, CER: 0.3333
#
# Reference: Seattle me pet friendly hotels
# Hypothesis: Seattle mei pet friendly hotels
# BLEU: 42.7287, WER: 0.2000, CER: 0.0333
#
# Reference: Orlando me abhi humidity
# Hypothesis: Orlando me abhi humidity
# BLEU: 100.0000, WER: 0.0000, CER: 0.0000
#
# Reference: kya mai coat la sakta hoon
# Hypothesis: Kya mujhe coat lena chahiye
# BLEU: 8.7458, WER: 0.8333, CER: 0.5769
#
# Reference: ek naya alarm set karo
# Hypothesis: naya alarm set kare
# BLEU: 46.3078, WER: 0.4000, CER: 0.1818
#
# Reference: mujhe sabhi alarms dikhao
# Hypothesis: mujhe saare alarms dikhao
# BLEU: 35.3553, WER: 0.2500, CER: 0.1200
#
# Reference: 30 seconds ke liye timer set karen
# Hypothesis: 30 seconds ke liye timer set kare
# BLEU: 80.9107, WER: 0.1429, CER: 0.0294
#
# Reference: Sunday ko kitna cold hone wala he ?
# Hypothesis: Sunday ko kitni garmi hai?
# BLEU: 12.8726, WER: 0.7500, CER: 0.4857
#
# Reference: Kya aap mujhe bata sakte hai Kabul me mausam kaisa hai ?
# Hypothesis: Kya aap mujhe batao Kabul me mausam kaisa hai?
# BLEU: 53.8755, WER: 0.4167, CER: 0.1964
#
# Reference: Mujhe yaad dilao ki Friday 2 30 pm ko Skylee ko doctor ki appointment hai .
# Hypothesis: Muje remind karaye ki Skylee ke liye Friday 2 : 30 pm ko doctor ki appointment hai
# BLEU: 32.2254, WER: 0.6250, CER: 0.4933
#
# Reference: laurie ko message karo ki i am on the ferry and will be 20 minutes late
# Hypothesis: laurie ko message karo ki i am on the ferry and will be 20 minutes late
# BLEU: 100.0000, WER: 0.0000, CER: 0.0000
#
# Reference: chicago aur denver ke beech ka distance kitna hai
# Hypothesis: Chicago aur denver ke liye kitna distance hai
# BLEU: 21.5737, WER: 0.4444, CER: 0.3061
#
# Reference: Kya aaj raat ko muje winter coat pehenna chahiye
# Hypothesis: Kya mujhe aaj raat winter coat pehenna chahiye
# BLEU: 37.7079, WER: 0.3333, CER: 0.2708
#
# Reference: 640 ke liye alarm lagaye
# Hypothesis: 640 ke liye alarm set kare
# BLEU: 50.8133, WER: 0.4000, CER: 0.2500
#
# Reference: kya agle mahine baarish hone ke koi chance hai
# Hypothesis: kya agley mahine ke liye chance hai
# BLEU: 12.4113, WER: 0.4444, CER: 0.3913
#
# Reference: kya agle saal Broward Center mei koi Andre Rieu ke concerts aane wale hai
# Hypothesis: kya agley aaj Broward Center me Andre Rieu ke concerts hai
# BLEU: 22.8255, WER: 0.4286, CER: 0.2466
#
# Reference: mai airport jaane ke liye kitne routes choose kar sakta hoon
# Hypothesis: mujhe airport tak pahuchne ke liye kitne routes choose kare
# BLEU: 37.2009, WER: 0.5455, CER: 0.3833
#
# Reference: meri mom ko milne ke liye mujhe reminder dikhao
# Hypothesis: mujhe mere mom ko meet karne ke liye reminder dikhao
# BLEU: 15.1069, WER: 0.5556, CER: 0.4255
#
# Reference: Mujhe aj raat ko garden ko water karne ke liye yaad dilaye
# Hypothesis: Muje aaj raat garden ko water karne ke liye yaad dilaye
# BLEU: 63.8194, WER: 0.2500, CER: 0.0862
#
# Reference: 10 am aur 11 am ke liye alarms set karen .
# Hypothesis: 10 am aur 11 am ke liye alarms set kare
# BLEU: 79.6358, WER: 0.1818, CER: 0.0714
#
# Reference: pollen count kitna hai
# Hypothesis: pollen count kya hai
# BLEU: 35.3553, WER: 0.2500, CER: 0.1364
#
# Reference: Is weekend Jackson me Music events hai
# Hypothesis: Is weekend Jackson me Music events
# BLEU: 84.6482, WER: 0.1429, CER: 0.1053
#
# Reference: midnight ka alarm set kare
# Hypothesis: Midnight alarm
# BLEU: 11.1565, WER: 0.8000, CER: 0.5000
#
# Reference: kya hiking group chat par kuch hai ?
# Hypothesis: kya hiking group chat par kuch karna hai?
# BLEU: 66.0633, WER: 0.2500, CER: 0.1944
#
# Reference: route 301 kitna busy hai
# Hypothesis: route 301 kitna busy hai
# BLEU: 100.0000, WER: 0.0000, CER: 0.0000
#
# Reference: is gaaney ko repeat par rakhiye
# Hypothesis: Is song ko repeat kare
# BLEU: 17.4917, WER: 0.6667, CER: 0.4516
#
# Reference: Mikayla ko text karo ki i didn ' t see him doing that yesterday '
# Hypothesis: Mikayla ko text karo ki i didn't see him doing that yesterday '
# BLEU: 65.2622, WER: 0.2000, CER: 0.0308
#
# Reference: mera agla alarm kis liye hai
# Hypothesis: Mere agle alarm kya hai
# BLEU: 10.4006, WER: 0.6667, CER: 0.3214
#
# Reference: mujhe har raat 9 pm tak mera alarm set karne ke liye yaad dilaayen
# Hypothesis: mujhe har raat 9 baje mera alarm set karne ke liye yaad dilaye
# ...
# BLEU: 39.9388, WER: 0.2000, CER: 0.2174
#
# Reference: Morgan Hill mei weather kaisa hai
# Hypothesis: Morgan Hill me mausam kaisa hai
# BLEU: 22.9575, WER: 0.3333, CER: 0.2121
#
# Reference: is gaaney ko repeat par rakhiye
# Hypothesis: Is song ko repeat kare
# BLEU: 17.4917, WER: 0.6667, CER: 0.4516
#
# Reference: nyc mei marathon
# Hypothesis: nyc me marathon
# BLEU: 34.6681, WER: 0.3333, CER: 0.0625
#
# Reference: Kya aaj San Francisco me traffic bhaari hai
# Hypothesis: kya aaj San Francisco me traffic heavy hai
# BLEU: 54.1082, WER: 0.2500, CER: 0.1163
#
# Reference: 30 minute ke liye har 5 minute mei alarm set kare
# Hypothesis: 30 minutes ke liye ek alarm set kare for every 5 minutes
# BLEU: 17.2422, WER: 0.8182, CER: 0.5918
#
# Reference: Please mere chat requests ko retrieve kare
# Hypothesis: please mere chat requests ko retrieve kare
# BLEU: 80.9107, WER: 0.1429, CER: 0.0238
#
# Reference: Altamonte ke aas pas Swimming lessons
# Hypothesis: Altamonte ke paas swimming lessons
# BLEU: 19.3577, WER: 0.5000, CER: 0.1351
#
# Reference: kya aaj mujhe jacket pahanani chahiye ?
# Hypothesis: Kya mujhe aaj jacket pehenna chahiye?
# BLEU: 16.5158, WER: 0.8571, CER: 0.3590
#
# Reference: kya maine kal mere doctor ko text kia
# Hypothesis: Kya aaj mere doctor ko text kare he?
# BLEU: 29.8475, WER: 0.6250, CER: 0.4054
#
# Reference: Arthur ko message karo ki A big big boat .
# Hypothesis: Arthur ko message karo A big big boat
# BLEU: 53.8495, WER: 0.2000, CER: 0.1190
#
# Reference: mere area me sabse zyada bhaari traffic kahan par hai
# Hypothesis: Mere area mei koi traffic kaisa hai
# BLEU: 5.6304, WER: 0.7000, CER: 0.4528
#
# Reference: group message par thumbs up reaction bheje
# Hypothesis: group message par thumbs up reaction bhejo
# BLEU: 80.9107, WER: 0.1429, CER: 0.0238
#
# Reference: mujhe mere ghar se Minneapolis ke liye directions chahiye , while taking a detour through Arkansas .
# Hypothesis: mujhe mere ghar se Minneapolis jaane ke liye directions chahiye, tak detour through Arkansas.
# BLEU: 57.5680, WER: 0.4706, CER: 0.1900
#
# Reference: Please , weather report bheje .
# Hypothesis: Please weather report.
# BLEU: 23.0432, WER: 0.6667, CER: 0.2903
#
# Reference: last song ko reply kare
# Hypothesis: last song ko replay kare
# BLEU: 42.7287, WER: 0.2000, CER: 0.0435
#
# Reference: mujhe supermarket tak drive karke jaane me kitna samay lagega
# Hypothesis: mujhe supermarket tak drive karne ke liye kitna time lagega
# BLEU: 29.0715, WER: 0.4000, CER: 0.1967
#
# Reference: RUSS ko message karo aur pucho ki WHEN HIS MOTHER WILL BE AT THE AIRPORT NEXT WEEK .
# Hypothesis: Russ ko message karo aur pucho ki when his mother will be at the airport NEXT WEEK
# BLEU: 29.8787, WER: 0.5556, CER: 0.4286
#
# Reference: kya Montgomery me is subha traffic kharab hai
# Hypothesis: kya Montgomery me aaj subah traffic kaisa hai
# BLEU: 23.3569, WER: 0.3750, CER: 0.2000
#
# Reference: aaj 6 baje ke liye ek nap alarm set karen
# Hypothesis: aj subah 6 baje ke liye nap alarm set kare
# BLEU: 37.9918, WER: 0.4000, CER: 0.2439
#
# Reference: Mujhe thursday 2 pm ko meri dentist appointment ke baare me yaad dilaayen
# Hypothesis: mujhe thursday 2 pm ko mere dentist appointment ke liye yaad dilaye
# BLEU: 29.1676, WER: 0.3846, CER: 0.1507
#
# Reference: Devin Jones ko ek voice message bhejo
# Hypothesis: Devin Jones ko voice message bhejo
# BLEU: 43.0125, WER: 0.1429, CER: 0.0811
#
# Reference: Staten Island se Perth Amboy tak traffic driving kya hai
# Hypothesis: Staten Island se Perth Amboy tak traffic driving kya hai
# BLEU: 100.0000, WER: 0.0000, CER: 0.0000
#
# Reference: Crystal Lake tak jane ke liye kitni der lagegi
# Hypothesis: Crystal Lake tak pahuchne me kitni der lagegi
# BLEU: 30.5098, WER: 0.3333, CER: 0.1957
#
# Reference: saare alarms band karo
# Hypothesis: saare alarms band kardo
# BLEU: 59.4604, WER: 0.2500, CER: 0.0455
#
# Reference: iheartradio par Y 102 5 station ko play kare
# Hypothesis: iheartradio par Y 102 5 station ko bajao
# BLEU: 74.2088, WER: 0.2222, CER: 0.1591
#
# Reference: Is subha alarm sounds ko hata den
# Hypothesis: Is mahine alarm sounds ko remove kare
# BLEU: 26.2691, WER: 0.4286, CER: 0.4848
#
# Reference: Saturday ke liye kya forecast hai
# Hypothesis: Saturday ke liye forecast kya hai?
# BLEU: 29.0715, WER: 0.5000, CER: 0.2727
#
# Reference: mujhe 6 baje hits hone par yaad dilaayen
# Hypothesis: Muje remind karaye when it hits 6
# BLEU: 6.7702, WER: 1.0000, CER: 0.7750
#
# Reference: Texas ke liye weather bataye please
# Hypothesis: Texas ke liye weather please
# BLEU: 57.8930, WER: 0.1667, CER: 0.2000
#
# Reference: Kya aaj mujhe apne saath umbrella laana chahiye ?
# Hypothesis: Kya muje aaj muje umbrella lena chahiye?
# BLEU: 12.2562, WER: 0.7778, CER: 0.3265
#
# Reference: sixth timer ko update kare
# Hypothesis: sixth timer ko update kare
# BLEU: 100.0000, WER: 0.0000, CER: 0.0000
#
# Reference: kya route 66 par traffic hai
# Hypothesis: kya route 66 par backup hai
# BLEU: 53.7285, WER: 0.1667, CER: 0.2143
#
# Reference: fathers day card kharidne ka reminder chahiye
# Hypothesis: fathers day card kharidne ke liye reminder chahiye
# BLEU: 41.1134, WER: 0.2857, CER: 0.1333
#
# Reference: workout timer par kitna time bacha hai
# Hypothesis: workout timer par kitna time bacha hai
# BLEU: 100.0000, WER: 0.0000, CER: 0.0000
#
# Reference: playlist ko display kare
# Hypothesis: playlist ko display kare
# BLEU: 100.0000, WER: 0.0000, CER: 0.0000
#
# Reference: classical music play karo
# Hypothesis: classical music bajao
# BLEU: 39.4322, WER: 0.5000, CER: 0.2400
#
# Reference: Mujhe aj ke liye work ke mere reminders dijiye
# Hypothesis: mujhe mere aaj ke liye work ke liye reminders dikhayen
# BLEU: 29.0715, WER: 0.5556, CER: 0.3043
#
# Reference: mere aas paas comic - con
# Hypothesis: mere liye Comic - Con chahiye
# BLEU: 9.6524, WER: 0.8333, CER: 0.7200
#
# Reference: 5 ghante ke liye timer set kardo
# Hypothesis: 5 ghante ke liye timer set kare
# BLEU: 80.9107, WER: 0.1429, CER: 0.0625
#
# Reference: mai Beyonce ka latest album sunna chahta hoon
# Hypothesis: mujhe latest Beyonce album sunna chahta hoon
# BLEU: 39.4424, WER: 0.5000, CER: 0.4000
#
# Reference: Mera alarm kab tak band rahega ?
# Hypothesis: mere alarm ko band karne ke liye kitni der lagegi?
# BLEU: 4.9324, WER: 1.2857, CER: 0.9062
#
# Reference: mujhe Yonkers se White Plains tak ka time batao
# Hypothesis: mujhe Yonkers se White Plains tak pahuchne ke liye time lagaye
# BLEU: 47.9878, WER: 0.4444, CER: 0.4043
#
# Reference: kya aj 100 degrees se zyada hone wala hai ?
# Hypothesis: Kya aaj 100 degrees hone wali hai?
# BLEU: 12.8625, WER: 0.7000, CER: 0.3023
#
# Reference: I - 30 par dopaher ke aas paas traffic kitna zada hai
# Hypothesis: I - 30 par noon ke liye traffic kaisa hai
# BLEU: 24.7369, WER: 0.4167, CER: 0.3962
#
# Reference: Tuesday ke liye mausam kaisa hoga
# Hypothesis: Tuesday ke liye weather kaisa hai
# BLEU: 32.4668, WER: 0.3333, CER: 0.2727
#
# Reference: Florida se California tak ki doori kitni hai
# Hypothesis: Florida se California tak ka distance kitna hai
# BLEU: 36.5555, WER: 0.3750, CER: 0.2045
#
# Reference: do tracks wapas jaayen
# Hypothesis: two tracks ko go back kare
# BLEU: 8.1167, WER: 1.2500, CER: 0.6364
#
# Reference: mujhe David ko text bhejna hai . kya ap mujhe 3 : 30 bajhe yaad dila sakte hai .
# Hypothesis: mujhe David ko text karne ke liye. kya aap mujhe 3 : 30 baje ke liye yaad dilaye
# BLEU: 28.5264, WER: 0.5263, CER: 0.3750
#
# Reference: Philly me Wine tasting meetups
# Hypothesis: Philly me Wine tasting meetups
# BLEU: 100.0000, WER: 0.0000, CER: 0.0000
#
# Reference: today long beach par waves kitne bhari hai
# Hypothesis: Aaj Long beach me kitna waves hai
# BLEU: 7.4924, WER: 0.7500, CER: 0.4524
#
# Reference: Kya hum lightning ki ummeed karsakte hai ?
# Hypothesis: kya mujhe lightning chahiye?
# BLEU: 6.9717, WER: 0.8750, CER: 0.6190
#
# Reference: Natalie Grant ke Concerts
# Hypothesis: Natalie Grant ke concerts
# BLEU: 59.4604, WER: 0.2500, CER: 0.0400
#
# Reference: Mera next church meeting ka reminder kab he ?
# Hypothesis: mere agley church meeting ke reminder kab hai?
# BLEU: 14.2588, WER: 0.5556, CER: 0.2222
#
# Reference: Mera alarm kab tak band rahega ?
# Hypothesis: mere alarm ko band karne ke liye kitni der lagegi?
# BLEU: 4.9324, WER: 1.2857, CER: 0.9062
#
# Reference: joselyn ki wedding ke liye June 10th ko , 2019 ka reminder banaye
# Hypothesis: joselyn ke wedding ke liye June 10th, 2019 ka reminder create kare
# BLEU: 49.7357, WER: 0.4615, CER: 0.2000
#
# Reference: Please har dusre din weight check ke liye ek reminder set karen .
# Hypothesis: Please weight check ke liye ek reminder set kare every other day.
# BLEU: 50.0872, WER: 0.5385, CER: 0.4462
#
# Reference: 2 minutes ke liye timer set karen
# Hypothesis: 2 minutes ke liye timer set kare
# BLEU: 80.9107, WER: 0.1429, CER: 0.0303
#
# Reference: timer par kitna samay hai ?
# Hypothesis: timer par kitna time bacha hai?
# BLEU: 30.7394, WER: 0.5000, CER: 0.3333
#
# Reference: Please meri music playlist ko play kare .
# Hypothesis: Please mere music playlist play kare
# BLEU: 17.3935, WER: 0.3750, CER: 0.1463
#
# Reference: Brady aur Jackson ko alert kare ki 3 baje mujhe nikalna hai ; unhe ek ghante pehle alert kare
# Hypothesis: Brady aur Jackson ko yaad dilaye ki we need to leave at 3; alert them an hour before.
# BLEU: 14.2539, WER: 0.7368, CER: 0.5699
#
# Reference: mai is traffic se kaise nikal sakta hoon
# Hypothesis: mujhe is traffic ke liye yaad dilaye
# BLEU: 11.3861, WER: 0.7500, CER: 0.5250
#
# Reference: alarm ko reset karen
# Hypothesis: alarm ko reset kare
# BLEU: 59.4604, WER: 0.2500, CER: 0.0500
#
# Reference: Frank ko message karo ki mai ten o ’ clock tak apke ghar par rahunga !
# Hypothesis: Frank ko message karo ki I will be at your place by ten o ’ clock!
# BLEU: 36.8214, WER: 0.6875, CER: 0.5143
#
# Reference: Mere timer par kitna time bacha he ?
# Hypothesis: mere timer par kitna time bacha hai
# BLEU: 53.2946, WER: 0.3750, CER: 0.1111
#
# Reference: yaha se Tampa , Florida tak kitne miles hai
# Hypothesis: here se Tampa, Florida tak kitne miles hai
# BLEU: 86.3340, WER: 0.3333, CER: 0.1163
#
# Reference: Kya New York me thand hogi
# Hypothesis: kya New York me cold hai?
# BLEU: 24.4462, WER: 0.5000, CER: 0.3077
#
# Reference: mile run ke liye mera timer set karen
# Hypothesis: mere mile run ke liye mera timer set kare
# BLEU: 72.5980, WER: 0.2500, CER: 0.1622
#
# Reference: kya kal subha road flooded hogaya tha ?
# Hypothesis: kya aaj subah road ko flood hone wali hai?
# BLEU: 5.5224, WER: 0.8750, CER: 0.4359
#
# Reference: Brad ko message karo aur pucho ke if he has my keys
# Hypothesis: Brad ko message karo aur pucho ki he has my keys
# BLEU: 64.0712, WER: 0.1667, CER: 0.0588
#
# Reference: New York me next weekend par kuch hone wala hai
# Hypothesis: kya agle weekend New York me kya hone wala hai
# BLEU: 27.3012, WER: 0.7000, CER: 0.5319
#
# Reference: kya meri ma ke ghar ke raaste me koi detours hai
# Hypothesis: Kya mere mothers house ke liye road par koi detours hai
# BLEU: 14.9911, WER: 0.7273, CER: 0.5000
#
# Reference: yaha se mujhe Neimen tak pahunchne me kitna samay lagega ?
# Hypothesis: Muje here se Neimen tak pahuchne me kitni der lagegi?
# BLEU: 9.4252, WER: 0.7273, CER: 0.3276
#
# Reference: Kya aaj Texas me koi tornado warning he ?
# Hypothesis: kya aaj Texas mei tornado warnings hai?
# BLEU: 11.5912, WER: 0.6667, CER: 0.1707
#
# Reference: Kya aap Megadeth ke latest album ko baja sakte hai ?
# Hypothesis: kya aap Megadeth ke latest album bajao?
# BLEU: 37.1880, WER: 0.5455, CER: 0.2885
#
# Reference: low tide kab hai ?
# Hypothesis: low tide kab hai?
# BLEU: 100.0000, WER: 0.4000, CER: 0.0556
#
# Reference: Utica , NY se Belleville , Il tak kitni doori hai
# Hypothesis: Utica, NY se Belleville, Il kitni door hai
# BLEU: 61.5629, WER: 0.5455, CER: 0.1429
#
# Reference: Timer countdown please
# Hypothesis: Timer ko countdown kare please
# BLEU: 14.0585, WER: 0.6667, CER: 0.3636
#
# Reference: mujhe TV repair reminder dikhao
# Hypothesis: mujhe TV repair reminder dikhao
# BLEU: 100.0000, WER: 0.0000, CER: 0.0000
#
# Reference: 2018 ke pehle hafte NYC me Activities
# Hypothesis: NYC me first week of 2018 me activities
# BLEU: 12.2231, WER: 1.0000, CER: 0.5946
#
# Reference: Mujhe aaj , kal aur Saturday ke liye weather bataye .
# Hypothesis: mujhe aaj, kal ke liye saturday ke mausam dikhao
# BLEU: 17.7717, WER: 0.8182, CER: 0.5472
#
# Reference: Sydney mei weather kaisa hai ?
# Hypothesis: Sydney me mausam kaisa hai
# BLEU: 19.3577, WER: 0.5000, CER: 0.3000
#
# Reference: Douglasville me Walmart ke liye directions construction ko avoid karte huye
# Hypothesis: Douglasville me Walmart ke directions construction avoid kare
# BLEU: 29.3670, WER: 0.3636, CER: 0.1867
#
# Reference: mujhe kal dopahar 3 bajhe bugs ke liye spray karne ke liye yaad dilaye
# Hypothesis: Muje kal 3 pm ko bugs ke liye yaad dilaye
# BLEU: 24.0849, WER: 0.5714, CER: 0.5000
#
# Reference: aaj ke 15 minutes ke study timer ko postpone kare
# Hypothesis: aaj 15 minutes ke study timer ko postpone kare
# BLEU: 79.5637, WER: 0.1000, CER: 0.0612
#
# Reference: 5 minute ke liye timer set kardo
# Hypothesis: 5 minutes ke liye timer set kare
# BLEU: 43.4721, WER: 0.2857, CER: 0.0938
#
# Reference: mai 8 am ko utna chahta hoon
# Hypothesis: mujhe subah 8 baje ke liye yaad dilaye
# BLEU: 5.5224, WER: 1.0000, CER: 0.9643
#
# Reference: is weekend ke liye Chocolate Tours
# Hypothesis: is weekend ke liye Chocolate tours
# BLEU: 75.9836, WER: 0.1667, CER: 0.0294
#
# Reference: Please mere daily yoga sessions ke liye alert hata den .
# Hypothesis: Please mere daily yoga sessions ke liye alert remove kare
# BLEU: 68.7528, WER: 0.2727, CER: 0.1964
#
# Reference: agar mai rush hour ke samay Pearlridge se H 1 ke zariye airport tak jaaon to mujhe kitna samay lagega
# Hypothesis: agar mai rush hour ke liye mujhe Pearlridge se H 1 par airport pahuchne me kitna time lagega
# BLEU: 33.0404, WER: 0.4500, CER: 0.3267
#
# Reference: Muje dog ko feed karne ke liye remind karaye please
# Hypothesis: please mujhe dog ko feed karne ke liye yaad dilaye
# BLEU: 53.7285, WER: 0.5000, CER: 0.4706
#
# Reference: is weekend ka weather forecast kya hai
# Hypothesis: is weekend ke liye weather forecast kya hai?
# BLEU: 35.4948, WER: 0.4286, CER: 0.1842
#
# Reference: Merideth ko Whatsapp par text karo ki we are bringing the side dishes we just need plates and cups
# Hypothesis: Merideth ko Whatsapp ko text karo ki we are bringing the side dishes we just need plates and cups
# BLEU: 84.9233, WER: 0.0526, CER: 0.0306
#
# Reference: mcallen se alamo tak ke liye directions
# Hypothesis: mcallen se the alamo tak directions
# BLEU: 20.5480, WER: 0.4286, CER: 0.3077
#
# Reference: kis freeway par sabse kam traffic hai
# Hypothesis: kya freeway par sabse traffic hai
# BLEU: 32.1594, WER: 0.2857, CER: 0.1622
#
# Reference: please Pandora ko play karna shuru karo
# Hypothesis: Pandora ko play kare please
# BLEU: 28.6419, WER: 0.5714, CER: 0.4615
#
# Reference: agley haftey haircut karne ke liye reminder set kare
# Hypothesis: agle hafte haircut karne ke liye reminder set kare
# BLEU: 72.5980, WER: 0.2222, CER: 0.0385
#
# Reference: yaha se ghar tak kitna time lagega
# Hypothesis: Aaj ke liye kitni der lagegi
# BLEU: 0.0000, WER: 1.0000, CER: 0.5294
#
# Reference: Please May 9 to 14 ke liye weather search kare ?
# Hypothesis: Please 9 to 14 May ke liye weather ko search kare?
# BLEU: 30.2138, WER: 0.4545, CER: 0.2500
#
# Reference: har Monday 10 : 30 am ko mera alarm repeat kare
# Hypothesis: har Monday subah 10 30 baje mera alarm ko repeat kare
# BLEU: 14.3677, WER: 0.4545, CER: 0.3191
#
# Reference: the Who ke Greatest Hits bajao
# Hypothesis: Who's Greatest Hits play kare
# BLEU: 17.4917, WER: 0.8333, CER: 0.4667
#
# Reference: sedona tak jane ke liye kitni der lagegi
# Hypothesis: sedona tak pahunchne me kitni der lagegi
# BLEU: 26.6473, WER: 0.3750, CER: 0.2250
#
# Reference: Sunday ke liye mere alarms ko dikhao
# Hypothesis: Sunday ke liye mere alarms dikhao
# BLEU: 67.3182, WER: 0.1429, CER: 0.0833
#
# Reference: kal kitni barf padi ?
# Hypothesis: kal kitna snow bacha hai?
# BLEU: 9.6524, WER: 0.8000, CER: 0.5714
#
# Reference: Steffani Howells
# Hypothesis: Steffani Howells
# BLEU: 100.0000, WER: 0.0000, CER: 0.0000
#
# Reference: commute kitna samay lagega ye sambhavna hai
# Hypothesis: commute ke liye kitni der lagegi
# BLEU: 6.8706, WER: 0.8571, CER: 0.6512
#
# === Evaluation Metrics ===
# Average BLEU Score: 40.1975
# Average Word Error Rate: 0.4724
# Average Character Error Rate: 0.2923
# Average Embedding Similarity: 0.0646

# %%
def count_rows_tsv(file_path):
  """Counts the number of rows in a TSV file.

  Args:
    file_path: The path to the TSV file.

  Returns:
    The number of rows in the file, or None if an error occurs.
  """
  try:
    with open(file_path, 'r', encoding='utf-8') as f:
      row_count = 0
      for line in f:
        row_count += 1
      return row_count
  except FileNotFoundError:
    print(f"Error: File not found at {file_path}")
    return None
  except Exception as e:
    print(f"An error occurred: {e}")
    return None

# Example usage:
file_path = '/content/Hinglish-TOP-Dataset/Dataset/Human Annotated Data/train.tsv'  # Replace with your file path
num_rows = count_rows_tsv(file_path)

if num_rows is not None:
  print(f"The file '{file_path}' has {num_rows} rows.")

#Example usage with pandas. If you already have pandas installed, this method is generally faster and more robust.
import pandas as pd

def count_rows_tsv_pandas(file_path):
    """Counts rows in a TSV using pandas."""
    try:
        df = pd.read_csv(file_path, sep='\t', header=None) #header=None if there is no header
        return len(df)
    except FileNotFoundError:
        print(f"Error: File not found at {file_path}")
        return None
    except Exception as e:
        print(f"An error occurred: {e}")
        return None

num_rows_pandas = count_rows_tsv_pandas(file_path)

if num_rows_pandas is not None:
  print(f"The file '{file_path}' has {num_rows_pandas} rows (using pandas).")
# Out:
# The file '/content/Hinglish-TOP-Dataset/Dataset/Human Annotated Data/train.tsv' has 2994 rows.
# The file '/content/Hinglish-TOP-Dataset/Dataset/Human Annotated Data/train.tsv' has 2994 rows (using pandas).

# %%
import matplotlib.pyplot as plt

# Data
epochs = list(range(1, 15))
training_loss = [1.998600, 1.580500, 1.389700, 1.242900, 1.169000, 1.077700, 0.970100, 0.943900, 0.914900, 0.894800,
                 0.830100, 0.837800, 0.805000, 0.823100]
validation_loss = [1.619507, 1.331256, 1.195374, 1.095705, 1.031489, 0.992077, 0.966935, 0.942918, 0.917708, 0.913071,
                   0.905118, 0.897494, 0.892284, 0.889529]

# Plot
plt.figure(figsize=(10, 5))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss Over Epochs')
plt.legend()
plt.grid()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
from collections import defaultdict

# Read the text file (ensure the file 't5_small_metric_eval.txt' is in your working directory)
with open('/content/t5_large_metric_eval.txt', 'r', encoding='utf-8') as f:
    data = f.read()

# Each block is assumed to be separated by a blank line
blocks = data.strip().split('\n\n')

rows = []
for block in blocks:
    lines = block.strip().splitlines()
    if len(lines) >= 3:
        # Extract the Reference, Hypothesis, and metric line
        ref_line = lines[0]
        hyp_line = lines[1]
        metric_line = lines[2]
        # Remove the prefix 'Reference:' and 'Hypothesis:'
        ref = re.sub(r'^Reference:\s*', '', ref_line).strip()
        hyp = re.sub(r'^Hypothesis:\s*', '', hyp_line).strip()
        # Use regex to extract BLEU, WER, CER from the metric line
        m = re.findall(r'BLEU:\s*([\d\.]+),\s*WER:\s*([\d\.]+),\s*CER:\s*([\d\.]+)', metric_line)
        if m:
            bleu, wer, cer = map(float, m[0])
        else:
            continue
        rows.append({'Reference': ref, 'Hypothesis': hyp, 'BLEU': bleu, 'WER': wer, 'CER': cer})

# Create a DataFrame from the extracted data
df = pd.DataFrame(rows)

# Tokenize the Reference text into words (convert to lowercase and split on whitespace)
df['ref_tokens'] = df['Reference'].str.lower().str.split()

# Create a dictionary to accumulate metrics for each word appearing in the Reference
word_metrics = defaultdict(lambda: {'wer': [], 'bleu': [], 'cer': [], 'count': 0})

# For each row, add the metric values for each word in the Reference text.
# Here, we count every occurrence. You can modify this if you prefer to use a set.
for _, row in df.iterrows():
    for word in row['ref_tokens']:
        word_metrics[word]['wer'].append(row['WER'])
        word_metrics[word]['bleu'].append(row['BLEU'])
        word_metrics[word]['cer'].append(row['CER'])
        word_metrics[word]['count'] += 1

# Build a DataFrame with average metrics per word
words = []
avg_wer = []
avg_bleu = []
avg_cer = []
counts = []

for word, metrics in word_metrics.items():
    words.append(word)
    avg_wer.append(sum(metrics['wer']) / len(metrics['wer']))
    avg_bleu.append(sum(metrics['bleu']) / len(metrics['bleu']))
    avg_cer.append(sum(metrics['cer']) / len(metrics['cer']))
    counts.append(metrics['count'])

metrics_df = pd.DataFrame({
    'word': words,
    'avg_WER': avg_wer,
    'avg_BLEU': avg_bleu,
    'avg_CER': avg_cer,
    'count': counts
})

# Filter out words that do not appear frequently (set threshold to 5 occurrences)
filtered_df = metrics_df[metrics_df['count'] >= 5].copy()

# Set a Seaborn style for better aesthetics
sns.set(style="whitegrid", font_scale=1.1)

# Visualization 1: Top 20 words associated with high WER
top_wer = filtered_df.sort_values('avg_WER', ascending=False).head(20)
plt.figure(figsize=(12, 6))
sns.barplot(x='avg_WER', y='word', data=top_wer, palette='viridis')
plt.title('Top 20 words associated with high WER (from Reference)')
plt.xlabel('Average WER')
plt.ylabel('Word')
plt.tight_layout()
plt.show()

# Visualization 2: Top 20 words associated with high CER
top_cer = filtered_df.sort_values('avg_CER', ascending=False).head(20)
plt.figure(figsize=(12, 6))
sns.barplot(x='avg_CER', y='word', data=top_cer, palette='rocket')
plt.title('Top 20 words associated with high CER (from Reference)')
plt.xlabel('Average CER')
plt.ylabel('Word')
plt.tight_layout()
plt.show()

# Visualization 3: Top 20 words associated with low BLEU (lower BLEU implies worse quality)
top_low_bleu = filtered_df.sort_values('avg_BLEU', ascending=True).head(20)
plt.figure(figsize=(12, 6))
sns.barplot(x='avg_BLEU', y='word', data=top_low_bleu, palette='mako')
plt.title('Top 20 words associated with low BLEU (from Reference)')
plt.xlabel('Average BLEU')
plt.ylabel('Word')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-10-7516c5cbaa5c>:82: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='avg_WER', y='word', data=top_wer, palette='viridis')
# <ipython-input-10-7516c5cbaa5c>:92: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='avg_CER', y='word', data=top_cer, palette='rocket')
# <ipython-input-10-7516c5cbaa5c>:102: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='avg_BLEU', y='word', data=top_low_bleu, palette='mako')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a bubble chart using the filtered DataFrame (filtered_df from previous code)
plt.figure(figsize=(12, 8))
scatter = plt.scatter(
    filtered_df['avg_WER'],
    filtered_df['avg_BLEU'],
    s=filtered_df['count'] * 10,  # adjust multiplier for better bubble sizes
    c=filtered_df['avg_CER'],
    cmap='viridis',
    alpha=0.7,
    edgecolor='k'
)
plt.xlabel('Average WER')
plt.ylabel('Average BLEU')
plt.title('Bubble Chart: Average WER vs Average BLEU (Bubble Size = Frequency, Color = Avg CER)')
cbar = plt.colorbar(scatter)
cbar.set_label('Average CER')

# Annotate a few high-frequency words for illustration purposes
for _, row in filtered_df.iterrows():
    if row['count'] > 20:  # annotate words that appear very frequently
        plt.annotate(row['word'], (row['avg_WER'], row['avg_BLEU']), fontsize=9, alpha=0.9)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objs as go
from plotly.subplots import make_subplots
from scipy import stats
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Read the data
def parse_metrics_file(file_path):
    metrics = []
    with open(file_path, 'r', encoding='utf-8') as file:
        current_entry = {}
        for line in file:
            line = line.strip()
            if line.startswith('Reference:'):
                current_entry['reference'] = line.replace('Reference: ', '')
            elif line.startswith('Hypothesis:'):
                current_entry['hypothesis'] = line.replace('Hypothesis: ', '')
            elif line.startswith('BLEU:'):
                # Extract numeric values
                bleu = float(line.split('BLEU:')[1].split(',')[0].strip())
                wer = float(line.split('WER:')[1].split(',')[0].strip())
                cer = float(line.split('CER:')[1].strip())

                current_entry['bleu'] = bleu
                current_entry['wer'] = wer
                current_entry['cer'] = cer

                metrics.append(current_entry)
                current_entry = {}

    return pd.DataFrame(metrics)

# Load the data (replace with your file path)
df = parse_metrics_file('/content/t5_large_metric_eval.txt')

# 1. Interactive Correlation Heatmap
def create_correlation_heatmap(df):
    correlation_matrix = df[['bleu', 'wer', 'cer']].corr()

    fig = px.imshow(correlation_matrix,
                    labels=dict(x="Metrics", y="Metrics", color="Correlation"),
                    x=['BLEU', 'WER', 'CER'],
                    y=['BLEU', 'WER', 'CER'],
                    color_continuous_scale='RdBu_r',
                    title='Correlation Between NLP Metrics')
    fig.show()
    return fig

# 2. Distribution of Metrics
def create_metrics_distribution(df):
    fig = make_subplots(rows=1, cols=3,
                        subplot_titles=('BLEU Score Distribution',
                                        'WER Distribution',
                                        'CER Distribution'))

    for i, metric in enumerate(['bleu', 'wer', 'cer'], 1):
        fig.add_trace(
            go.Histogram(x=df[metric], name=metric.upper()),
            row=1, col=i
        )

    fig.update_layout(title_text="Distribution of NLP Metrics")
    fig.show()
    return fig

# 3. Length Impact Analysis
def create_length_impact_analysis(df):
    df['ref_length'] = df['reference'].str.len()
    df['hyp_length'] = df['hypothesis'].str.len()

    fig = make_subplots(rows=1, cols=3,
                        subplot_titles=('Reference Length vs BLEU',
                                        'Reference Length vs WER',
                                        'Reference Length vs CER'))

    # BLEU vs Length
    fig.add_trace(
        go.Scatter(x=df['ref_length'], y=df['bleu'], mode='markers',
                   name='BLEU', marker=dict(color='blue', opacity=0.6)),
        row=1, col=1
    )

    # WER vs Length
    fig.add_trace(
        go.Scatter(x=df['ref_length'], y=df['wer'], mode='markers',
                   name='WER', marker=dict(color='red', opacity=0.6)),
        row=1, col=2
    )

    # CER vs Length
    fig.add_trace(
        go.Scatter(x=df['ref_length'], y=df['cer'], mode='markers',
                   name='CER', marker=dict(color='green', opacity=0.6)),
        row=1, col=3
    )

    fig.update_layout(title_text="Impact of Reference Length on Metrics")
    fig.update_xaxes(title_text="Reference Length")
    fig.update_yaxes(title_text="Metric Value")

    fig.show()
    return fig

# 4. Word Frequency Analysis
def create_word_frequency_analysis(df):
    import re
    from collections import Counter

    def extract_words(text):
        return re.findall(r'\b\w+\b', text.lower())

    # Collect words from references and hypotheses
    ref_words = [word for text in df['reference'] for word in extract_words(text)]
    hyp_words = [word for text in df['hypothesis'] for word in extract_words(text)]

    # Top 20 most frequent words
    ref_word_freq = Counter(ref_words).most_common(20)
    hyp_word_freq = Counter(hyp_words).most_common(20)

    # Create subplots for word frequencies
    fig = make_subplots(rows=1, cols=2,
                        subplot_titles=('Top Words in References',
                                        'Top Words in Hypotheses'))

    # References word frequency
    fig.add_trace(
        go.Bar(x=[word[0] for word in ref_word_freq],
               y=[word[1] for word in ref_word_freq],
               name='Reference Words'),
        row=1, col=1
    )

    # Hypotheses word frequency
    fig.add_trace(
        go.Bar(x=[word[0] for word in hyp_word_freq],
               y=[word[1] for word in hyp_word_freq],
               name='Hypothesis Words'),
        row=1, col=2
    )

    fig.update_layout(title_text="Word Frequency Analysis")
    fig.show()
    return fig

# 5. Advanced Scatter Plot
def create_advanced_scatter(df):
    fig = px.scatter(df, x='wer', y='bleu', color='cer',
                     title='WER vs BLEU Colored by CER',
                     labels={'wer': 'Word Error Rate',
                             'bleu': 'BLEU Score',
                             'cer': 'Character Error Rate'},
                     color_continuous_scale='viridis')
    fig.show()
    return fig

# 6. PCA Visualization
def create_pca_visualization(df):
    # Feature Engineering
    df['ref_unique_words'] = df['reference'].apply(lambda x: len(set(x.split())))
    df['hyp_unique_words'] = df['hypothesis'].apply(lambda x: len(set(x.split())))
    df['ref_word_diversity'] = df['ref_unique_words'] / df['reference'].apply(lambda x: len(x.split()))
    df['hyp_word_diversity'] = df['hyp_unique_words'] / df['hypothesis'].apply(lambda x: len(x.split()))

    # Prepare data for PCA
    features_for_pca = ['bleu', 'wer', 'cer', 'ref_unique_words', 'hyp_unique_words',
                        'ref_word_diversity', 'hyp_word_diversity']

    # Standardize features
    scaler = StandardScaler()
    scaled_features = scaler.fit_transform(df[features_for_pca])

    # PCA
    pca = PCA(n_components=2)
    pca_result = pca.fit_transform(scaled_features)

    # Create DataFrame for plotting
    pca_df = pd.DataFrame(data=pca_result, columns=['PC1', 'PC2'])
    pca_df['BLEU'] = df['bleu']

    # Interactive PCA plot
    fig = px.scatter(pca_df, x='PC1', y='PC2', color='BLEU',
                     title='PCA of NLP Metrics',
                     labels={'PC1': 'First Principal Component',
                             'PC2': 'Second Principal Component'},
                     color_continuous_scale='viridis')

    # Add variance explained annotation
    variance_explained = pca.explained_variance_ratio_
    fig.add_annotation(
        text=f'Variance Explained:<br>PC1: {variance_explained[0]*100:.2f}%<br>PC2: {variance_explained[1]*100:.2f}%',
        xref='paper', yref='paper',
        x=0.05, y=0.95,
        showarrow=False
    )

    fig.show()
    return fig

# Execute all visualizations
print("1. Correlation Heatmap")
create_correlation_heatmap(df)

print("\n2. Metrics Distribution")
create_metrics_distribution(df)

print("\n3. Length Impact Analysis")
create_length_impact_analysis(df)

print("\n4. Word Frequency Analysis")
create_word_frequency_analysis(df)

print("\n5. Advanced Scatter Plot")
create_advanced_scatter(df)

print("\n6. PCA Visualization")
create_pca_visualization(df)

# Print Descriptive Statistics
print("\nDescriptive Statistics:")
print(df[['bleu', 'wer', 'cer']].describe())

# Correlation Analysis
print("\nCorrelation Analysis:")
print(df[['bleu', 'wer', 'cer']].corr())
# Out:
# 1. Correlation Heatmap
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="60e9e452-b4d1-45c3-b94c-eea91340f9c9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("60e9e452-b4d1-45c3-b94c-eea91340f9c9")) {                    Plotly.newPlot(                        "60e9e452-b4d1-45c3-b94c-eea91340f9c9",                        [{"coloraxis":"coloraxis","name":"0","x":["BLEU","WER","CER"],"y":["BLEU","WER","CER"],"z":[[1.0,-0.8307711235662224,-0.7662837714993396],[-0.8307711235662224,1.0,0.9010526118045848],[-0.7662837714993396,0.9010526118045848,1.0]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"Metrics: %{x}\u003cbr\u003eMetrics: %{y}\u003cbr\u003eCorrelation: %{z}\u003cextra\u003e\u003c\u002fextra\u003e"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar": ...
# 2. Metrics Distribution
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f6c72478-4237-4aa9-8369-d81e1dfb6737" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f6c72478-4237-4aa9-8369-d81e1dfb6737")) {                    Plotly.newPlot(                        "f6c72478-4237-4aa9-8369-d81e1dfb6737",                        [{"name":"BLEU","x":[46.5954,29.3772,14.7596,16.5158,81.8731,66.874,49.7609,35.4542,86.334,15.2072,14.5752,30.2138,54.5247,30.5098,62.207,100.0,9.8647,8.643,3.4815,24.6898,19.3313,52.4736,66.9048,47.2871,47.0277,100.0,10.1753,51.1508,32.6683,59.5933,100.0,65.4891,100.0,8.5153,33.0316,100.0,49.6264,65.5228,14.5358,17.695,66.0633,66.874,7.8098,54.1082,38.5032,19.3049,22.3617,49.7357,19.7406,39.2815,23.8752,3.0098,100.0,9.0836,34.5721,100.0,54.7518,8.9534,19.3049,13.4928,61.9676,64.3459,32.5556,100.0,20.6124,35.4948,26.2691,75.9836,43.4721,100.0,42.7287,33.7646,48.8716,34.9833,100.0,28.6419,76.2626,10.6822,74.4782,100.0,10.7868,49.1953,33.5387,60.1053,12.7033,30.3265,18.9959,13.9587,76.1161,14.7596,21.6491,26.7261,67.3182,100.0,44.9641,14.5358,22.9348,32.2601,10.6822,24.8805,10.2292,30.7394,42.1181,8.5153,43.0125,24.1772,26.6543,37.685,5.6042,66.874,19.1569,14.5358,28.3619,75.9836,54.91,36.2824,61.4788,61.4788,66.874,17.286,47.7503,36.8894,14.2588,54.1082,28.6419,52.5382,75.9836,7.7686,50.8133,87.024,59.5417,64.3187,68.0375,9.8375,92.5961,15.2072,61.4788,43.4721,9.3451,38.7392,53.7285,32.5556,19.675,59.4604,61.2611,43.2982,38.5032,32.1594,47.7584,24.8408,55.78,7.7155,38.4302,15.2072,26.6543,22.6136,46.3078,100.0,19.0387,16.6823,47.2871,27.5161,11.7266,32.6683,100.0,27.5161,45.7231,39.4322,100.0,32.4668,4.8319,10.4006,46.3078,26.2959,20.8727,100.0,20.1649,19.8818,100.0,30.8958,100.0,59.2065,19.6407,20.6124,17.4917,17.2034,54.7518,29.0607,48.327,39.7635,100.0,15.7278,30.1815,6.5673,8.5492,61.6261,47.0852,100.0,22.3162,32.4668,42.7287,34.6863,16.2617,11.6972,100.0,14.5358,7.8098,13.6744,53.7285,100.0,13.1345,100.0,20.7728,54.1082,38.3867,23.7368,78.8193,27.4825,11.3861,17.4917,14.794],"type":"histogram","xaxis":"x","yaxis":"y"},{"name":"WER","x":[0.1667,0.3636,0.4444,0.75,0.1667,0.2,0.2,0.5,0.1111,0.5714,0.5556,0.5,0.3333,0.3333,0.2143,0.0,0.8889,0.7143,1.0,0.9333,0.6364,0.4444,0.1,0.5714,0.3333,0.0,0.7,0.1429,0.4444,0.3333,0.0,0.5,0.3333,0.8571,0.3333,0.0,0.2222,0.1667,0.7143,0.6471,0.2,0.2,0.8571,0.375,0.2667,0.5,0.625,0.2308,0.5556,0.5,0.3333,1.0,0.2857,1.0769,0.25,0.0,0.3333,0.8571,0.3333,0.6,0.3333,0.1429,0.5,0.0,0.7778,0.375,0.6,0.2222,0.4286,0.0,0.2,0.3333,0.3571,0.3333,0.0,0.4286,0.1538,0.8,0.1333,0.0,0.6667,0.3846,0.3158,0.3636,1.0,0.6667,0.6667,0.5556,0.0769,0.6667,0.625,0.6,0.4286,0.0,0.3333,0.5714,0.72,0.4444,0.8,0.6,0.7,0.5714,0.3846,0.8571,0.1429,0.5556,0.5714,0.375,1.25,0.2,0.3636,0.8571,0.52,0.1667,0.3333,0.3333,0.2857,0.2857,0.2,0.4286,0.5556,0.625,0.625,0.25,0.4286,0.4444,0.1667,0.8462,0.3333,0.2353,0.1818,0.2857,0.25,1.2222,0.0714,0.8571,0.3333,0.2857,0.8462,0.8,0.1667,0.8333,0.6923,0.125,0.3077,0.5,0.6,0.2857,0.4667,0.5,0.25,0.75,0.4286,0.8571,0.5714,0.75,0.4,0.0,0.6,0.5714,0.5714,0.6667,0.6316,0.5556,0.0,0.6667,0.6429,0.5,0.0,0.3333,0.8125,0.6667,0.4,0.6364,0.7083,0.4,0.5556,0.375,0.5,0.3333,0.0,0.3333,0.5714,0.6667,0.75,0.6,0.3333,0.3333,0.5,0.4,0.0,0.9091,0.4286,0.8571,0.7857,0.2143,0.1667,0.3333,0.4444,0.5,0.2857,0.4615,0.7,0.6471,0.0,0.8,1.0,0.8182,0.1667,0.0,0.625,0.0,0.7273,0.375,0.3846,0.7,0.2143,0.5714,0.75,0.5,0.6],"type":"histogram","xaxis":"x2","yaxis":"y2"},{"name":"CER","x":[0.0758,0.1887,0.3333,0.5238,0.0714,0.0357,0.1111,0.3516,0.0488,0.4839,0.2955,0.4,0.3333,0.1957,0.1091,0.0,0.7556,0.4,0.6582,0.6622,0.537,0.2,0.0465,0.225,0.1209,0.0,0.4565,0.1818,0.2727,0.321,0.0,0.2553,0.0323,0.7273,0.0833,0.0,0.2381,0.1333,0.5,0.2442,0.102,0.0312,0.6364,0.08 ...
# 3. Length Impact Analysis
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="03fb3481-3ff4-465c-89fb-d821f01c46fe" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("03fb3481-3ff4-465c-89fb-d821f01c46fe")) {                    Plotly.newPlot(                        "03fb3481-3ff4-465c-89fb-d821f01c46fe",                        [{"marker":{"color":"blue","opacity":0.6},"mode":"markers","name":"BLEU","x":[66,53,39,42,28,28,27,91,41,31,44,30,51,46,55,22,45,35,79,74,54,50,43,40,91,31,46,44,44,81,35,47,31,33,48,24,42,60,38,86,49,32,33,36,80,38,91,65,40,52,44,96,32,67,40,37,38,70,32,41,67,33,28,51,49,45,42,35,29,18,27,50,62,31,30,39,68,24,83,37,40,66,95,52,15,15,16,48,69,48,36,82,29,55,70,36,128,43,28,25,55,32,67,28,39,44,30,43,50,29,47,30,125,29,65,48,29,37,25,36,40,46,40,36,33,40,30,68,30,67,53,35,44,52,54,34,25,32,69,70,30,25,66,43,60,38,77,33,68,22,44,44,98,31,41,53,24,21,51,99,37,11,100,47,35,21,72,20,19,30,82,30,22,51,96,29,36,39,18,48,39,46,38,48,59,48,30,60,56,26,29,57,28,31,74,69,62,32,49,31,33,65,63,91,49,34,22,52,30,18,41,50,62,36,68,41,73,28,47,57,26],"y":[46.5954,29.3772,14.7596,16.5158,81.8731,66.874,49.7609,35.4542,86.334,15.2072,14.5752,30.2138,54.5247,30.5098,62.207,100.0,9.8647,8.643,3.4815,24.6898,19.3313,52.4736,66.9048,47.2871,47.0277,100.0,10.1753,51.1508,32.6683,59.5933,100.0,65.4891,100.0,8.5153,33.0316,100.0,49.6264,65.5228,14.5358,17.695,66.0633,66.874,7.8098,54.1082,38.5032,19.3049,22.3617,49.7357,19.7406,39.2815,23.8752,3.0098,100.0,9.0836,34.5721,100.0,54.7518,8.9534,19.3049,13.4928,61.9676,64.3459,32.5556,100.0,20.6124,35.4948,26.2691,75.9836,43.4721,100.0,42.7287,33.7646,48.8716,34.9833,100.0,28.6419,76.2626,10.6822,74.4782,100.0,10.7868,49.1953,33.5387,60.1053,12.7033,30.3265,18.9959,13.9587,76.1161,14.7596,21.6491,26.7261,67.3182,100.0,44.9641,14.5358,22.9348,32.2601,10.6822,24.8805,10.2292,30.7394,42.1181,8.5153,43.0125,24.1772,26.6543,37.685,5.6042,66.874,19.1569,14.5358,28.3619,75.9836,54.91,36.2824,61.4788,61.4788,66.874,17.286,47.7503,36.8894,14.2588,54.1082,28.6419,52.5382,75.9836,7.7686,50.8133,87.024,59.5417,64.3187,68.0375,9.8375,92.5961,15.2072,61.4788,43.4721,9.3451,38.7392,53.7285,32.5556,19.675,59.4604,61.2611,43.2982,38.5032,32.1594,47.7584,24.8408,55.78,7.7155,38.4302,15.2072,26.6543,22.6136,46.3078,100.0,19.0387,16.6823,47.2871,27.5161,11.7266,32.6683,100.0,27.5161,45.7231,39.4322,100.0,32.4668,4.8319,10.4006,46.3078,26.2959,20.8727,100.0,20.1649,19.8818,100.0,30.8958,100.0,59.2065,19.6407,20.6124,17.4917,17.2034,54.7518,29.0607,48.327,39.7635,100.0,15.7278,30.1815,6.5673,8.5492,61.6261,47.0852,100.0,22.3162,32.4668,42.7287,34.6863,16.2617,11.6972,100.0,14.5358,7.8098,13.6744,53.7285,100.0,13.1345,100.0,20.7728,54.1082,38.3867,23.7368,78.8193,27.4825,11.3861,17.4917,14.794],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"red","opacity":0.6},"mode":"markers","name":"WER","x":[66,53,39,42,28,28,27,91,41,31,44,30,51,46,55,22,45,35,79,74,54,50,43,40,91,31,46,44,44,81,35,47,31,33,48,24,42,60,38,86,49,32,33,36,80,38,91,65,40,52,44,96,32,67,40,37,38,70,32,41,67,33,28,51,49,45,42,35,29,18,27,50,62,31,30,39,68,24,83,37,40,66,95,52,15,15,16,48,69,48,36,82,29,55,70,36,128,43,28,25,55,32,67,28,39,44,30,43,50,29,47,30,125,29,65,48,29,37,25,36,40,46,40,36,33,40,30,68,30,67,53,35,44,52,54,34,25,32,69,70,30,25,66,43,60,38,77,33,68,22,44,44,98,31,41,53,24,21,51,99,37,11,100,47,35,21,72,20,19,30,82,30,22,51,96,29,36,39,18,48,39,46,38,48,59,48,30,60,56,26,29,57,28,31,74,69,62,32,49,31,33,65,63,91,49,34,22,52,30,18,41,50,62,36,68,41,73,28,47,57,26],"y":[0.1667,0.3636,0.4444,0.75,0.1667,0.2,0.2,0.5,0.1111,0.5714,0.5556,0.5,0.3333,0.3333,0.2143,0.0,0.8889,0.7143,1.0,0.9333,0.6364,0.4444,0.1,0.5714,0.3333,0.0,0.7,0.1429,0.4444,0.3333,0.0,0.5,0.3333,0.8571,0.3333,0 ...
# 4. Word Frequency Analysis
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="843b50d9-f503-4cff-8454-3b97cec13dcb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("843b50d9-f503-4cff-8454-3b97cec13dcb")) {                    Plotly.newPlot(                        "843b50d9-f503-4cff-8454-3b97cec13dcb",                        [{"name":"Reference Words","x":["ke","liye","hai","kya","me","ko","mujhe","kare","alarm","mere","se","set","is","tak","aaj","par","kitna","mai","yaad","ek"],"y":[108,75,63,54,53,53,38,29,28,27,25,24,23,19,19,19,16,16,15,15],"type":"bar","xaxis":"x","yaxis":"y"},{"name":"Hypothesis Words","x":["ke","liye","hai","kya","ko","kare","mujhe","me","alarm","mere","set","is","yaad","dilaye","karne","par","aaj","am","pm","kaisa"],"y":[111,91,83,60,59,49,47,39,29,27,24,21,19,18,18,18,17,16,14,14],"type":"bar","xaxis":"x2","yaxis":"y2"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5}, ...
# 5. Advanced Scatter Plot
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="db1b705a-5cb8-4d77-9717-53867a4e806c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("db1b705a-5cb8-4d77-9717-53867a4e806c")) {                    Plotly.newPlot(                        "db1b705a-5cb8-4d77-9717-53867a4e806c",                        [{"hovertemplate":"Word Error Rate=%{x}\u003cbr\u003eBLEU Score=%{y}\u003cbr\u003eCharacter Error Rate=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[0.0758,0.1887,0.3333,0.5238,0.0714,0.0357,0.1111,0.3516,0.0488,0.4839,0.2955,0.4,0.3333,0.1957,0.1091,0.0,0.7556,0.4,0.6582,0.6622,0.537,0.2,0.0465,0.225,0.1209,0.0,0.4565,0.1818,0.2727,0.321,0.0,0.2553,0.0323,0.7273,0.0833,0.0,0.2381,0.1333,0.5,0.2442,0.102,0.0312,0.6364,0.0833,0.125,0.5526,0.4835,0.1538,0.25,0.3654,0.3182,0.6979,0.0312,0.9104,0.05,0.0,0.1842,0.6,0.1562,0.3171,0.194,0.1818,0.2143,0.0,0.4898,0.2222,0.4048,0.1714,0.1034,0.0,0.1111,0.22,0.2097,0.1613,0.0,0.2564,0.1471,0.3333,0.0361,0.0,0.3,0.1667,0.1684,0.3269,0.6,0.3333,0.25,0.2917,0.0435,0.3125,0.3611,0.3049,0.1379,0.0,0.2286,0.25,0.5,0.2558,0.75,0.32,0.4909,0.25,0.2239,0.6071,0.1282,0.3864,0.3333,0.186,0.78,0.069,0.1489,0.3333,0.24,0.1379,0.1846,0.2292,0.1379,0.2162,0.08,0.3056,0.325,0.5217,0.35,0.1944,0.303,0.2,0.0333,0.6324,0.2333,0.0448,0.0566,0.2571,0.0682,0.8846,0.037,0.6765,0.24,0.0938,0.7246,0.4571,0.0667,0.64,0.4545,0.0233,0.3333,0.2895,0.5455,0.2121,0.3676,0.1364,0.0909,0.4091,0.3469,0.3871,0.4146,0.5472,0.2917,0.0,0.4706,0.4545,0.2432,0.5455,0.3,0.2766,0.0,0.4286,0.5139,0.35,0.0,0.3,0.622,0.2667,0.1818,0.4706,0.6667,0.0345,0.3333,0.2564,0.0556,0.125,0.0,0.1522,0.3421,0.4375,0.6102,0.3542,0.1667,0.2167,0.3929,0.0769,0.0,0.6842,0.3571,0.5806,0.5,0.1159,0.0806,0.0312,0.2857,0.3548,0.303,0.2308,0.4603,0.2418,0.0,0.5882,0.6818,0.4231,0.0333,0.0,0.2683,0.0,0.5484,0.0833,0.1176,0.4634,0.0548,0.25,0.2979,0.2632,0.3077],"coloraxis":"coloraxis","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[0.1667,0.3636,0.4444,0.75,0.1667,0.2,0.2,0.5,0.1111,0.5714,0.5556,0.5,0.3333,0.3333,0.2143,0.0,0.8889,0.7143,1.0,0.9333,0.6364,0.4444,0.1,0.5714,0.3333,0.0,0.7,0.1429,0.4444,0.3333,0.0,0.5,0.3333,0.8571,0.3333,0.0,0.2222,0.1667,0.7143,0.6471,0.2,0.2,0.8571,0.375,0.2667,0.5,0.625,0.2308,0.5556,0.5,0.3333,1.0,0.2857,1.0769,0.25,0.0,0.3333,0.8571,0.3333,0.6,0.3333,0.1429,0.5,0.0,0.7778,0.375,0.6,0.2222,0.4286,0.0,0.2,0.3333,0.3571,0.3333,0.0,0.4286,0.1538,0.8,0.1333,0.0,0.6667,0.3846,0.3158,0.3636,1.0,0.6667,0.6667,0.5556,0.0769,0.6667,0.625,0.6,0.4286,0.0,0.3333,0.5714,0.72,0.4444,0.8,0.6,0.7,0.5714,0.3846,0.8571,0.1429,0.5556,0.5714,0.375,1.25,0.2,0.3636,0.8571,0.52,0.1667,0.3333,0.3333,0.2857,0.2857,0.2,0.4286,0.5556,0.625,0.625,0.25,0.4286,0.4444,0.1667,0.8462,0.3333,0.2353,0.1818,0.2857,0.25,1.2222,0.0714,0.8571,0.3333,0.2857,0.8462,0.8,0.1667,0.8333,0.6923,0.125,0.3077,0.5,0.6,0.2857,0.4667,0.5,0.25,0.75,0.4286,0.8571,0.5714,0.75,0.4,0.0,0.6,0.5714,0.5714,0.6667,0.6316,0.5556,0.0,0.6667,0.6429,0.5,0.0,0.3333,0.8125,0.6667,0.4,0.6364,0.7083,0.4,0.5556,0.375,0.5,0.3333,0.0,0.3333,0.5714,0.6667,0.75,0.6,0.3333,0.3333,0.5,0.4,0.0,0.9091,0.4286,0.8571,0.7857,0.2143,0.1667,0.3333,0.4444,0.5,0.2857,0.4615,0.7,0.6471,0.0,0.8,1.0,0.8182,0.1667,0.0,0.625,0.0,0.7273,0.375,0.3846,0.7,0.2143,0.5714,0.75,0.5,0.6],"xaxis":"x","y":[46.5954,29.3772,14.7596,16.5158,81.8731,66.874,49.7609,35.4542,86.334,15.2072,14.5752,30.2138,54.5247,30.5098,62.207,100.0,9.8647,8.643,3.4815,24.6898,19.3313,52.4736,66.9048,47.2871,47.0277,100.0,10.1753,51.1508,32.6683,59.5933,100.0,65.4891,100.0,8.5153,33.0316,100.0,49.6264,65.5228,14.5358,17.695,66.0633,66.874,7.8098,54.1082,38.5032,19.3049,22.3617,49.7357,19.7406,39.28 ...
# 6. PCA Visualization
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e5e28264-77a3-45fa-aa19-42ce3ed298b1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e5e28264-77a3-45fa-aa19-42ce3ed298b1")) {                    Plotly.newPlot(                        "e5e28264-77a3-45fa-aa19-42ce3ed298b1",                        [{"hovertemplate":"First Principal Component=%{x}\u003cbr\u003eSecond Principal Component=%{y}\u003cbr\u003eBLEU=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[46.5954,29.3772,14.7596,16.5158,81.8731,66.874,49.7609,35.4542,86.334,15.2072,14.5752,30.2138,54.5247,30.5098,62.207,100.0,9.8647,8.643,3.4815,24.6898,19.3313,52.4736,66.9048,47.2871,47.0277,100.0,10.1753,51.1508,32.6683,59.5933,100.0,65.4891,100.0,8.5153,33.0316,100.0,49.6264,65.5228,14.5358,17.695,66.0633,66.874,7.8098,54.1082,38.5032,19.3049,22.3617,49.7357,19.7406,39.2815,23.8752,3.0098,100.0,9.0836,34.5721,100.0,54.7518,8.9534,19.3049,13.4928,61.9676,64.3459,32.5556,100.0,20.6124,35.4948,26.2691,75.9836,43.4721,100.0,42.7287,33.7646,48.8716,34.9833,100.0,28.6419,76.2626,10.6822,74.4782,100.0,10.7868,49.1953,33.5387,60.1053,12.7033,30.3265,18.9959,13.9587,76.1161,14.7596,21.6491,26.7261,67.3182,100.0,44.9641,14.5358,22.9348,32.2601,10.6822,24.8805,10.2292,30.7394,42.1181,8.5153,43.0125,24.1772,26.6543,37.685,5.6042,66.874,19.1569,14.5358,28.3619,75.9836,54.91,36.2824,61.4788,61.4788,66.874,17.286,47.7503,36.8894,14.2588,54.1082,28.6419,52.5382,75.9836,7.7686,50.8133,87.024,59.5417,64.3187,68.0375,9.8375,92.5961,15.2072,61.4788,43.4721,9.3451,38.7392,53.7285,32.5556,19.675,59.4604,61.2611,43.2982,38.5032,32.1594,47.7584,24.8408,55.78,7.7155,38.4302,15.2072,26.6543,22.6136,46.3078,100.0,19.0387,16.6823,47.2871,27.5161,11.7266,32.6683,100.0,27.5161,45.7231,39.4322,100.0,32.4668,4.8319,10.4006,46.3078,26.2959,20.8727,100.0,20.1649,19.8818,100.0,30.8958,100.0,59.2065,19.6407,20.6124,17.4917,17.2034,54.7518,29.0607,48.327,39.7635,100.0,15.7278,30.1815,6.5673,8.5492,61.6261,47.0852,100.0,22.3162,32.4668,42.7287,34.6863,16.2617,11.6972,100.0,14.5358,7.8098,13.6744,53.7285,100.0,13.1345,100.0,20.7728,54.1082,38.3867,23.7368,78.8193,27.4825,11.3861,17.4917,14.794],"coloraxis":"coloraxis","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[-0.5655226907213328,-0.007181647167869939,0.1971842655922435,1.118066760674613,-2.35468920993215,-2.2466744820035998,-1.9141822988901744,1.546449803136063,-0.6906472862596467,0.459059658303033,0.39839191444638117,-0.17205482254723342,0.07986956210730914,-0.4420594966192495,-0.45819426276117614,-3.3561601208757166,2.362351867893551,0.6085686062343415,4.334374933203787,2.663287295398583,1.3913512255858969,-0.6753520015698472,-1.5311454585344104,-0.6124469484494665,1.5047317529365,-2.9734784804137737,0.9716998693515784,-1.4884448219059312,-0.2110378698898648,1.560569651836876,-2.9734784804137737,-0.559659859900428,-2.4377202238404836,1.4939067904952255,-0.6374264416575005,-3.164819300644745,-0.8220745930780065,-0.8190688286721329,0.8428684880156635,2.204614515873712,-1.1276526647867402,-2.2568586358405613,1.4932294660917658,-1.1749326229001233,0.5074851684692653,0.33842401490244994,1.9675950959176836,1.0112203435636735,0.12005070268592802,0.3777501404631565,-0.0643993922102484,4.234393784027664,-2.328822088576871,5.050889287418087,-1.0673659649294092,-2.590796839951831,-1.409047828477333,2.538562823082383,-0.8386910378213269,1.3414079134077543,-0.3480462384910549,-1.5909909347768971,-0.7249495058433503,-2.3994560197208594,1.1199658316654224,0.19815265343903524,1.3464969393526187,-1.177619104728377,-1.0697592394928868,-3.3561601208757166,-1.710557328565189,-0.4363314356863388,1.3984628767687386,-1.161647411413264 ...
# Descriptive Statistics:
#              bleu         wer         cer
# count  221.000000  221.000000  221.000000
# mean    41.867173    0.454767    0.278848
# std     27.997026    0.266428    0.205164
# min      3.009800    0.000000    0.000000
# 25%     19.156900    0.266700    0.115900
# 50%     34.686300    0.428600    0.250000
# 75%     59.541700    0.636400    0.400000
# max    100.000000    1.250000    0.910400
#
# Correlation Analysis:
#           bleu       wer       cer
# bleu  1.000000 -0.830771 -0.766284
# wer  -0.830771  1.000000  0.901053
# cer  -0.766284  0.901053  1.000000

# %% [markdown]
# # Comprehensive Analysis of NLP Metrics Visualizations
#
# ## 1. Correlation Heatmap
# ### What it Represents:
# The correlation heatmap shows the statistical relationship between BLEU, WER (Word Error Rate), and CER (Character Error Rate) scores.
#
# #### Key Insights:
# - **Color Interpretation**:
#   - Red indicates negative correlation
#   - Blue indicates positive correlation
#   - Darker colors represent stronger correlations
#   - White or light colors suggest weak or no correlation
#
# #### Possible Scenarios:
# - A strong negative correlation between BLEU and WER would suggest that as Word Error Rate increases, BLEU score decreases
# - Moderate correlations might indicate complex interactions between metrics
# - Weak correlations suggest the metrics capture different aspects of translation quality
#
# ## 2. Metrics Distribution
# ### What it Represents:
# This visualization shows the frequency distribution of BLEU, WER, and CER scores.
#
# #### Key Insights:
# - **Shape of Distribution**:
#   - Normal (bell-curve) distribution suggests consistent performance
#   - Skewed distribution indicates bias in translation quality
#   - Multiple peaks might suggest distinct performance groups
#
# #### Interpretation:
# - Peak location shows the most common score range
# - Width of distribution indicates performance variability
# - Outliers represent exceptional cases of very good or poor translations
#
# ## 3. Length Impact Analysis
# ### What it Represents:
# Explores how text length affects different NLP metrics (BLEU, WER, CER).
#
# #### Key Insights:
# - **Relationship Between Length and Metrics**:
#   - Clustering of points suggests consistent performance
#   - Scattered points indicate high variability
#   - Trend lines (if visible) show how metrics change with text length
#
# #### Potential Observations:
# - Do longer texts have more consistent or more variable metrics?
# - Is there a sweet spot for text length that yields optimal performance?
# - How do different metrics respond to text length?
#
# ## 4. Word Frequency Analysis
# ### What it Represents:
# Displays the most frequently occurring words in references and hypotheses.
#
# #### Key Insights:
# - **Linguistic Patterns**:
#   - Common words across references and hypotheses
#   - Differences in word usage between reference and hypothesis
#   - Potential impact of frequent words on translation quality
#
# #### Potential Analysis:
# - Identify most challenging words for translation
# - Understand vocabulary complexity
# - Detect potential systematic translation errors
#
# ## 5. Advanced Scatter Plot (WER vs BLEU)
# ### What it Represents:
# A multi-dimensional view of Word Error Rate, BLEU Score, and Character Error Rate.
#
# #### Key Insights:
# - **Color Gradient**:
#   - Represents Character Error Rate
#   - Darker/lighter colors show variation in CER
# - **Point Distribution**:
#   - Clustering indicates consistent performance
#   - Spread suggests high variability
#
# #### Interpretation:
# - Relationship between translation accuracy (WER)
# - Impact of character-level errors on overall translation quality
# - Identifying optimal performance regions
#
# ## 6. PCA (Principal Component Analysis) Visualization
# ### What it Represents:
# Reduces multiple metrics to two principal components to show underlying patterns.
#
# #### Key Insights:
# - **Dimension Reduction**:
#   - Combines multiple features into two principal components
#   - Shows how different metrics interrelate
# - **Color Coding**:
#   - BLEU score represented by color gradient
#   - Helps identify patterns in translation quality
#
# #### Potential Discoveries:
# - Hidden relationships between different metrics
# - Clustering of translation performance
# - Variance explained by principal components
#
# ## Descriptive Statistics Interpretation
#
# ### Mean (Average):
# - Provides central tendency of metrics
# - Indicates overall translation performance
#
# ### Standard Deviation:
# - Measures variation in metrics
# - High deviation suggests inconsistent translation quality
#
# ### Minimum and Maximum:
# - Identifies extreme cases
# - Shows the range of translation performance
#
# ## Correlation Analysis
# ### What it Represents:
# Numerical representation of relationships between metrics.
#
# #### Interpretation:
# - Values close to 1 or -1 indicate strong correlation
# - Values near 0 suggest weak or no correlation
# - Helps understand how different metrics interact
#
# ## Research-Worthy Insights
# 1. **Performance Variability**: Analyze factors causing metric fluctuations
# 2. **Linguistic Complexity**: Understand how text characteristics impact translation
# 3. **Metric Interdependence**: Explore relationships between different evaluation metrics
# 4. **Error Pattern Recognition**: Identify systematic translation challenges
