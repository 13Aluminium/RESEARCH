# %% [markdown]
# <a href="https://colab.research.google.com/github/13Aluminium/RESEARCH/blob/main/RESEARCH_0_T5_SMALL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/google-research-datasets/Hinglish-TOP-Dataset

# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-3.4.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.12.0,>=2023.1.0 (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.14)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.29.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.2.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading datasets-3.4.1-py3-none-any.whl (487 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 487.4/487.4 kB 12.7 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.1 MB/s eta 0:00:00
# Downloading fsspec-2024.12.0-py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 15.9 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 12.2 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 13.6 MB/s eta 0:00:00
# Installing collected packages: xxhash, fsspec, dill, multiprocess, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.0
#     Uninstalling fsspec-2025.3.0:
#       Successfully uninstalled fsspec-2025.3.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.6.0+cu124 requires nvidia-cublas-cu12==12.4.5.8; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cublas-cu12 12.5.3.2 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-cupti-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-cupti-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-nvrtc-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-nvrtc-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-runtime-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-runtime-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cudnn-cu12==9.1.0.70; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cudnn-cu12 9.3.0.75 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cufft-cu12==11.2.1.3; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cufft-cu12 11.2.3.61 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-curand-cu12==10.3.5.147; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-curand-cu12 10.3.6.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusolver-cu12==11.6.1.9; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusolver-cu12 11.6.3.83 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusparse-cu12==12.3.1.170; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusparse-cu12 12.5.1.3 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-nvjitlink-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-nvjitlink-cu12 12.5.82 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2024.12.0 which is incompatible.
# Successfully installed datasets-3.4.1 dill-0.3.8 fsspec-2024.12.0 multiprocess-0.70.16 xxhash-3.5.0

# %%
import pandas as pd
import torch
from datasets import Dataset, DatasetDict
from transformers import (
    T5Tokenizer,
    T5ForConditionalGeneration,
    DataCollatorForSeq2Seq,
    Trainer,
    TrainingArguments
)

# Load datasets
train_df = pd.read_csv('/content/Hinglish-TOP-Dataset/Dataset/Human Annotated Data/train.tsv', sep='\t')
valid_df = pd.read_csv('/content/Hinglish-TOP-Dataset/Dataset/Human Annotated Data/validation.tsv', sep='\t')
test_df = pd.read_csv('/content/Hinglish-TOP-Dataset/Dataset/Human Annotated Data/test.tsv', sep='\t')

# Convert pandas DataFrame to Hugging Face Dataset
data = DatasetDict({
    'train': Dataset.from_pandas(train_df),
    'validation': Dataset.from_pandas(valid_df),
    'test': Dataset.from_pandas(test_df)
})

# Load T5 tokenizer and model
model_name = "t5-small"
tokenizer = T5Tokenizer.from_pretrained(model_name)
model = T5ForConditionalGeneration.from_pretrained(model_name)

# Enable gradient checkpointing for memory optimization
model.gradient_checkpointing_enable()

# Define preprocessing function
def preprocess_function(examples):
    inputs = ["translate English to Hinglish: " + ex for ex in examples["en_query"]]
    model_inputs = tokenizer(inputs, max_length=64, truncation=True)  # Reduced max_length

    # Tokenize targets
    with tokenizer.as_target_tokenizer():
        labels = tokenizer(examples["cs_query"], max_length=64, truncation=True)
    model_inputs["labels"] = labels["input_ids"]

    return model_inputs

# Tokenize dataset
tokenized_data = data.map(preprocess_function, batched=True)

# Training arguments (GPU training)
training_args = TrainingArguments(
    output_dir="./results",
    eval_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=8,   # Lower batch size to avoid OOM
    per_device_eval_batch_size=8,    # Lower batch size
    gradient_accumulation_steps=2,   # Accumulate gradients for effective batch size of 16
    weight_decay=0.01,
    save_total_limit=3,
    num_train_epochs=45,
    logging_dir='./logs',
    logging_steps=50,
    report_to=[]
)

# Data collator for dynamic padding
data_collator = DataCollatorForSeq2Seq(tokenizer, model=model)

# Initialize Trainer (GPU training)
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_data["train"],
    eval_dataset=tokenized_data["validation"],
    tokenizer=tokenizer,
    data_collator=data_collator,
)

# Training on GPU
trainer.train()

# Save the trained model
trainer.save_model("./final_model")

# Clear CUDA Cache
torch.cuda.empty_cache()

# Print completion message
print("Model training and saving completed successfully.")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/2.32k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/242M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# Map:   0%|          | 0/2993 [00:00<?, ? examples/s]
# /usr/local/lib/python3.11/dist-packages/transformers/tokenization_utils_base.py:3980: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   warnings.warn(
# Map:   0%|          | 0/1390 [00:00<?, ? examples/s]
# Map:   0%|          | 0/6513 [00:00<?, ? examples/s]
# <ipython-input-4-ff18ca7dcd5a>:67: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# `use_cache=True` is incompatible with gradient checkpointing. Setting `use_cache=False`...
#     <div>
#
#       <progress value='8415' max='8415' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [8415/8415 34:42, Epoch 44/45]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>3.681600</td>
#       <td>3.024720</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.006700</td>
#       <td>2.622414</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.770500</td>
#       <td>2.417901</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.590300</td>
#       <td>2.282089</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>2.495800</td>
#       <td>2.164588</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.384100</td>
#       <td>2.076579</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>2.259000</td>
#       <td>1.982894</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>2.153100</td>
#       <td>1.908898</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>2.079000</td>
#       <td>1.851472</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>2.034400</td>
#       <td>1.797256</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.938100</td>
#       <td>1.750794</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.920300</td>
#       <td>1.714936</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>1.863200</td>
#       <td>1.674309</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>1.829100</td>
#       <td>1.642020</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>1.813700</td>
#       <td>1.612759</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>1.769100</td>
#       <td>1.586208</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>1.734600</td>
#       <td>1.568624</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>1.706300</td>
#       <td>1.543831</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>1.710400</td>
#       <td>1.522732</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.641000</td>
#       <td>1.507442</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>1.668300</td>
#       <td>1.492645</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>1.671100</td>
#       <td>1.473223</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>1.632200</td>
#       <td>1.461964</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>1.565400</td>
#       <td>1.447103</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>1.575400</td>
#       <td>1.438179</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>1.606300</td>
#       <td>1.425479</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>1.538200</td>
#       <td>1.415710</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>1.580600</td>
#       <td>1.408858</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>1.524300</td>
#       <td>1.401811</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.530400</td>
#       <td>1.390592</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>1.520900</td>
#       <td>1.384160</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>1.515500</td>
#       <td>1.376050</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>1.517200</td>
#       <td>1.370378</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>1.454900</td>
#       <td>1.367961</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>1.430000</td>
#       <td>1.362531</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>1.434000</td>
#       <td>1.357652</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>1.496000</td>
#       <td>1.352898</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>1.457600</td>
#       <td>1.348957</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>1.474600</td>
#       <td>1.345799</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>1.465800</td>
#       <td>1.343336</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>1.423000</td>
#       <td>1.341641</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>1.496600</td>
#       <td>1.340179</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>1.452200</td>
#       <td>1.339212</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>1.473700</td>
#       <td>1.338731</td>
#     </tr>
#   </tbody>
# </table><p>
# Passing a tuple of `past_key_values` is deprecated and will be removed in Transformers v4.48.0. You should pass an instance of `EncoderDecoderCache` instead, e.g. `past_key_values=EncoderDecoderCache.from_legacy_cache(past_key_values)`.
# Model training and saving completed successfully.

# %%
import torch
import pandas as pd
import sys
import traceback
from transformers import T5Tokenizer, T5ForConditionalGeneration

def minimal_debug_inference(model_path, test_file_path):
    print("Starting minimal debug inference...")

    try:
        # Print Python and library versions
        print(f"Python Version: {sys.version}")
        print(f"PyTorch Version: {torch.__version__}")
        print(f"Transformers Version: {torch.__version__}")

        # Load test data with verbose error handling
        print("Attempting to load test dataset...")
        try:
            test_df = pd.read_csv(test_file_path, sep='\t')
            print(f"Loaded dataset: {len(test_df)} samples")
            print(f"Columns: {list(test_df.columns)}")
        except Exception as data_error:
            print(f"❌ DATA LOADING ERROR: {data_error}")
            print(traceback.format_exc())
            return

        # Validate required columns
        if 'en_query' not in test_df.columns:
            print("❌ ERROR: 'en_query' column not found in dataset!")
            print("Available columns:", list(test_df.columns))
            return

        # Load tokenizer with verbose error handling
        print("Attempting to load tokenizer...")
        try:
            tokenizer = T5Tokenizer.from_pretrained("t5-small")
        except Exception as tokenizer_error:
            print(f"❌ TOKENIZER LOADING ERROR: {tokenizer_error}")
            print(traceback.format_exc())
            return

        # Load model with verbose error handling
        print("Attempting to load model...")
        try:
            model = T5ForConditionalGeneration.from_pretrained(model_path)
        except Exception as model_error:
            print(f"❌ MODEL LOADING ERROR: {model_error}")
            print(traceback.format_exc())

            # Check model directory contents
            import os
            print("\nChecking model directory contents:")
            try:
                print(os.listdir(model_path))
            except Exception as dir_error:
                print(f"Could not list directory: {dir_error}")
            return

        # Prepare device
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        print(f"Running on device: {device}")
        model.to(device)
        model.eval()

        # Prepare inputs
        print("Preparing model inputs...")
        inputs = ["translate English to Hinglish: " + str(ex) for ex in test_df["en_query"][:5]]

        # Tokenize
        print("Tokenizing inputs...")
        encodings = tokenizer(
            inputs,
            max_length=64,
            truncation=True,
            padding=True,
            return_tensors="pt"
        )

        # Inference
        print("Starting inference...")
        with torch.no_grad():
            outputs = model.generate(
                input_ids=encodings['input_ids'].to(device),
                max_length=64,
                num_beams=4,
                early_stopping=True
            )

        # Decode predictions
        predictions = tokenizer.batch_decode(outputs, skip_special_tokens=True)

        # Print results
        print("\n=== SAMPLE PREDICTIONS ===")
        for orig, trans in zip(inputs, predictions):
            print(f"Original: {orig}")
            print(f"Translation: {trans}")
            print("---")

        print("Inference completed successfully!")

    except Exception as e:
        print(f"❌ UNEXPECTED ERROR: {e}")
        print(traceback.format_exc())

# Main execution
if __name__ == "__main__":
    minimal_debug_inference(
        model_path="/content/final_model",
        test_file_path='/content/Hinglish-TOP-Dataset/Dataset/Human Annotated Data/test.tsv'
    )
# Out:
# Starting minimal debug inference...
# Python Version: 3.11.11 (main, Dec  4 2024, 08:55:07) [GCC 11.4.0]
# PyTorch Version: 2.6.0+cu124
# Transformers Version: 2.6.0+cu124
# Attempting to load test dataset...
# Loaded dataset: 6513 samples
# Columns: ['en_query', 'cs_query', 'en_parse', 'cs_parse', 'domain']
# Attempting to load tokenizer...
# Attempting to load model...
# Running on device: cuda
# Preparing model inputs...
# Tokenizing inputs...
# Starting inference...
#
# === SAMPLE PREDICTIONS ===
# Original: translate English to Hinglish: Pause my timer .
# Translation: mere timer ko pause kare
# ---
# Original: translate English to Hinglish: Is it raining in Hawaii ?
# Translation: Kya Hawaii me baarish hone wali hai?
# ---
# Original: translate English to Hinglish: Set a reminder for me to wake up at 630 am tomorrow .
# Translation: mujhe kal 630 am ko wake up ka reminder set kare
# ---
# Original: translate English to Hinglish: Please pause timer
# Translation: Please timer ko pause kare
# ---
# Original: translate English to Hinglish: play the first album for killswitch engaged
# Translation: killswitch engaged ke liye ek liye ek liye ek album play kare
# ---
# Inference completed successfully!

# %%
# !pip install sacrebleu
# Out:
# Collecting sacrebleu
#   Downloading sacrebleu-2.5.1-py3-none-any.whl.metadata (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 2.5 MB/s eta 0:00:00
# Collecting portalocker (from sacrebleu)
#   Downloading portalocker-3.1.1-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (from sacrebleu) (2024.11.6)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.11/dist-packages (from sacrebleu) (0.9.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from sacrebleu) (2.0.2)
# Collecting colorama (from sacrebleu)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/dist-packages (from sacrebleu) (5.3.1)
# Downloading sacrebleu-2.5.1-py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.1/104.1 kB 5.9 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading portalocker-3.1.1-py3-none-any.whl (19 kB)
# Installing collected packages: portalocker, colorama, sacrebleu
# Successfully installed colorama-0.4.6 portalocker-3.1.1 sacrebleu-2.5.1

# %%
import torch
import pandas as pd
import sacrebleu

from transformers import T5Tokenizer, T5ForConditionalGeneration

def compute_bleu_metric(predictions, references):
    """
    Compute BLEU score using sacreBLEU.

    Args:
        predictions (list of str): Model-generated translations
        references (list of str): Ground-truth translations

    Returns:
        float: BLEU score
    """
    # sacreBLEU expects references in a list of lists
    bleu_score = sacrebleu.corpus_bleu(predictions, [references]).score
    return bleu_score

def evaluate_model(
    model_path,
    data_file,
    row_limit=500,
    max_length=64,
    num_beams=4
):
    """
    Load the model and dataset, generate translations, and compute BLEU metric.

    Args:
        model_path (str): Path to the saved T5 model directory
        data_file (str): Path to the TSV file with columns [en_query, cs_query, ...]
        row_limit (int): Maximum number of rows to use from the dataset
        max_length (int): Max length for generated translations
        num_beams (int): Number of beams for beam search
    """
    print("Loading dataset for evaluation...")
    df = pd.read_csv(data_file, sep='\t')

    # We need 'en_query' as input and 'cs_query' as reference
    if 'en_query' not in df.columns or 'cs_query' not in df.columns:
        raise ValueError("Data file must contain 'en_query' and 'cs_query' columns!")

    # Limit rows for faster evaluation
    df = df.head(row_limit)

    # Prepare model & tokenizer
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    tokenizer = T5Tokenizer.from_pretrained("t5-small")
    model = T5ForConditionalGeneration.from_pretrained(model_path)
    model.to(device)
    model.eval()

    # Generate predictions
    predictions = []
    references = []

    print(f"Generating translations for up to {len(df)} rows...")

    for _, row in df.iterrows():
        # Prepare input text
        input_text = "translate English to Hinglish: " + str(row['en_query'])

        # Tokenize
        encodings = tokenizer(
            input_text,
            max_length=max_length,
            truncation=True,
            return_tensors="pt"
        ).to(device)

        # Generate
        with torch.no_grad():
            outputs = model.generate(
                input_ids=encodings['input_ids'],
                attention_mask=encodings['attention_mask'],
                max_length=max_length,
                num_beams=num_beams,
                early_stopping=True
            )

        # Decode prediction
        pred_text = tokenizer.decode(outputs[0], skip_special_tokens=True)

        # Append prediction and reference
        predictions.append(pred_text)
        references.append(str(row['cs_query']))

    print("Done generating translations. Now computing BLEU metric...")

    # Compute BLEU metric
    bleu_score = compute_bleu_metric(predictions, references)

    # Print metric
    print("\n=== Evaluation Metric ===")
    print(f"BLEU Score: {bleu_score:.4f}")

    return bleu_score

def main():
    # Example usage
    model_path = "/content/final_model"  # Adjust if needed
    data_file = "/content/Hinglish-TOP-Dataset/Dataset/Synthetically Generated Data/train.tsv"  # Adjust path if needed

    # Evaluate on up to 500 rows from the train file
    evaluate_model(
        model_path=model_path,
        data_file=data_file,
        row_limit=500,       # Adjust as needed (200, 500, 1000, etc.)
        max_length=64,
        num_beams=4
    )

if __name__ == "__main__":
    main()
# Out:
# Loading dataset for evaluation...
# Generating translations for up to 500 rows...
# Done generating translations. Now computing BLEU metric...
#
# === Evaluation Metric ===
# BLEU Score: 26.6990

# %%
import torch
import pandas as pd
import numpy as np
import sacrebleu
from transformers import T5Tokenizer, T5ForConditionalGeneration, AutoModel, AutoTokenizer

def levenshtein_distance(s1, s2):
    """
    Compute Levenshtein distance between two strings
    Supports both word and character-level distance
    """
    # If input is string, convert to list of characters/words
    if isinstance(s1, str):
        s1 = list(s1)
    if isinstance(s2, str):
        s2 = list(s2)

    # Create distance matrix
    rows, cols = len(s1) + 1, len(s2) + 1
    dist = [[0 for x in range(cols)] for x in range(rows)]

    # Initialize first row and column
    for i in range(1, rows):
        dist[i][0] = i
    for j in range(1, cols):
        dist[0][j] = j

    # Compute Levenshtein distance
    for col in range(1, cols):
        for row in range(1, rows):
            if s1[row-1] == s2[col-1]:
                cost = 0
            else:
                cost = 1
            dist[row][col] = min(
                dist[row-1][col] + 1,      # deletion
                dist[row][col-1] + 1,      # insertion
                dist[row-1][col-1] + cost  # substitution
            )

    return dist[rows-1][cols-1]

def word_error_rate(reference, hypothesis):
    """
    Compute Word Error Rate (WER)
    Lower is better (0 is perfect match)
    """
    # Split into words
    r = reference.split()
    h = hypothesis.split()

    # Compute Levenshtein distance
    return levenshtein_distance(r, h) / len(r)

def character_error_rate(reference, hypothesis):
    """
    Compute Character Error Rate (CER)
    Lower is better (0 is perfect match)
    """
    return levenshtein_distance(reference, hypothesis) / len(reference)

def compute_embedding_similarity(reference, hypothesis, model_name='distilbert-base-uncased'):
    """
    Compute cosine similarity between sentence embeddings
    Higher is better (1 is perfect similarity)
    """
    try:
        # Load pre-trained model and tokenizer
        tokenizer = AutoTokenizer.from_pretrained(model_name)
        model = AutoModel.from_pretrained(model_name)

        # Tokenize and get embeddings
        inputs_ref = tokenizer(reference, return_tensors='pt', truncation=True, max_length=512)
        inputs_hyp = tokenizer(hypothesis, return_tensors='pt', truncation=True, max_length=512)

        # Generate embeddings
        with torch.no_grad():
            outputs_ref = model(**inputs_ref)
            outputs_hyp = model(**inputs_hyp)

        # Mean pooling
        ref_embedding = outputs_ref.last_hidden_state.mean(dim=1)
        hyp_embedding = outputs_hyp.last_hidden_state.mean(dim=1)

        # Compute cosine similarity
        return 1 - torch.nn.functional.cosine_similarity(ref_embedding, hyp_embedding).item()
    except Exception as e:
        print(f"Error in embedding similarity: {e}")
        return None

def evaluate_model_metrics(
    model_path,
    data_file,
    row_limit=500,
    max_length=64,
    num_beams=4
):
    """
    Comprehensive model evaluation with multiple metrics
    """
    print("Loading dataset for evaluation...")
    df = pd.read_csv(data_file, sep='\t')

    # Validate columns
    if 'en_query' not in df.columns or 'cs_query' not in df.columns:
        raise ValueError("Data file must contain 'en_query' and 'cs_query' columns!")

    # Limit rows
    df = df.head(row_limit)

    # Prepare model & tokenizer
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    tokenizer = T5Tokenizer.from_pretrained("t5-small")
    model = T5ForConditionalGeneration.from_pretrained(model_path)
    model.to(device)
    model.eval()

    # Metrics storage
    metrics = {
        'bleu_scores': [],
        'wer_scores': [],
        'cer_scores': [],
        'embedding_similarities': []
    }

    print(f"Generating translations for up to {len(df)} rows...")

    for _, row in df.iterrows():
        # Prepare input text
        input_text = "translate English to Hinglish: " + str(row['en_query'])
        reference = str(row['cs_query'])

        # Tokenize
        encodings = tokenizer(
            input_text,
            max_length=max_length,
            truncation=True,
            return_tensors="pt"
        ).to(device)

        # Generate
        with torch.no_grad():
            outputs = model.generate(
                input_ids=encodings['input_ids'],
                attention_mask=encodings['attention_mask'],
                max_length=max_length,
                num_beams=num_beams,
                early_stopping=True
            )

        # Decode prediction
        hypothesis = tokenizer.decode(outputs[0], skip_special_tokens=True)

        # Compute metrics
        # BLEU
        bleu_score = sacrebleu.sentence_bleu(hypothesis, [reference]).score
        metrics['bleu_scores'].append(bleu_score)

        # Word Error Rate
        wer = word_error_rate(reference, hypothesis)
        metrics['wer_scores'].append(wer)

        # Character Error Rate
        cer = character_error_rate(reference, hypothesis)
        metrics['cer_scores'].append(cer)

        # Embedding Similarity
        emb_sim = compute_embedding_similarity(reference, hypothesis)
        if emb_sim is not None:
            metrics['embedding_similarities'].append(emb_sim)

        # Optional: print individual sample results
        print(f"\nReference: {reference}")
        print(f"Hypothesis: {hypothesis}")
        print(f"BLEU: {bleu_score:.4f}, WER: {wer:.4f}, CER: {cer:.4f}")

    # Compute average metrics
    print("\n=== Evaluation Metrics ===")
    print(f"Average BLEU Score: {np.mean(metrics['bleu_scores']):.4f}")
    print(f"Average Word Error Rate: {np.mean(metrics['wer_scores']):.4f}")
    print(f"Average Character Error Rate: {np.mean(metrics['cer_scores']):.4f}")
    if metrics['embedding_similarities']:
        print(f"Average Embedding Similarity: {np.mean(metrics['embedding_similarities']):.4f}")

    return metrics

def main():
    # Example usage
    model_path = "/content/final_model"  # Adjust if needed
    data_file = "/content/Hinglish-TOP-Dataset/Dataset/Synthetically Generated Data/train.tsv"  # Adjust path if needed

    # Evaluate on up to 500 rows from the train file
    evaluate_model_metrics(
        model_path=model_path,
        data_file=data_file,
        row_limit=500,
        max_length=64,
        num_beams=4
    )

if __name__ == "__main__":
    main()
# Out:
# Loading dataset for evaluation...
# Generating translations for up to 500 rows...
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Reference: Is Saturday night The Grand Ole Opry me featured performer kya hai
# Hypothesis: Saturday night The Grand Ole Opry me featured performer kya hai
# BLEU: 91.3101, WER: 0.0833, CER: 0.0455
#
# Reference: mujhe 12 am ko meri meeting ke baare me yaad dilaayen
# Hypothesis: mujhe 12 am ke liye mere meeting ke liye yaad dilaye
# BLEU: 18.3603, WER: 0.5455, CER: 0.3019
#
# Reference: subha 5 baje ke liye ek alarm set karen
# Hypothesis: 5 am ke liye alarm set kare
# BLEU: 14.7596, WER: 0.4444, CER: 0.3333
#
# Reference: dopaher 2 baje Sydney me mausam kaisa hoga
# Hypothesis: Sydney me 2 pm me mausam kaisa hai
# BLEU: 25.8487, WER: 0.6250, CER: 0.4762
#
# Reference: Canada me mausam kaisa hai ?
# Hypothesis: Canada me mausam kya hai?
# BLEU: 37.9918, WER: 0.5000, CER: 0.1429
#
# Reference: weekend alarm ko delete karo
# Hypothesis: weekend alarm ko delete kare
# BLEU: 66.8740, WER: 0.2000, CER: 0.0357
#
# Reference: abhi ka temperature kya hai
# Hypothesis: aj temperature kya hai
# BLEU: 46.3078, WER: 0.4000, CER: 0.2222
#
# Reference: Interstate 90 ke zariye yaha se Cades Cove TN tak drive karke jaane me kitna samay lagega ?
# Hypothesis: Kya aaj raat Cades Cove TN via Interstate 90 ko drive karne ke liye kitna sakta hai?
# BLEU: 11.6439, WER: 0.8889, CER: 0.6374
#
# Reference: 30 may ke midnight ke liye alarm set kare
# Hypothesis: may 30th midnight ke liye alarm set kare
# BLEU: 62.4020, WER: 0.2222, CER: 0.1707
#
# Reference: please wo song ko phir se bajao
# Hypothesis: please song ko replay kare
# BLEU: 15.8487, WER: 0.5714, CER: 0.4516
#
# Reference: Please aaj raat ke liye wo alarm cancel kare
# Hypothesis: please aj raat ke liye alarm cancel kare
# BLEU: 30.5098, WER: 0.3333, CER: 0.1136
#
# Reference: channel ko Spotify me badal do
# Hypothesis: Spotify me channel ko change kare
# BLEU: 22.9575, WER: 1.0000, CER: 0.9000
#
# Reference: kal 5 pm ko mujhe Perth ke liye weather update de ?
# Hypothesis: Muje kal 5 pm ko Perth me weather update bataye?
# BLEU: 27.3768, WER: 0.5000, CER: 0.4510
#
# Reference: mere weather app ke liye Tokyo ko delete kardo
# Hypothesis: Tokyo ko meri weather app ko delete kare
# BLEU: 16.1301, WER: 0.7778, CER: 0.5652
#
# Reference: agle Monday 9 : 15 AM ke liye ek alert time set karen .
# Hypothesis: next Monday ko 9 : 15 AM ke liye alert time set kare
# BLEU: 46.0533, WER: 0.3571, CER: 0.2364
#
# Reference: snooze alarm band kare
# Hypothesis: snooze alarm ko off kare
# BLEU: 23.6435, WER: 0.5000, CER: 0.2727
#
# Reference: kal subha kuch bacchon ke liye events kya hai
# Hypothesis: kal morning ke liye ek kid friendly events kya hai
# BLEU: 20.5567, WER: 0.6667, CER: 0.5778
#
# Reference: aaj kitni damn garmi honi chahiye ?
# Hypothesis: aj kitna hot hai?
# BLEU: 7.1605, WER: 1.0000, CER: 0.5429
#
# Reference: Mujhe har dusre Tuesday ko recycling ko curb me le jane ke liye yaad dilaayen .
# Hypothesis: mujhe aaj raat ke liye recycling ke liye yaad dilaye
# BLEU: 9.2115, WER: 0.7500, CER: 0.4937
#
# Reference: is mahine steak dinner ke sabhi reminders me Brian aur Matt ko add karen .
# Hypothesis: Brian and Matt ko add kare to all reminders involving steak dinner this month.
# BLEU: 13.8344, WER: 1.0000, CER: 0.7432
#
# Reference: mujhe I 95 par Houston pahuchne mei kitni der lagegi .
# Hypothesis: mujhe I 95 ke liye Houston ke liye yaad dilaayen
# BLEU: 15.1872, WER: 0.7273, CER: 0.5926
#
# Reference: Aaj ke liye highest expected temperature kya hai ?
# Hypothesis: Aaj ke liye highest expected temperature kya hai?
# BLEU: 100.0000, WER: 0.2222, CER: 0.0200
#
# Reference: mere jog ke liye 20 - minute timer set kare
# Hypothesis: mere jog me 20 minute ke liye timer set kare
# BLEU: 24.4462, WER: 0.5000, CER: 0.3721
#
# Reference: Kya aaj mujhe raincoat pehenna chahiye ?
# Hypothesis: kya aaj mujhe raincoat ki chahiye?
# BLEU: 30.7394, WER: 0.5714, CER: 0.2250
#
# Reference: please mujhe Friday 1 : 00 pm se pehle mera job application mail karne ke liye yaad dilayen
# Hypothesis: Please mujhe Friday 1 : 00 pm ke liye mera job application mail karne ke liye remind karaye
# BLEU: 59.1815, WER: 0.2778, CER: 0.1648
#
# Reference: friday ke liye humidity kya hai
# Hypothesis: friday ka humidity kya hai
# BLEU: 34.9833, WER: 0.3333, CER: 0.1935
#
# Reference: mere alarms kya time ke liye set kare gaye hai
# Hypothesis: mere alarm ka time set kya hai?
# BLEU: 6.4313, WER: 0.7000, CER: 0.3913
#
# Reference: is season ke liye average climatic condition
# Hypothesis: this season ke liye Climatic condition hai
# BLEU: 26.2691, WER: 0.5714, CER: 0.3409
#
# Reference: kya aj raat koi shooting stars hone wale hai
# Hypothesis: Kya aaj raat koi shooting stars hai
# BLEU: 32.6683, WER: 0.4444, CER: 0.2727
#
# Reference: saturday dopahar ko Samantha ke liye cake pick up karne ke liye reminder set kare
# Hypothesis: Samantha ko reminder set kare to pick up the cake Saturday at noon
# BLEU: 13.9428, WER: 0.8000, CER: 0.6173
#
# Reference: mujhe Skype par unread chats dikhao
# Hypothesis: mujhe Skype me unread chats dikhao
# BLEU: 37.9918, WER: 0.1667, CER: 0.0857
#
# Reference: kya aap iheartradio par 107 . 9 bajaa sakte hai
# Hypothesis: kya iheartradio me 107. 9 bajao
# BLEU: 18.0945, WER: 0.7000, CER: 0.4043
#
# Reference: kya bahar sweater weather hai ?
# Hypothesis: Kya sweater ka weather hai?
# BLEU: 32.4668, WER: 0.8333, CER: 0.3548
#
# Reference: kaam ku jaane ke raaste me wrecks
# Hypothesis: work ko work ke liye shuru hai
# BLEU: 6.5673, WER: 0.8571, CER: 0.7273
#
# Reference: mujhe new york city mein kal ka forecast bataiye
# Hypothesis: mujhe new york city me kal forecast bataye
# BLEU: 33.7646, WER: 0.3333, CER: 0.1250
#
# Reference: Pam ka Thumbs up message
# Hypothesis: Pam ko message ko thumbs up
# BLEU: 10.6822, WER: 1.0000, CER: 0.7500
#
# Reference: mere subah 7 bajhe ke alarm ko cancel kare
# Hypothesis: mere 7 am ke alarm cancel kare
# BLEU: 15.4479, WER: 0.3333, CER: 0.3095
#
# Reference: Monday through Friday ka subah 5 baje ke liye alarm set kare
# Hypothesis: Monday through Friday 5 am ke liye alarm set kare
# BLEU: 44.3001, WER: 0.2500, CER: 0.2000
#
# Reference: meri wedding ka theme kya hona chahiye
# Hypothesis: our wedding ke theme kya he
# BLEU: 15.2072, WER: 0.5714, CER: 0.3684
#
# Reference: agar mai ek ghante me nikal jaoon to mujhe sams ghar pahunchne me kitna samay lagega ?
# Hypothesis: sams house ke liye ek hour ke liye yaad dilaayen?
# BLEU: 2.8587, WER: 1.0000, CER: 0.7209
#
# Reference: kya palo alto me 28 degree fahrenheit se upar hai
# Hypothesis: Kya 28 degree fahrenheit palo alto ke liye he
# BLEU: 19.9694, WER: 0.9000, CER: 0.6327
#
# Reference: is weekend Santa Claus locations
# Hypothesis: this weekend ko Santa Claus ka locations
# BLEU: 15.6197, WER: 0.6000, CER: 0.2500
#
# Reference: maine alarm kis liye set kiya tha
# Hypothesis: kya aap mujhe alarm set kare
# BLEU: 8.1706, WER: 0.8571, CER: 0.6667
#
# Reference: Mere timer par kitna time bacha he ?
# Hypothesis: mere timer me kitna time chahiye?
# BLEU: 13.5404, WER: 0.6250, CER: 0.2778
#
# Reference: marketing team ko kal subah 9 bajhe conference room me milne ke liye yaad dilaye
# Hypothesis: Marketing team ko raat 9 bajhe conference room ke liye yaad dilaye
# BLEU: 36.2885, WER: 0.3333, CER: 0.2125
#
# Reference: Currently windham me traffic kaisa hai
# Hypothesis: windham me traffic kaisa hai
# BLEU: 81.8731, WER: 0.1667, CER: 0.2632
#
# Reference: mujhe Highway 84 par Flowers Hospital se Wiregrass Commons Mall tak ke liye Directions de .
# Hypothesis: Muje Flowers Hospital se Highway 84 ke liye Wiregrass Commons Mall ke liye Directions get kare
# BLEU: 22.6764, WER: 0.6875, CER: 0.4835
#
# Reference: Aaj raat mujhe kaam ke baad milk pick karne ke liye yaad dilaayen
# Hypothesis: mujhe aaj work ke liye milk pick karne ke liye yaad dilayen
# BLEU: 41.2491, WER: 0.4615, CER: 0.3077
#
# Reference: Kya muje aaj raat coat pehen na padega .
# Hypothesis: Kya aaj mujhe coat chahiye
# BLEU: 6.3169, WER: 0.6667, CER: 0.6000
#
# Reference: mere roast timer ko 20 minutes tak kam karna chahiye
# Hypothesis: mere roast timer ko 20 minutes ke liye decreased kare
# BLEU: 51.6973, WER: 0.4000, CER: 0.3462
#
# Reference: kya agle hafte bahar 72 Celsius se niche hai
# Hypothesis: Kya aaj raat 72 Celsius hone wala hai
# BLEU: 10.7868, WER: 0.6667, CER: 0.4545
#
# Reference: mujhe kal subah 10 bajhe meri girlfriend ko jagaane ke liye uske appointment ke liye yaad dilaye
# Hypothesis: mujhe kal 10 : 00 am ke liye mere girlfriend ko wake up karne ke liye yaad dilaye
# BLEU: 20.5902, WER: 0.7059, CER: 0.4062
#
# Reference: timer par kitna time bacha hai ?
# Hypothesis: timer me kitna time hai?
# BLEU: 20.5480, WER: 0.5714, CER: 0.3125
#
# Reference: mai yaha se car dealership par Commercial me kaise jaa sakta hoon ?
# Hypothesis: kya aaj raat Commercial ke liye car dealership ke liye yaad dilaye?
# BLEU: 7.3471, WER: 1.0000, CER: 0.7313
#
# Reference: aj ke liye mere sarey alarms cancel kare
# Hypothesis: aaj ke liye mere alarms cancel kare
# BLEU: 35.6403, WER: 0.2500, CER: 0.1750
#
# Reference: har 10 minutes ke liye alarm set kare
# Hypothesis: 10 minutes ke liye alarm set kare
# BLEU: 86.6878, WER: 0.1250, CER: 0.1081
#
# Reference: please kuch relaxation music play kare
# Hypothesis: please relaxation music play kare
# BLEU: 57.8930, WER: 0.1667, CER: 0.1316
#
# Reference: mujhe Sunday 7 pm ko mere tutoring session ke baare me yaad dilaayen .
# Hypothesis: Muje Sunday 7 pm ko meri tutoring session ke liye yaad dilaye
# BLEU: 26.8354, WER: 0.4286, CER: 0.2000
#
# Reference: kya aaj shaam traffic kharab hai
# Hypothesis: kya aaj raat traffic kaisa hai
# BLEU: 19.3049, WER: 0.3333, CER: 0.2188
#
# Reference: 7 am tak alarm par kitna time bakhi hai ?
# Hypothesis: 7 am ke alarm ke liye kitna time hai?
# BLEU: 15.1069, WER: 0.6000, CER: 0.4146
#
# Reference: please mujhe Providence aur New York City ke beech ki doori batayen
# Hypothesis: please mujhe Providence ke New York City ke liye distance bataye
# BLEU: 30.9838, WER: 0.4167, CER: 0.2388
#
# Reference: aj dopaher ke liye alarm set kare
# Hypothesis: aj noon ke liye alarm set kare
# BLEU: 64.3459, WER: 0.1429, CER: 0.1818
#
# Reference: Aaj ki traffic report kya he
# Hypothesis: aj traffic report kaisa hai
# BLEU: 17.4917, WER: 0.6667, CER: 0.3214
#
# Reference: Atlantic City se Edison tak traffic driving kya hai
# Hypothesis: Atlantic City se Edison me traffic kaisa hai
# BLEU: 33.7646, WER: 0.3333, CER: 0.2353
#
# Reference: agle mahine mere area mei Beyonce ke concerts hai
# Hypothesis: next month ke liye beyonce concerts in my area
# BLEU: 6.2747, WER: 1.0000, CER: 0.6531
#
# Reference: Jackie Chan dwara Beauty and the Beast bajaye
# Hypothesis: Jackie Chan ko Beauty and the Beast play kare
# BLEU: 35.4948, WER: 0.3750, CER: 0.2444
#
# Reference: kya aj yaha 79 degree f ke aas paas rahega
# Hypothesis: Kya aaj raat 79 degree f ke liye hai
# BLEU: 26.7087, WER: 0.6000, CER: 0.4286
#
# Reference: 11 am aur 4 pm ke liye alarm lagaye
# Hypothesis: 11 am aur 4 pm ke liye alarm set kare
# BLEU: 75.9836, WER: 0.2222, CER: 0.1714
#
# Reference: Kya kal cloudy hone wala he ?
# Hypothesis: Kya kal cloudy hone wala hai?
# BLEU: 64.3459, WER: 0.2857, CER: 0.0690
#
# Reference: track ko skip kare
# Hypothesis: track ko skip kare
# BLEU: 100.0000, WER: 0.0000, CER: 0.0000
#
# Reference: Farenheit me mausam kya hai
# Hypothesis: Farenheit me mausam kaisa hai
# BLEU: 42.7287, WER: 0.2000, CER: 0.1111
#
# Reference: Charlotte aur Tampa ke beech ka distance kitna hai
# Hypothesis: Charlotte se Tampa me distance kya hai
# BLEU: 6.9794, WER: 0.5556, CER: 0.3200
#
# Reference: Kya mere paas aaj ke liye work ke baare me koi reminders hai ?
# Hypothesis: mujhe aaj work ke liye reminders hai?
# BLEU: 14.2720, WER: 0.7143, CER: 0.5161
#
# Reference: monday ke reminders ko hata den
# Hypothesis: monday reminders ko remove kare
# BLEU: 19.3577, WER: 0.5000, CER: 0.4194
#
# Reference: kya is weekend koi concert hai
# Hypothesis: kya aaj weekend ke liye concert hai
# BLEU: 15.6197, WER: 0.5000, CER: 0.2667
#
# Reference: Temecula me traffic kaisi dikh rahi hai
# Hypothesis: Temecula me traffic kaisa hai
# BLEU: 28.6419, WER: 0.4286, CER: 0.2564
#
# Reference: kya agle hafte New Albany Ohio me koi Christmas events hone wale hai
# Hypothesis: kya aaj New Albany Ohio ke liye Christmas events hai
# BLEU: 15.8271, WER: 0.4615, CER: 0.3382
#
# Reference: kal ka mousam kaisa hoga
# Hypothesis: kal mausam kaisa hai?
# BLEU: 12.7033, WER: 0.6000, CER: 0.2917
#
# Reference: accounting staff ke liye ek weekly reminder set karen meet 1st thing in the morning
# Hypothesis: kal 1st thing ko meet kare ke liye accounting staff ke liye weekly reminder set kare
# BLEU: 25.3365, WER: 1.0667, CER: 0.7711
#
# Reference: har 15 minutes ke liye timer set kare
# Hypothesis: every 15 minutes ke liye timer set kare
# BLEU: 84.0896, WER: 0.1250, CER: 0.1081
#
# Reference: Kya is week me garm weather hone wala he
# Hypothesis: kya aaj raat hone wala hai
# BLEU: 9.8461, WER: 0.7778, CER: 0.5500
#
# Reference: Mujhe agle Wednesday ko Mom ke birthday ke bare me yaad dilaayen .
# Hypothesis: Muje aaj raat Mom ke birthday ke liye yaad dilaye
# BLEU: 20.5771, WER: 0.6154, CER: 0.3788
#
# Reference: agar mai abhi nikalta hun toh mujhe yaha se Shun ke ghar drive karke jane me kitna samay lagega
# Hypothesis: mujhe aaj raat Shun ke house drive karne ke liye kitna sakta hai
# BLEU: 4.8966, WER: 0.7368, CER: 0.5684
#
# Reference: kya aap Jeff ko ek video message send karsakte hai ?
# Hypothesis: kya Jeff ke liye ek video message send kare?
# BLEU: 27.3385, WER: 0.5455, CER: 0.3654
#
# Reference: sunrise kab hai
# Hypothesis: sunrise ka time kya hai
# BLEU: 12.7033, WER: 1.0000, CER: 0.6000
#
# Reference: agley track par
# Hypothesis: next track
# BLEU: 30.3265, WER: 0.6667, CER: 0.6000
#
# Reference: agla song please
# Hypothesis: next song please
# BLEU: 55.0321, WER: 0.3333, CER: 0.2500
#
# Reference: mujhe kal meri interview ke baare me yaad dilaye
# Hypothesis: mujhe mera interview tomorow ke liye yaad dilaye
# BLEU: 12.2562, WER: 0.5556, CER: 0.3542
#
# Reference: mujhe Tuesday 3 pm tak library books return karne ke liye yaad dilaye
# Hypothesis: mujhe Tuesday 3 pm ke liye library books return kare ke liye yaad dilaye
# BLEU: 43.7481, WER: 0.2308, CER: 0.1159
#
# Reference: agle monday ko temperature kitna hone wala hai ?
# Hypothesis: aj monday ke liye temperature kya hai?
# BLEU: 11.5912, WER: 0.8889, CER: 0.4792
#
# Reference: sabhi alarms aur timers ko hata do .
# Hypothesis: saare alarms ko delete kare
# BLEU: 6.9717, WER: 0.7500, CER: 0.5833
#
# Reference: Agar mai turnpike leta hoon toh mujhe Florida Keys pahuchne mei kitni der lagegi ?
# Hypothesis: mujhe turnpike ke liye Florida Keys ko kitna sakta hai?
# BLEU: 6.5518, WER: 0.8000, CER: 0.5610
#
# Reference: kal ka expected low kya hai ?
# Hypothesis: kal ke liye expected low kya hai?
# BLEU: 54.1082, WER: 0.5714, CER: 0.2414
#
# Reference: Pennsylvania se the Catskills tak drive kitni lambi hai
# Hypothesis: Pennsylvania me catskills ke drive kitna kitna kitna sakta hai
# BLEU: 5.5224, WER: 0.8889, CER: 0.4545
#
# Reference: Bob Michaels ko ek message bhejo jo kehta he ki thank you for the game
# Hypothesis: Bob Michaels ko message karo ki thank you for the game.
# BLEU: 42.4639, WER: 0.4000, CER: 0.2714
#
# Reference: Mere stoped timer ke sath chalu kare
# Hypothesis: mere stopped timer ko shuru karo
# BLEU: 6.8706, WER: 0.8571, CER: 0.3056
#
# Reference: Frank aur Bob ke wedding ke liye September 3rd ko reminder set kare ; mujhe ek week pehle gift khareedne ke liye yaad dilaayen .
# Hypothesis: Frank and Bob ko wedding ke liye reminder set kare on September 3rd ; remind me to buy a gift a week in advance.
# BLEU: 12.5369, WER: 0.7600, CER: 0.5078
#
# Reference: Kya ghar ke raste me koi traffic delays hai
# Hypothesis: Kya meri way home par traffic delays hai
# BLEU: 19.4940, WER: 0.5556, CER: 0.3256
#
# Reference: FRIDAY ko TRAFFIC KAISA HOGA
# Hypothesis: FRIDAY ko TRAFFIC ke liye yaad dilaayen
# BLEU: 24.4462, WER: 0.8000, CER: 0.7143
#
# Reference: Kya waha koi accidents he
# Hypothesis: kya koi accidents hai
# BLEU: 24.8805, WER: 0.6000, CER: 0.3200
#
# Reference: kya mujhe kal dopahar apni umbrella ki zarurat padegi ?
# Hypothesis: Kya aaj raat ke liye mera umbrella chahiye?
# BLEU: 5.0736, WER: 1.0000, CER: 0.6364
#
# Reference: Hawai me abhi mausam kaisa hai ?
# Hypothesis: Aaj Hawaii me mausam kaisa hai?
# BLEU: 43.4721, WER: 0.7143, CER: 0.3438
#
# Reference: Agle Saturday ko San Antonio me Travis Park me jazz concert kab hai
# Hypothesis: Next Saturday ko kya times is the Jazz concert at Travis Park in San Antonio
# BLEU: 9.4612, WER: 1.0000, CER: 0.7164
#
# Reference: kya aaj ole girne wale hai ?
# Hypothesis: Kya aaj hail he?
# BLEU: 8.5153, WER: 0.8571, CER: 0.5714
#
# Reference: ek ghante ke liye classical music bajao
# Hypothesis: classical music bajao for one hour
# BLEU: 25.5754, WER: 1.0000, CER: 0.7949
#
# Reference: weekend ke liye mausam kaisa dikh raha hai ?
# Hypothesis: weekend ke liye weather kaisa hai?
# BLEU: 24.1772, WER: 0.5556, CER: 0.3864
#
# Reference: Is song ko phir se shuru karen
# Hypothesis: this song ko start kare
# BLEU: 14.3210, WER: 0.7143, CER: 0.5000
#
# Reference: Kansas City me traffic ki conditions kya he
# Hypothesis: Kansas City me traffic conditions kya hai
# BLEU: 42.3837, WER: 0.2500, CER: 0.1163
#
# Reference: mere sabhi weekend reminders Max ke sath pahunchne
# Hypothesis: Max ke liye sabhi weekend reminders ko get kare.
# BLEU: 19.6407, WER: 0.8750, CER: 0.5000
#
# Reference: mujhe kal ke reminders bataye
# Hypothesis: mujhe kal ke reminders bataye
# BLEU: 100.0000, WER: 0.0000, CER: 0.0000
#
# Reference: Mera 5 am ka alarm har 10 minute me snooze kare
# Hypothesis: mere 5 am ke alarm ko snooze karne ke liye every 10 minutes
# BLEU: 7.7686, WER: 0.9091, CER: 0.7447
#
# Reference: kya aaj toofan aane wala hai ?
# Hypothesis: Kya aaj storm hone wala hai?
# BLEU: 26.2691, WER: 0.7143, CER: 0.3000
#
# Reference: Agar mai is afternoon 3 : 00 baje nikal jaoon to mujhe yaha se Fayetteville me the mall tak pahunchne me kitna samay lagega ?
# Hypothesis: mujhe aaj raat 3 : 00 baje ke liye mall in Fayetteville ke liye kitna sakta hai?
# BLEU: 11.1615, WER: 0.7600, CER: 0.5760
#
# Reference: mujhe Bruno Mars ko sunna hai
# Hypothesis: mujhe Bruno Mars ko sakta chahiye
# BLEU: 50.8133, WER: 0.3333, CER: 0.2414
#
# Reference: Is saturday subah 10 bajhe team meeting ke liye reminder set kare
# Hypothesis: team meeting ke liye ek reminder set kare this Saturday at 10 am
# BLEU: 28.9178, WER: 0.9167, CER: 0.8154
#
# Reference: Mai pandora par Justin Bieber ko sunna chahta hu
# Hypothesis: kya pandora me Justin Bieber ke liye yaad dilaye
# BLEU: 10.5527, WER: 0.6667, CER: 0.4583
#
# Reference: 5 minutes me timer ko on karo
# Hypothesis: 5 minutes ke liye timer ko shuru kare
# BLEU: 15.6197, WER: 0.5714, CER: 0.4138
#
# Reference: subha walk ke liye reminder set karen
# Hypothesis: morning walk ke liye reminder set kare
# BLEU: 61.4788, WER: 0.2857, CER: 0.2162
#
# Reference: kal ke alarm cancel kardo
# Hypothesis: kal ke alarm cancel kare
# BLEU: 66.8740, WER: 0.2000, CER: 0.0800
#
# Reference: is weekend par family events kya hai
# Hypothesis: Is weekend ke liye family events hai
# BLEU: 15.6197, WER: 0.5714, CER: 0.3333
#
# Reference: is haftey ka sabse coldest day kya hai ?
# Hypothesis: this week ko the coldest day kya hai?
# BLEU: 44.6324, WER: 0.6667, CER: 0.3250
#
# Reference: is mahine hone wale Kendrick Lamar ke concerts
# Hypothesis: Kendrick Lamar ko concerts kaisa hai
# BLEU: 12.8726, WER: 0.8750, CER: 0.6739
#
# Reference: Kya seattle me abhi baarish horahi hai ?
# Hypothesis: kya seattle me baarish hai?
# BLEU: 17.3935, WER: 0.6250, CER: 0.3500
#
# Reference: har do ghante ke liye alarm set kare
# Hypothesis: har two hours ke liye alarm set kare
# BLEU: 54.1082, WER: 0.2500, CER: 0.1944
#
# Reference: LAX ke aas paas traffic kaisa hai
# Hypothesis: LAX me traffic kaisa hai
# BLEU: 28.6419, WER: 0.4286, CER: 0.3030
#
# Reference: Mt . Hood tak current drive time kya hai
# Hypothesis: Mt Hood me current drive time kya hai
# BLEU: 49.6264, WER: 0.2222, CER: 0.1250
#
# Reference: aaj cairo me traffic kaisa hai
# Hypothesis: aaj cairo me traffic kaisa hai
# BLEU: 100.0000, WER: 0.0000, CER: 0.0000
#
# Reference: current traffic ke sath mai ghar se safeway kab tak pahunch sakta hu
# Hypothesis: kya aaj raat ke liye home ke liye safeway ke liye yaad dilaayen
# BLEU: 3.6735, WER: 0.9231, CER: 0.6618
#
# Reference: mai sam hunt sunna chahta hoon
# Hypothesis: mujhe sam hunt ke liye listen kare
# BLEU: 13.1345, WER: 0.8333, CER: 0.7000
#
# Reference: is coming Monday 2 pm , 3 pm aur 4 pm ke liye ek naya alarm banayen
# Hypothesis: this coming Monday 2 pm, 3 pm and 4 pm ke liye naye alarm banaye
# BLEU: 50.9517, WER: 0.4118, CER: 0.1493
#
# Reference: mujhe is friday subah 9 bajhe ke liye alarm chahiye .
# Hypothesis: mujhe aaj raat friday 9 bajhe ke liye alarm chahiye
# BLEU: 50.2659, WER: 0.3636, CER: 0.2642
#
# Reference: Mere paas abhi kitne alarms set hai
# Hypothesis: aaj raat kitni alarms set karne ke liye hai
# BLEU: 10.5527, WER: 1.0000, CER: 0.7429
#
# Reference: aaj Lake Ontario me water temperature kya he
# Hypothesis: aj Lake Ontario me water temperature kya hai
# BLEU: 68.0375, WER: 0.2500, CER: 0.0682
#
# Reference: mujhe Tuesday ko adhe ghante pehle mail alarm banaye
# Hypothesis: Tuesday ke liye mera mail alarm half on hour ke liye make kare
# BLEU: 6.8372, WER: 1.3333, CER: 0.8654
#
# Reference: Jin aur Sop ko message bhejo ki I am on the way home .
# Hypothesis: Jin ke liye Sop ko message ko send kare ke liye yaad dilaye yaad dilaye
# BLEU: 10.5118, WER: 0.7857, CER: 0.7407
#
# Reference: Please clock par 1 minute add kare
# Hypothesis: please 1 minute ke liye on the clock
# BLEU: 12.2231, WER: 1.1429, CER: 0.7647
#
# Reference: 6 pm ke liye alarm lagaye
# Hypothesis: 6 pm ke liye alarm set kare
# BLEU: 61.4788, WER: 0.3333, CER: 0.2400
#
# Reference: agley 10 din ka forecast kya hai
# Hypothesis: next 10 day ke forecast kya hai
# BLEU: 26.2691, WER: 0.4286, CER: 0.2500
#
# Reference: Is weekend Paris ke paas kitna cold hone wala he in degree Fahrenheit
# Hypothesis: Paris me weekend ka degree Fahrenheit me kitna sakta hai
# BLEU: 7.8176, WER: 0.9231, CER: 0.6957
#
# Reference: Please mere liye ek flight incoming alarm fix kare for today at 6 pm .
# Hypothesis: Please aaj 6 pm ke liye ek flight incoming alarm fix kare
# BLEU: 45.6304, WER: 0.6667, CER: 0.4143
#
# Reference: alarm par kitna time bakhi hai
# Hypothesis: alarm ke liye kitna time hai
# BLEU: 19.3049, WER: 0.5000, CER: 0.4333
#
# Reference: 95 . 1 bajaana shuru karo
# Hypothesis: 95. 1 ko bajao
# BLEU: 32.5556, WER: 0.8333, CER: 0.6400
#
# Reference: mujhe dopahar tak St . Paul pahuchne ke liye kab nikalna chahiye ?
# Hypothesis: kya aaj raat St. Paul par noon ke liye yaad dilaayen?
# BLEU: 15.1332, WER: 0.8462, CER: 0.5000
#
# Reference: kya area mei koi free Christmas parties hai
# Hypothesis: kya area ke liye free Christmas parties hai
# BLEU: 41.1134, WER: 0.2500, CER: 0.1395
#
# Reference: mujhe 8 am ko school ke liye tayyar hone ke liye yaad dilaye
# Hypothesis: mujhe school ke liye 8 baje ke liye yaad dilayen
# BLEU: 20.9118, WER: 0.4615, CER: 0.3000
#
# Reference: Tuesday ko kitni garmi hone wali hai ?
# Hypothesis: Tuesday ko kitna hot hai?
# BLEU: 16.4498, WER: 0.7500, CER: 0.3684
#
# Reference: har Friday 1 pm ko housekeeper ke liye paise bachne ke liye reminder set kare
# Hypothesis: har Friday 1 pm ko housekeeper ko money leave karne ke liye reminder set kare
# BLEU: 57.0282, WER: 0.2667, CER: 0.1558
#
# Reference: road trip ke bare mei yaad dilaye
# Hypothesis: road trip ke liye yaad dilaye
# BLEU: 32.1594, WER: 0.2857, CER: 0.2121
#
# Reference: mujhe har Sunday 10 am ko mere alarm ke zariye uthane ke liye bolo .
# Hypothesis: mere alarm ko wake me up at 10 am every Sunday.
# BLEU: 8.5799, WER: 0.9333, CER: 0.6912
#
# Reference: agle hafte ke concerts
# Hypothesis: agle ke liye concerts
# BLEU: 21.0224, WER: 0.5000, CER: 0.3182
#
# Reference: dentist ke liye mere reminder ko delete karo
# Hypothesis: dentist ke liye mere reminder delete kare
# BLEU: 55.7800, WER: 0.2500, CER: 0.0909
#
# Reference: Muje Australia ke mausam ke baarey me bataye
# Hypothesis: mujhe Australia me mausam bataye
# BLEU: 8.2908, WER: 0.6250, CER: 0.3636
#
# Reference: Joyce ke ghar se AT & T center jaate samay traffic se bachne ke liye sabse acha detour konsa hai ?
# Hypothesis: Joyce ke liye AT & T center par traffic kaisa chahiye?
# BLEU: 13.9359, WER: 0.6667, CER: 0.5408
#
# Reference: Kya bahar baarish ho rahi hai ?
# Hypothesis: kya baarish hone wala hai?
# BLEU: 15.2072, WER: 0.8571, CER: 0.4194
#
# Reference: mai mere reminders edit karna chahta hoon
# Hypothesis: mujhe mere reminders edit kare
# BLEU: 26.6543, WER: 0.5714, CER: 0.4390
#
# Reference: mai chahta hu ki time 15th May ko 10 baje band hojaye
# Hypothesis: mujhe 15th May ko 10 baje ke liye time chahiye
# BLEU: 33.6608, WER: 0.7500, CER: 0.6415
#
# Reference: song ko repeat par rakho
# Hypothesis: song ko repeat kare
# BLEU: 46.3078, WER: 0.4000, CER: 0.2917
#
# Reference: construction kaha hai
# Hypothesis: kya construction kya hai
# BLEU: 18.9959, WER: 0.6667, CER: 0.2857
#
# Reference: Kya mere area ke liye koi hurricanes predicted he ?
# Hypothesis: Kya mere area ke liye predicted hurricanes hai?
# BLEU: 44.9185, WER: 0.4000, CER: 0.3922
#
# Reference: mai Tuesday April 18th ko kaam par vapas jaunga , us din subah 7 baje ke liye mere liye alarm banao
# Hypothesis: mujhe Tuesday April 18th ke liye work ke liye yaad dilaye, mujhe alarm banaye for 7 am on that day.
# BLEU: 9.3643, WER: 0.8571, CER: 0.6364
#
# Reference: Kya aaj mujhe skirt pehenna chahiye ?
# Hypothesis: kya mujhe aaj skirt ki chahiye?
# BLEU: 16.5158, WER: 0.8571, CER: 0.4595
#
# Reference: abhi nahi !
# Hypothesis: kya aaj raat hai!
# BLEU: 10.6822, WER: 1.3333, CER: 1.0909
#
# Reference: Agar mai 5 minutes mei nikalta hu aur detours leta hu toh downtown pahunchne me kitna samay lagega ?
# Hypothesis: downtown ke liye yaad dilaye 5 minutes ke liye yaad dilayen?
# BLEU: 4.4947, WER: 1.0000, CER: 0.7500
#
# Reference: Mere paas thursday ke liye kitne reminders he ?
# Hypothesis: Muje Thursday ke liye kitni reminders hai?
# BLEU: 11.5912, WER: 0.6667, CER: 0.2340
#
# Reference: mujhe 16 July ke liye alarm chahiye
# Hypothesis: mujhe 16 July ke liye alarm chahiye
# BLEU: 100.0000, WER: 0.0000, CER: 0.0000
#
# Reference: Aerosmith play kariye
# Hypothesis: Aerosmith me play kare
# BLEU: 18.9959, WER: 0.6667, CER: 0.2381
#
# Reference: haircut karne ke liye mere reminder ko delete kare since i had one today
# Hypothesis: mera reminder ko delete kare to get a haircut since i had one today
# BLEU: 45.7231, WER: 0.6429, CER: 0.5139
#
# Reference: waha bahar kaisa hai
# Hypothesis: kya hai
# BLEU: 18.3940, WER: 0.7500, CER: 0.7000
#
# Reference: temperature kya hai
# Hypothesis: temperature kya hai
# BLEU: 100.0000, WER: 0.0000, CER: 0.0000
#
# Reference: Texas me abhi mausam kaisa hai
# Hypothesis: Texas me aaj mausam kaisa hai
# BLEU: 37.9918, WER: 0.1667, CER: 0.1000
#
# Reference: Mujhe game par time se pohochne ke liye konsa route mujhe time se pahuch sakta hai
# Hypothesis: mere liye game ke liye yaad dilaayen
# BLEU: 4.0185, WER: 0.8750, CER: 0.7439
#
# Reference: snow kab forecast kia gaya tha
# Hypothesis: kya aaj raat snow forecast hone wala hai
# BLEU: 6.5673, WER: 1.1667, CER: 0.7667
#
# Reference: ek naya timer add karo
# Hypothesis: new timer ko add kare
# BLEU: 12.7033, WER: 0.8000, CER: 0.4545
#
# Reference: mai ek minute ke liye set kiya hua ek timer chahiye
# Hypothesis: mujhe minute ke liye timer set kare
# BLEU: 15.6857, WER: 0.7273, CER: 0.4902
#
# Reference: Fri ke liye swim team ke liye alerts ko 4 : 45 ke liye badlein aur sat ko 9 : 45 ke liye badlein
# Hypothesis: swim team ke liye fri alerts change kare to 4 : 45 and sat to 9 : 45
# BLEU: 18.6353, WER: 0.6250, CER: 0.5833
#
# Reference: thunderstorm kab shuru hoga ?
# Hypothesis: kya thunderstorm ke liye yaad dilaye?
# BLEU: 7.8098, WER: 1.0000, CER: 0.6897
#
# Reference: aj ke liye 10 mins ka timer set kare
# Hypothesis: Aaj ke liye 10 mins timer ko put kare
# BLEU: 33.0316, WER: 0.4444, CER: 0.2500
#
# Reference: kya Salem me koi concerts aane wala hai
# Hypothesis: kya Salem mei koi concerts hai
# BLEU: 17.3935, WER: 0.3750, CER: 0.2821
#
# Reference: forecast kya hai ?
# Hypothesis: forecast kya hai?
# BLEU: 100.0000, WER: 0.5000, CER: 0.0556
#
# Reference: groceries ke liye ek weekly reminder set karen .
# Hypothesis: groceries ke liye weekly reminder set kare
# BLEU: 30.8958, WER: 0.3333, CER: 0.1250
#
# Reference: New Mexico se Texas tak kitne miles hai
# Hypothesis: New Mexico se Texas me kitna miles hai
# BLEU: 41.1134, WER: 0.2500, CER: 0.1026
#
# Reference: Kate se pucho ki kya she is going to be late .
# Hypothesis: Kate ko ask karo if she is going to be late.
# BLEU: 53.3168, WER: 0.5000, CER: 0.3043
#
# Reference: Kya abhi Pittsburgh me traffic slow he
# Hypothesis: kya Pittsburgh me aaj traffic kaisa slow hai
# BLEU: 13.1345, WER: 0.7143, CER: 0.4737
#
# Reference: kya mujhe sun glasses pehnna chahiye ya Jacket ?
# Hypothesis: Kya mujhe sun glasses ke liye Jacket ke liye yaad dilaye?
# BLEU: 14.3231, WER: 0.8889, CER: 0.5417
#
# Reference: New York city me is weekend hone wale gaming events ki list
# Hypothesis: Is weekend New York city me gaming events ke liye list hai
# BLEU: 27.0920, WER: 0.7500, CER: 0.6271
#
# Reference: is sunday ko Boat parade kis time par shuru hogi
# Hypothesis: Is Sunday ko Boat parade ke liye yaad dilaye
# BLEU: 15.8811, WER: 0.7000, CER: 0.3958
#
# Reference: traffic jam kitne miles tak he
# Hypothesis: traffic jam me kitna miles kitna hai
# BLEU: 14.5358, WER: 0.6667, CER: 0.3333
#
# Reference: mai dad ke sath mere breakfast ke liye ek reminder chahiye .
# Hypothesis: mujhe dad me breakfast ke liye reminder kiye.
# BLEU: 15.1226, WER: 0.5833, CER: 0.3500
#
# Reference: mere alarm ko 5 ghante me vibrate karne ke liye set kare
# Hypothesis: mere alarm set kare to vibrate in 5 hours
# BLEU: 10.6933, WER: 0.7500, CER: 0.5000
#
# Reference: meri Aunt ko message bhejo
# Hypothesis: mere Aunt ko message send kare
# BLEU: 30.2138, WER: 0.6000, CER: 0.3846
#
# Reference: kuch instrumental music bajao
# Hypothesis: kya instrumental music bajao
# BLEU: 59.4604, WER: 0.2500, CER: 0.1034
#
# Reference: mere meeting alert ka samay Monday 830 pm ke liye badlein
# Hypothesis: Monday ko meri meeting alert ko 830 pm ke liye time ko change kare
# BLEU: 21.9728, WER: 0.9091, CER: 0.7193
#
# Reference: last song ko phir se bajao .
# Hypothesis: last song ko play kare
# BLEU: 26.6543, WER: 0.5714, CER: 0.4286
#
# Reference: is weekend mai kya kar sakta hu
# Hypothesis: Is weekend ke liye yaad dilaayen
# BLEU: 6.8706, WER: 0.8571, CER: 0.5484
#
# Reference: Muje aaj subah 11 baje freezer se chicken nikalane ke liye remind karaye .
# Hypothesis: mujhe aaj 11 AM ke liye chicken ko freezer ko take karne ke liye yaad dilaye
# BLEU: 6.4372, WER: 0.9286, CER: 0.5946
#
# Reference: aj dopahar ko work ke liye order plac karne ke liye reminder set kare
# Hypothesis: Aaj noon ko work order karne ke liye reminder set kare
# BLEU: 40.7163, WER: 0.3571, CER: 0.2899
#
# Reference: Salt Lake City se Spokane tak drive karne mei kitni der lagegi
# Hypothesis: Salt Lake City se Spokane tak drive karne ke liye kitna sakta hai
# BLEU: 55.9368, WER: 0.4167, CER: 0.2258
#
# Reference: Celsius me temperature kya hai ?
# Hypothesis: Celsius me temperature kya hai?
# BLEU: 100.0000, WER: 0.3333, CER: 0.0312
#
# Reference: Agle hafte San Francisco ke paas temperature F me
# Hypothesis: next week ke liye San Francisco ke liye temperature F
# BLEU: 19.6407, WER: 0.6667, CER: 0.4286
#
# Reference: kuch New Years parties kaha hai
# Hypothesis: New Years ke party kya hai
# BLEU: 17.9652, WER: 0.6667, CER: 0.4194
#
# Reference: New York me abhi mausam kaisa hai
# Hypothesis: Aaj New York me mausam kaisa hai
# BLEU: 41.1134, WER: 0.2857, CER: 0.2727
#
# Reference: Mujhe kal tak sabhi emails ko reply karne ke liye yaad dilaayen .
# Hypothesis: mujhe kal sabhi emails reply karne ke liye yaad dilaye
# BLEU: 34.6064, WER: 0.3846, CER: 0.1846
#
# Reference: Kya aaj raat mujhe store se emergency supplies kharidne chahiye
# Hypothesis: Kya aaj raat ke store ke emergency supplies kaisa chahiye
# BLEU: 21.3644, WER: 0.3000, CER: 0.1587
#
# Reference: Agar mai abhi nikal jaoon to mujhe Carpenter par imax tak pahunchne me kitna samay lagega .
# Hypothesis: kya aaj Carpenter mei imax ke liye yaad dilaayen.
# BLEU: 2.7423, WER: 0.8824, CER: 0.6593
#
# Reference: Please mujhe taxes file karne ke liye yaad dilaye
# Hypothesis: Please mujhe taxes file karne ke liye yaad dilaayen
# BLEU: 86.3340, WER: 0.1111, CER: 0.0408
#
# Reference: alarm ko 7 am se 6 am tak badal do
# Hypothesis: alarm change kare at 7 am to 6 am
# BLEU: 12.7593, WER: 0.7000, CER: 0.6176
#
# Reference: aaj kitni thand hogi ?
# Hypothesis: aj kitna cold hai?
# BLEU: 10.6822, WER: 1.0000, CER: 0.4091
#
# Reference: abhi work se Joe tak pohochne me kitna time lagega ?
# Hypothesis: Joe's ke liye aaj work ke liye kitna sakta hai?
# BLEU: 4.9324, WER: 0.9091, CER: 0.6538
#
# Reference: har hafte alarm ko repeat kare
# Hypothesis: agle ke liye alarm ko repeat kare
# BLEU: 41.1134, WER: 0.5000, CER: 0.3333
#
# Reference: aj kitni garmi hai
# Hypothesis: Aaj kitni hot hai
# BLEU: 18.9959, WER: 0.5000, CER: 0.3333
#
# Reference: Is weekend chicago me kitni barf padegi ?
# Hypothesis: chicago mei this weekend ke liye kitna snow hai?
# BLEU: 5.5224, WER: 1.1250, CER: 0.8293
#
# Reference: 3 00 pm ko 10 minutes ke liye daily timer set kare
# Hypothesis: 10 minutes ke liye daily timer set kare
# BLEU: 60.6531, WER: 0.3333, CER: 0.2200
#
# Reference: Kya Minneapolis me is weekend koi naye nightclubs khul rahe he
# Hypothesis: Is weekend Minneapolis me koi new nightclubs opening hai
# BLEU: 9.6010, WER: 0.7273, CER: 0.5645
#
# Reference: Mere timer par kitna time bacha he ?
# Hypothesis: mere timer me kitna time chahiye?
# BLEU: 13.5404, WER: 0.6250, CER: 0.2778
#
# Reference: mere current playlist me kendrick lamar ka album DAMN ko add karen .
# Hypothesis: mere current playlist me kendrick lamar album DAMN ko add kare
# BLEU: 58.5034, WER: 0.2308, CER: 0.0882
#
# Reference: is week ke liye sun kab forecast me hai ?
# Hypothesis: this week ke liye sun ka forecast kya hai?
# BLEU: 32.4668, WER: 0.5000, CER: 0.1707
#
# Reference: mere bhai ko bolo ki Mentor Library is hosting a Dahmer reading tonight .
# Hypothesis: meri brother ke liye Mentor Library ko aaj Dahmer reading ko hosting kare
# BLEU: 8.9534, WER: 0.7857, CER: 0.4932
#
# Reference: Aaj ki wind speed kya hogi ?
# Hypothesis: aj wind speed kya hai?
# BLEU: 27.4825, WER: 0.5714, CER: 0.2500
#
# Reference: Muje Legoland tak pohochne me kitna time lagega
# Hypothesis: mujhe Legoland me kitna kitna sakta hai
# BLEU: 12.6007, WER: 0.7500, CER: 0.5319
#
# Reference: Kya aap aaj raat ke liye mera alarm cancel karsakte hai ?
# Hypothesis: kya aaj raat ke alarm cancel kare?
# BLEU: 16.4091, WER: 0.5833, CER: 0.4211
#
# Reference: Please agla song play kare
# Hypothesis: Please next song play kare
# BLEU: 42.7287, WER: 0.2000, CER: 0.1538
#
# Reference: kal Orlando me karne ke liye chize
# Hypothesis: Orlando me kal ke liye yaad dilaayen
# BLEU: 19.6407, WER: 0.5714, CER: 0.5294
#
# Reference: mujhe library se kitne baje nikal na chahiye 6PM tak work par pahunchne ke liye
# Hypothesis: mujhe 6PM ke liye library ke liye time kaisa chahiye?
# BLEU: 6.8574, WER: 0.9333, CER: 0.6709
#
# Reference: Do minutes ke liye har 30 second me alarm set kare
# Hypothesis: alarm set kare for every 30 seconds for two minutes
# BLEU: 16.0585, WER: 0.9091, CER: 0.7000
#
# Reference: mere timer me ek aur 2 hours add kare
# Hypothesis: mere timer me 2 hours add kare
# BLEU: 44.6831, WER: 0.2222, CER: 0.1892
#
# Reference: Mere paas monday , August 20th ke liye konse reminders he ?
# Hypothesis: Monday, August 20th ke liye reminders kaisa hai?
# BLEU: 34.9833, WER: 0.5833, CER: 0.4237
#
# Reference: Miami me karne ke liye cheeze
# Hypothesis: Miami ke liye ek things to do in general
# BLEU: 10.5527, WER: 1.3333, CER: 0.8966
#
# Reference: mujhe 9 am se pehle coffee pot band karne ke liye yaad dilaye
# Hypothesis: mujhe 9 baje ke liye coffee pot ko off kare.
# BLEU: 10.8243, WER: 0.6923, CER: 0.5574
#
# Reference: Mera alarm kab tak band rahega ?
# Hypothesis: mere alarm ko band karne ke liye kitne ke liye yaad dilayen?
# BLEU: 4.0654, WER: 1.5714, CER: 1.2188
#
# Reference: Annie ko ek response bhejo
# Hypothesis: Annie ko response send kare
# BLEU: 23.6435, WER: 0.6000, CER: 0.4615
#
# Reference: alarm ko on karo
# Hypothesis: alarm ko shuru kare
# BLEU: 31.9472, WER: 0.5000, CER: 0.3750
#
# Reference: 2 min 30 sec ke liye timer set karo
# Hypothesis: 2 min 30 sec ke liye timer set kare
# BLEU: 86.3340, WER: 0.1111, CER: 0.0286
#
# Reference: kya aap proofing ke liye timer ko pause karsakte hai
# Hypothesis: kya timer ko proofing pause ke liye yaad dilaye
# BLEU: 13.8790, WER: 0.8000, CER: 0.6731
#
# Reference: aas paas kuch mazedaar chizein chal rahe hai
# Hypothesis: Aaj raat ke liye kya fun things hai
# BLEU: 5.5224, WER: 0.8750, CER: 0.6364
#
# Reference: reminder location badlein
# Hypothesis: reminder location ko change kare
# BLEU: 21.3644, WER: 1.0000, CER: 0.4800
#
# Reference: 16th ko 1 am ke liye ek alarm set karen .
# Hypothesis: 16th ke 1 a. m ke liye alarm set kare
# BLEU: 12.1921, WER: 0.5455, CER: 0.2195
#
# Reference: running timer ko pause karo
# Hypothesis: running timer ko pause kare
# BLEU: 66.8740, WER: 0.2000, CER: 0.0370
#
# Reference: rest of the year ke liye moms group meetings ke sarey reminders pull up kare
# Hypothesis: rest of the year ke liye moms group meetings ke liye reminders pull kare
# BLEU: 69.0797, WER: 0.1333, CER: 0.0921
#
# Reference: thursday ka weather kya hai ?
# Hypothesis: thursday ke liye weather kya hai?
# BLEU: 43.4721, WER: 0.6667, CER: 0.2414
#
# Reference: Los Angeles me traffic
# Hypothesis: Los Angeles me traffic
# BLEU: 100.0000, WER: 0.0000, CER: 0.0000
#
# Reference: kya aj barish hogi
# Hypothesis: Kya aaj baarish hone wali hai
# BLEU: 0.0000, WER: 1.5000, CER: 0.7222
#
# Reference: traffic kaisa delay causing hai
# Hypothesis: traffic ke liye yaad dilaayen
# BLEU: 10.6822, WER: 0.8000, CER: 0.6129
#
# Reference: Phoenix mei Family events hai
# Hypothesis: Phoenix me family events
# BLEU: 14.7940, WER: 0.6000, CER: 0.2069
#
# Reference: kal library books return karne ke liye reminder add karen
# Hypothesis: kal library books return ko reminder add kare
# BLEU: 32.0191, WER: 0.4000, CER: 0.2281
#
# Reference: mere pati ko bolo ki maine saturday subah 10 bajhe ke liye spa date booked kar diya hai
# Hypothesis: mere wife ko raat 10 baje ke liye yaad dilaayen ki ke liye yaad dilaayen
# BLEU: 5.6633, WER: 0.7778, CER: 0.6207
#
# Reference: middlebury aur chicago ke beech ka distance kitna hai
# Hypothesis: middlebury ke chicago me distance kya hai
# BLEU: 7.3798, WER: 0.5556, CER: 0.3019
#
# Reference: Please Julie ko message bhejkar pucho ki where the festival is at this weekend .
# Hypothesis: Please Julie ko message karo asking her where the festival is at this weekend.
# BLEU: 64.7545, WER: 0.3333, CER: 0.1875
#
# Reference: Hawai me sunset kab hai
# Hypothesis: Hawaii me sunset kaisa hai
# BLEU: 23.6435, WER: 0.4000, CER: 0.1739
#
# Reference: Mere liye mom ka last message padker sunaiye
# Hypothesis: mujhe mom me last message ko read kare
# BLEU: 12.2231, WER: 0.7500, CER: 0.4773
#
# Reference: New South Wales ke liye weather Outlook kya hai ?
# Hypothesis: New South Wales me weather ke liye Outlook?
# BLEU: 22.4592, WER: 0.6000, CER: 0.4082
#
# Reference: mere timer ko restart kare
# Hypothesis: mere timer ko restart kare
# BLEU: 100.0000, WER: 0.0000, CER: 0.0000
#
# Reference: London me teen din me mausam kaisa hone wala hai ?
# Hypothesis: London me three days ke liye weather kaisa hai?
# BLEU: 11.3551, WER: 0.8182, CER: 0.5000
#
# Reference: please holiday bash ke reminder ko cancel kardo
# Hypothesis: Please holiday bash ke reminder cancel kare
# BLEU: 37.6850, WER: 0.3750, CER: 0.1277
#
# Reference: agla song
# Hypothesis: next song
# BLEU: 50.0000, WER: 0.5000, CER: 0.4444
#
# Reference: Mark ko text bheje
# Hypothesis: Mark ko text kare
# BLEU: 59.4604, WER: 0.2500, CER: 0.2222
#
# Reference: kya aap kuch bhi karsakte hai jo mujhe laugh karne ke liye motive kare
# Hypothesis: kya aap mujhe ke liye yaad dilaayen
# BLEU: 7.2254, WER: 0.6429, CER: 0.6857
#
# Reference: egg timer ko drop kare
# Hypothesis: egg timer ko drop kare
# BLEU: 100.0000, WER: 0.0000, CER: 0.0000
#
# Reference: music ko on karo please
# Hypothesis: please music ko shuru kare
# BLEU: 23.6435, WER: 0.8000, CER: 0.7391
#
# Reference: mere music ko rok do
# Hypothesis: mere music ko pause kare
# BLEU: 39.7635, WER: 0.4000, CER: 0.4500
#
# Reference: mere time ko resume kardo
# Hypothesis: mere time ke liye tracking resume kare
# BLEU: 14.5358, WER: 0.8000, CER: 0.6800
#
# Reference: Kya aaj flooding hone ke chances he ?
# Hypothesis: kya aaj raat flash flooding hai?
# BLEU: 7.4924, WER: 0.8750, CER: 0.6486
#
# Reference: Aaj event se 1 ghanta pehle ke liye reminders ko dikhayen
# Hypothesis: Aaj raat event ke liye ek reminders set kare
# BLEU: 9.6010, WER: 0.7273, CER: 0.5088
#
# Reference: September 1st ke liye mujhe mere saarey reminders dikhao .
# Hypothesis: mujhe September 1st ke liye mere reminders dikhao
# BLEU: 34.4068, WER: 0.4000, CER: 0.3621
#
# Reference: is saal maine kachra baahar nikalne ke liye kitne reminders gehae hai ?
# Hypothesis: Is year ke liye kitni reminders kitna sakta hai?
# BLEU: 9.2968, WER: 0.7692, CER: 0.5915
#
# Reference: last track ko fir se chalaye please
# Hypothesis: please last track ko repeat kare
# BLEU: 27.4825, WER: 0.7143, CER: 0.6286
#
# Reference: 10 minutes ke liye timer ko set kare
# Hypothesis: mere phone timer 10 minutes ke liye set kare
# BLEU: 36.8894, WER: 0.6250, CER: 0.7222
#
# Reference: please abhi chats ko dikhao
# Hypothesis: please aj chats ko look kare
# BLEU: 17.9652, WER: 0.6000, CER: 0.3704
#
# Reference: Bournemouth me kal ke liye mausam kaisa hai
# Hypothesis: Bournemouth me kal ka weather kaisa hai
# BLEU: 26.6473, WER: 0.3750, CER: 0.2326
#
# Reference: Kya humko ice storm milne wala he
# Hypothesis: kya ice storm kaisa hai
# BLEU: 14.3210, WER: 0.7143, CER: 0.5455
#
# Reference: mere playlist me track ko add karen
# Hypothesis: mere playlist me track ko add kare
# BLEU: 80.9107, WER: 0.1429, CER: 0.0286
#
# Reference: kal kya ho raha he
# Hypothesis: kal ke liye yaad dilaye
# BLEU: 10.6822, WER: 0.8000, CER: 0.7778
#
# Reference: 45 seconds ke liye timer set karen .
# Hypothesis: 45 seconds ke liye timer set kare
# BLEU: 70.1397, WER: 0.2500, CER: 0.0833
#
# Reference: yaha se Niagara Falls , Canada tak kitne miles hai
# Hypothesis: Niagara Falls, Canada me kitni miles hai
# BLEU: 32.0191, WER: 0.6000, CER: 0.2600
#
# Reference: kya mujhe current traffic me Tracy ke ghar pahunchne me ek ghante se zyada lagega ?
# Hypothesis: Kya aap mujhe Tracy ke liye current traffic ke liye yaad dilaayen?
# BLEU: 7.6766, WER: 0.8750, CER: 0.6867
#
# Reference: meeting ke liye reminder ko delete kare
# Hypothesis: meeting ke reminder ko delete kare
# BLEU: 51.1508, WER: 0.1429, CER: 0.1282
#
# Reference: 10 30 second intervals ke liye timer set kare
# Hypothesis: 10 30 second intervals ke liye timer set kare
# BLEU: 100.0000, WER: 0.0000, CER: 0.0000
#
# Reference: grocery list reminder me Spinach aur onions ko add karen
# Hypothesis: grocery list ke reminder ke spinach and onions add kare
# BLEU: 10.5527, WER: 0.6000, CER: 0.1964
#
# Reference: classical music play karo
# Hypothesis: classical music bajao
# BLEU: 39.4322, WER: 0.5000, CER: 0.2400
#
# Reference: agla song bajao
# Hypothesis: next song ko play kare
# BLEU: 10.6822, WER: 1.3333, CER: 0.9333
#
# Reference: Monday 18th June ko subah 9 bajhe ke liye ek naye alarm ko create karen
# Hypothesis: Monday 18th June ko 9 am ke liye ek naya alarm create kare
# BLEU: 26.2168, WER: 0.3333, CER: 0.2113
#
# Reference: is gaaney ko restart kare
# Hypothesis: this song ko restart kare
# BLEU: 39.7635, WER: 0.4000, CER: 0.2800
#
# Reference: kya aaj roads wet hone wale hai ?
# Hypothesis: Kya aaj roads kaisa he?
# BLEU: 12.8726, WER: 0.7500, CER: 0.4848
#
# Reference: Seattle me pet friendly hotels
# Hypothesis: Seattle me pet friendly hotels
# BLEU: 100.0000, WER: 0.0000, CER: 0.0000
#
# Reference: Orlando me abhi humidity
# Hypothesis: Aaj Orlando me humidity hai
# BLEU: 23.6435, WER: 0.7500, CER: 0.5417
#
# Reference: kya mai coat la sakta hoon
# Hypothesis: kya aap coat ko bring kare
# BLEU: 9.6524, WER: 0.6667, CER: 0.5000
#
# Reference: ek naya alarm set karo
# Hypothesis: naya alarm set kare
# BLEU: 46.3078, WER: 0.4000, CER: 0.1818
#
# Reference: mujhe sabhi alarms dikhao
# Hypothesis: mujhe sabhi alarms dikhao
# BLEU: 100.0000, WER: 0.0000, CER: 0.0000
#
# Reference: 30 seconds ke liye timer set karen
# Hypothesis: 30 seconds ke liye timer set kare
# BLEU: 80.9107, WER: 0.1429, CER: 0.0294
#
# Reference: Sunday ko kitna cold hone wala he ?
# Hypothesis: Sunday me kitna cold hone wala hai?
# BLEU: 38.2603, WER: 0.3750, CER: 0.1143
#
# Reference: Kya aap mujhe bata sakte hai Kabul me mausam kaisa hai ?
# Hypothesis: Kya mujhe Kabul me mausam kaisa hai?
# BLEU: 44.3441, WER: 0.5000, CER: 0.3571
#
# Reference: Mujhe yaad dilao ki Friday 2 30 pm ko Skylee ko doctor ki appointment hai .
# Hypothesis: Muje remind karaye that Skylee has a doctor's appointment on Friday at 2:30 pm
# BLEU: 6.4372, WER: 1.0000, CER: 0.6800
#
# Reference: laurie ko message karo ki i am on the ferry and will be 20 minutes late
# Hypothesis: laurie ko message kare ki ki ki ki ferry ke liye yaad dilaye ki 20 minutes late
# BLEU: 15.3848, WER: 0.6250, CER: 0.3380
#
# Reference: chicago aur denver ke beech ka distance kitna hai
# Hypothesis: chicago aur denver ke liye distance hai
# BLEU: 34.1918, WER: 0.3333, CER: 0.2857
#
# Reference: Kya aaj raat ko muje winter coat pehenna chahiye
# Hypothesis: Kya aaj raat winter coat ke liye mujhe he
# BLEU: 22.3162, WER: 0.6667, CER: 0.4167
#
# Reference: 640 ke liye alarm lagaye
# Hypothesis: 640 ke liye alarm set kare
# BLEU: 50.8133, WER: 0.4000, CER: 0.2500
#
# Reference: kya agle mahine baarish hone ke koi chance hai
# Hypothesis: Kya aaj raat rain ka chance hai
# BLEU: 9.8703, WER: 0.7778, CER: 0.5000
#
# Reference: kya agle saal Broward Center mei koi Andre Rieu ke concerts aane wale hai
# Hypothesis: kya aaj raat Broward Center mei Andre Rieu concerts hai
# BLEU: 14.8071, WER: 0.4286, CER: 0.3014
#
# Reference: mai airport jaane ke liye kitne routes choose kar sakta hoon
# Hypothesis: airport me kitna routes ke liye yaad dilaayen
# BLEU: 9.0272, WER: 0.8182, CER: 0.5667
#
# Reference: meri mom ko milne ke liye mujhe reminder dikhao
# Hypothesis: mujhe mere mom ko meet karne ke liye reminder bataye
# BLEU: 13.1345, WER: 0.6667, CER: 0.5532
#
# Reference: Mujhe aj raat ko garden ko water karne ke liye yaad dilaye
# Hypothesis: mujhe aaj raat garden ko water karo
# BLEU: 12.8598, WER: 0.6667, CER: 0.4655
#
# Reference: 10 am aur 11 am ke liye alarms set karen .
# Hypothesis: 10 am aur 11 am ke liye alarms set kare
# BLEU: 79.6358, WER: 0.1818, CER: 0.0714
#
# Reference: pollen count kitna hai
# Hypothesis: pollen count kya hai
# BLEU: 35.3553, WER: 0.2500, CER: 0.1364
#
# Reference: Is weekend Jackson me Music events hai
# Hypothesis: Is weekend Jackson me music events
# BLEU: 45.4802, WER: 0.2857, CER: 0.1316
#
# Reference: midnight ka alarm set kare
# Hypothesis: Midnight alarm
# BLEU: 11.1565, WER: 0.8000, CER: 0.5000
#
# Reference: kya hiking group chat par kuch hai ?
# Hypothesis: kya hiking group chat ke liye hai?
# BLEU: 41.1134, WER: 0.5000, CER: 0.2222
#
# Reference: route 301 kitna busy hai
# Hypothesis: route 301 me busy kya hai
# BLEU: 19.3049, WER: 0.4000, CER: 0.3750
#
# Reference: is gaaney ko repeat par rakhiye
# Hypothesis: this song ko repeat kare
# BLEU: 17.4917, WER: 0.6667, CER: 0.4839
#
# Reference: Mikayla ko text karo ki i didn ' t see him doing that yesterday '
# Hypothesis: Mikayla ko text kare'i didn't see him doing that yesterday '
# BLEU: 40.8556, WER: 0.4000, CER: 0.1077
#
# Reference: mera agla alarm kis liye hai
# Hypothesis: mere next alarm kya hai
# BLEU: 10.4006, WER: 0.6667, CER: 0.3929
#
# Reference: mujhe har raat 9 pm tak mera alarm set karne ke liye yaad dilaayen
# Hypothesis: mujhe aaj raat 9 baje ke liye mere alarm set karen
# BLEU: 10.2720, WER: 0.7143, CER: 0.5455
#
# Reference: kya abhi koi snow storms aane wale hai ?
# Hypothesis: Kya aaj raat snow storms hai?
# BLEU: 13.9587, WER: 0.7778, CER: 0.4750
#
# Reference: Stone sour song # 3 ko bajao
# Hypothesis: Stone sour song # 3 bajao
# BLEU: 67.3182, WER: 0.1429, CER: 0.1071
#
# Reference: West Palm Beach FL me turnpike par traffic kaisa hai
# Hypothesis: West Palm Beach FL me turnpike me traffic kaisa hai
# BLEU: 65.8037, WER: 0.1000, CER: 0.0577
#
# Reference: mere timer me 5 minute add kardo
# Hypothesis: mere timer me 5 minutes add kare
# BLEU: 43.4721, WER: 0.2857, CER: 0.0938
#
# Reference: kya taylor swift town mei aane wali hai
# Hypothesis: kya taylor swift ke liye yaad dilaye
# BLEU: 21.1918, WER: 0.6250, CER: 0.4359
#
# Reference: timer pause kare
# Hypothesis: timer ko pause kare please
# BLEU: 23.6435, WER: 0.6667, CER: 0.6250
#
# ...
#
# Reference: kya Mandy ke ghar jaane ke liye roads saaf hai
# Hypothesis: kya Mandy ke house ke liye roads clear hai
# BLEU: 27.7581, WER: 0.3000, CER: 0.2609
#
# Reference: Morgan Hill mei weather kaisa hai
# Hypothesis: Morgan Hill me mausam kaisa hai
# BLEU: 22.9575, WER: 0.3333, CER: 0.2121
#
# Reference: is gaaney ko repeat par rakhiye
# Hypothesis: this song ko repeat kare
# BLEU: 17.4917, WER: 0.6667, CER: 0.4839
#
# Reference: nyc mei marathon
# Hypothesis: nyc me marathon
# BLEU: 34.6681, WER: 0.3333, CER: 0.0625
#
# Reference: Kya aaj San Francisco me traffic bhaari hai
# Hypothesis: kya aaj San Francisco me traffic heavy hai
# BLEU: 54.1082, WER: 0.2500, CER: 0.1163
#
# Reference: 30 minute ke liye har 5 minute mei alarm set kare
# Hypothesis: 30 minutes ke liye alarm set kare for every 5 minutes
# BLEU: 19.0817, WER: 0.7273, CER: 0.5306
#
# Reference: Please mere chat requests ko retrieve kare
# Hypothesis: please mere chat requests ko retrieve kare
# BLEU: 80.9107, WER: 0.1429, CER: 0.0238
#
# Reference: Altamonte ke aas pas Swimming lessons
# Hypothesis: Altamonte me swimming lessons
# BLEU: 11.5216, WER: 0.6667, CER: 0.2432
#
# Reference: kya aaj mujhe jacket pahanani chahiye ?
# Hypothesis: kya aaj mujhe jacket ki chahiye?
# BLEU: 48.8923, WER: 0.4286, CER: 0.2051
#
# Reference: kya maine kal mere doctor ko text kia
# Hypothesis: kya aaj mujhe meri doctor text kare?
# BLEU: 7.2679, WER: 0.6250, CER: 0.4324
#
# Reference: Arthur ko message karo ki A big big boat .
# Hypothesis: Arthur A big big boat ko message kare
# BLEU: 33.2771, WER: 0.7000, CER: 0.6667
#
# Reference: mere area me sabse zyada bhaari traffic kahan par hai
# Hypothesis: mere area me traffic kaisa heaviest hai
# BLEU: 18.0945, WER: 0.5000, CER: 0.5472
#
# Reference: group message par thumbs up reaction bheje
# Hypothesis: group message ko thumbs up reaction send kare
# BLEU: 25.8487, WER: 0.4286, CER: 0.2619
#
# Reference: mujhe mere ghar se Minneapolis ke liye directions chahiye , while taking a detour through Arkansas .
# Hypothesis: mujhe mere house ke Minneapolis me directions chahiye, while taking a detour through Arkansas.
# BLEU: 61.1456, WER: 0.4706, CER: 0.1400
#
# Reference: Please , weather report bheje .
# Hypothesis: please, weather report.
# BLEU: 34.9833, WER: 0.8333, CER: 0.2903
#
# Reference: last song ko reply kare
# Hypothesis: last song ko play kare
# BLEU: 42.7287, WER: 0.2000, CER: 0.1304
#
# Reference: mujhe supermarket tak drive karke jaane me kitna samay lagega
# Hypothesis: supermarket ke liye drive karne ke liye kitna chahiye
# BLEU: 5.6148, WER: 0.8000, CER: 0.5082
#
# Reference: RUSS ko message karo aur pucho ki WHEN HIS MOTHER WILL BE AT THE AIRPORT NEXT WEEK .
# Hypothesis: RUSS MESSAGE & HIM ko apne ke liye yaad dilaye WHEN HIS MOTHER WILL BE AT THE AIRPORT NEXT WEEK
# BLEU: 47.7559, WER: 0.5000, CER: 0.4405
#
# Reference: kya Montgomery me is subha traffic kharab hai
# Hypothesis: kya aaj Montgomery me traffic kaisa hai
# BLEU: 14.3172, WER: 0.5000, CER: 0.3778
#
# Reference: aaj 6 baje ke liye ek nap alarm set karen
# Hypothesis: aj 6 baje ke liye nap alarm set kare
# BLEU: 38.6275, WER: 0.3000, CER: 0.1220
#
# Reference: Mujhe thursday 2 pm ko meri dentist appointment ke baare me yaad dilaayen
# Hypothesis: mujhe thursday 2 pm ko meri dentist appointment ke liye yaad dilaye
# BLEU: 58.1059, WER: 0.3077, CER: 0.1370
#
# Reference: Devin Jones ko ek voice message bhejo
# Hypothesis: Devin Jones ko voice message ko shoot kare
# BLEU: 25.8487, WER: 0.5714, CER: 0.4054
#
# Reference: Staten Island se Perth Amboy tak traffic driving kya hai
# Hypothesis: Staten Island se Perth Amboy me traffic driving kaisa hai
# BLEU: 46.7138, WER: 0.2000, CER: 0.1071
#
# Reference: Crystal Lake tak jane ke liye kitni der lagegi
# Hypothesis: Crystal Lake me kitna kitna kitna sakta hai
# BLEU: 9.7470, WER: 0.7778, CER: 0.4783
#
# Reference: saare alarms band karo
# Hypothesis: sabhi alarms ko off kare
# BLEU: 10.6822, WER: 1.0000, CER: 0.4545
#
# Reference: iheartradio par Y 102 5 station ko play kare
# Hypothesis: iheartradio me Y 102 5 station play kare
# BLEU: 37.7079, WER: 0.2222, CER: 0.1364
#
# Reference: Is subha alarm sounds ko hata den
# Hypothesis: Is morning ke liye alarm sounds ko remove kare
# BLEU: 19.0708, WER: 0.7143, CER: 0.7576
#
# Reference: Saturday ke liye kya forecast hai
# Hypothesis: Saturday ka forecast kya hai?
# BLEU: 11.4787, WER: 0.6667, CER: 0.4242
#
# Reference: mujhe 6 baje hits hone par yaad dilaayen
# Hypothesis: mujhe 6 baje ke liye yaad dilaye
# BLEU: 22.7721, WER: 0.5000, CER: 0.3250
#
# Reference: Texas ke liye weather bataye please
# Hypothesis: Texas me mausam kaisa hai
# BLEU: 8.7458, WER: 0.8333, CER: 0.6286
#
# Reference: Kya aaj mujhe apne saath umbrella laana chahiye ?
# Hypothesis: kya aaj mujhe umbrella bring kare?
# BLEU: 11.7378, WER: 0.6667, CER: 0.4490
#
# Reference: sixth timer ko update kare
# Hypothesis: sixth timer ko update kare
# BLEU: 100.0000, WER: 0.0000, CER: 0.0000
#
# Reference: kya route 66 par traffic hai
# Hypothesis: kya route 66 ke liye backed up he
# BLEU: 20.5567, WER: 0.8333, CER: 0.6429
#
# Reference: fathers day card kharidne ka reminder chahiye
# Hypothesis: fathers day card ke liye reminder ko shuru kare
# BLEU: 19.0708, WER: 0.7143, CER: 0.4222
#
# Reference: workout timer par kitna time bacha hai
# Hypothesis: workout timer me kitna time chahiye
# BLEU: 19.4331, WER: 0.4286, CER: 0.2368
#
# Reference: playlist ko display kare
# Hypothesis: playlist ko display kare
# BLEU: 100.0000, WER: 0.0000, CER: 0.0000
#
# Reference: classical music play karo
# Hypothesis: classical music bajao
# BLEU: 39.4322, WER: 0.5000, CER: 0.2400
#
# Reference: Mujhe aj ke liye work ke mere reminders dijiye
# Hypothesis: mujhe aaj ke liye work ke liye reminders bataye
# BLEU: 31.5598, WER: 0.4444, CER: 0.1957
#
# Reference: mere aas paas comic - con
# Hypothesis: mere liye Comic - Con
# BLEU: 10.4006, WER: 0.6667, CER: 0.4000
#
# Reference: 5 ghante ke liye timer set kardo
# Hypothesis: 5 hours ke liye timer set kare
# BLEU: 43.4721, WER: 0.2857, CER: 0.2188
#
# Reference: mai Beyonce ka latest album sunna chahta hoon
# Hypothesis: mujhe latest Beyonce album ko listen kare.
# BLEU: 7.2679, WER: 0.8750, CER: 0.7556
#
# Reference: Mera alarm kab tak band rahega ?
# Hypothesis: mere alarm ko band karne ke liye kitne ke liye yaad dilayen?
# BLEU: 4.0654, WER: 1.5714, CER: 1.2188
#
# Reference: mujhe Yonkers se White Plains tak ka time batao
# Hypothesis: Muje Yonkers se White Plains me time ko bataye.
# BLEU: 27.7762, WER: 0.5556, CER: 0.2979
#
# Reference: kya aj 100 degrees se zyada hone wala hai ?
# Hypothesis: Kya aaj raat over 100 degrees hone wala hai?
# BLEU: 31.2394, WER: 0.8000, CER: 0.4884
#
# Reference: I - 30 par dopaher ke aas paas traffic kitna zada hai
# Hypothesis: I - 30 ke liye traffic kitna heavy hai
# BLEU: 17.3935, WER: 0.4167, CER: 0.4528
#
# Reference: Tuesday ke liye mausam kaisa hoga
# Hypothesis: Tuesday me mausam kaisa hai
# BLEU: 19.3577, WER: 0.5000, CER: 0.2727
#
# Reference: Florida se California tak ki doori kitni hai
# Hypothesis: Florida se California ke liye distance hai
# BLEU: 22.7721, WER: 0.5000, CER: 0.3409
#
# Reference: do tracks wapas jaayen
# Hypothesis: two tracks ke liye go back
# BLEU: 8.1167, WER: 1.2500, CER: 0.7273
#
# Reference: mujhe David ko text bhejna hai . kya ap mujhe 3 : 30 bajhe yaad dila sakte hai .
# Hypothesis: mujhe David ko text kare. kya aap mujhe 3 : 30 ke liye remind kare.
# BLEU: 28.6487, WER: 0.5263, CER: 0.4000
#
# Reference: Philly me Wine tasting meetups
# Hypothesis: Philly me wine tasting meetups
# BLEU: 30.2138, WER: 0.2000, CER: 0.0333
#
# Reference: today long beach par waves kitne bhari hai
# Hypothesis: Aaj Long beach mei waves kaisa hai
# BLEU: 7.4924, WER: 0.6250, CER: 0.4048
#
# Reference: Kya hum lightning ki ummeed karsakte hai ?
# Hypothesis: kya mujhe lightning ke liye yaad dilaye?
# BLEU: 6.5673, WER: 0.8750, CER: 0.5000
#
# Reference: Natalie Grant ke Concerts
# Hypothesis: Natalie Grant me Concerts
# BLEU: 35.3553, WER: 0.2500, CER: 0.0400
#
# Reference: Mera next church meeting ka reminder kab he ?
# Hypothesis: mere next church meeting reminder kya he?
# BLEU: 23.8752, WER: 0.5556, CER: 0.1778
#
# Reference: Mera alarm kab tak band rahega ?
# Hypothesis: mere alarm ko shuru karne ke liye kitna time chahiye?
# BLEU: 4.4569, WER: 1.2857, CER: 1.0625
#
# Reference: joselyn ki wedding ke liye June 10th ko , 2019 ka reminder banaye
# Hypothesis: joselyn ke wedding ke liye reminder create kare on June 10th, 2019
# BLEU: 17.9965, WER: 0.6923, CER: 0.5385
#
# Reference: Please har dusre din weight check ke liye ek reminder set karen .
# Hypothesis: Please every other day ko weight check ke liye reminder set kare.
# BLEU: 24.7124, WER: 0.5385, CER: 0.2923
#
# Reference: 2 minutes ke liye timer set karen
# Hypothesis: 2 minutes ke liye timer set kare
# BLEU: 80.9107, WER: 0.1429, CER: 0.0303
#
# Reference: timer par kitna samay hai ?
# Hypothesis: timer me kitna long hone wala hai
# BLEU: 8.6430, WER: 0.8333, CER: 0.6667
#
# Reference: Please meri music playlist ko play kare .
# Hypothesis: Please meri music playlist play kare
# BLEU: 43.2982, WER: 0.2500, CER: 0.1220
#
# Reference: Brady aur Jackson ko alert kare ki 3 baje mujhe nikalna hai ; unhe ek ghante pehle alert kare
# Hypothesis: Brady and Jackson ko remind karo ki we need to leave at 3 ; alert them an hour before.
# BLEU: 5.2375, WER: 0.7895, CER: 0.5806
#
# Reference: mai is traffic se kaise nikal sakta hoon
# Hypothesis: kya aaj raat traffic ke liye hai
# BLEU: 5.6930, WER: 1.0000, CER: 0.7250
#
# Reference: alarm ko reset karen
# Hypothesis: alarm ko reset kare
# BLEU: 59.4604, WER: 0.2500, CER: 0.0500
#
# Reference: Frank ko message karo ki mai ten o ’ clock tak apke ghar par rahunga !
# Hypothesis: Frank ko message karo ki I will be at your place by ten o ’ clock!
# BLEU: 36.8214, WER: 0.6875, CER: 0.5143
#
# Reference: Mere timer par kitna time bacha he ?
# Hypothesis: mere timer me kitna time chahiye
# BLEU: 12.8726, WER: 0.6250, CER: 0.2778
#
# Reference: yaha se Tampa , Florida tak kitne miles hai
# Hypothesis: Tampa, Florida me kitna miles hai
# BLEU: 23.1000, WER: 0.6667, CER: 0.3023
#
# Reference: Kya New York me thand hogi
# Hypothesis: Kya New York me cold hone wala hai?
# BLEU: 29.8475, WER: 0.6667, CER: 0.5769
#
# Reference: mile run ke liye mera timer set karen
# Hypothesis: mere mile run ke liye timer set kare
# BLEU: 41.1134, WER: 0.3750, CER: 0.2973
#
# Reference: kya kal subha road flooded hogaya tha ?
# Hypothesis: kya aaj road kaisa hai?
# BLEU: 7.6541, WER: 0.7500, CER: 0.5897
#
# Reference: Brad ko message karo aur pucho ke if he has my keys
# Hypothesis: Brad ko message karo ki and ask if he has my keys
# BLEU: 53.1073, WER: 0.2500, CER: 0.1961
#
# Reference: New York me next weekend par kuch hone wala hai
# Hypothesis: kya New York me next weekend ke liye yaad dilaayen
# BLEU: 39.2815, WER: 0.6000, CER: 0.4468
#
# Reference: kya meri ma ke ghar ke raaste me koi detours hai
# Hypothesis: mujhe mere mothers house me road ke liye yaad dilaayen
# BLEU: 4.5152, WER: 1.0000, CER: 0.7917
#
# Reference: yaha se mujhe Neimen tak pahunchne me kitna samay lagega ?
# Hypothesis: mujhe Neimen ke liye kitna sakta hai?
# BLEU: 9.0272, WER: 0.7273, CER: 0.5345
#
# Reference: Kya aaj Texas me koi tornado warning he ?
# Hypothesis: Texas me aaj tornado warnings hai?
# BLEU: 12.4113, WER: 0.6667, CER: 0.3415
#
# Reference: Kya aap Megadeth ke latest album ko baja sakte hai ?
# Hypothesis: kya Megadeth ke latest album ko play kare?
# BLEU: 37.4055, WER: 0.5455, CER: 0.3269
#
# Reference: low tide kab hai ?
# Hypothesis: low tide kaisa hai?
# BLEU: 30.2138, WER: 0.6000, CER: 0.2222
#
# Reference: Utica , NY se Belleville , Il tak kitni doori hai
# Hypothesis: Utica, NY se Belleville, Il me kitna kitna hai
# BLEU: 59.0047, WER: 0.6364, CER: 0.2245
#
# Reference: Timer countdown please
# Hypothesis: Timer countdown ko please
# BLEU: 35.3553, WER: 0.3333, CER: 0.1364
#
# Reference: mujhe TV repair reminder dikhao
# Hypothesis: mujhe TV repair reminder bataye
# BLEU: 66.8740, WER: 0.2000, CER: 0.1935
#
# Reference: 2018 ke pehle hafte NYC me Activities
# Hypothesis: NYC me first week of 2018 ke liye activities
# BLEU: 13.4851, WER: 1.2857, CER: 0.7568
#
# Reference: Mujhe aaj , kal aur Saturday ke liye weather bataye .
# Hypothesis: mujhe Aaj, kal ek Saturday ke liye weather bataye
# BLEU: 40.8806, WER: 0.4545, CER: 0.1509
#
# Reference: Sydney mei weather kaisa hai ?
# Hypothesis: Sydney me mausam kaisa hai?
# BLEU: 32.4668, WER: 0.6667, CER: 0.2667
#
# Reference: Douglasville me Walmart ke liye directions construction ko avoid karte huye
# Hypothesis: Walmart ko Douglasville ke liye ek directions ki avoiding construction
# BLEU: 10.3864, WER: 0.8182, CER: 0.6800
#
# Reference: mujhe kal dopahar 3 bajhe bugs ke liye spray karne ke liye yaad dilaye
# Hypothesis: mujhe kal 3 pm ke bugs ke liye spray karne ke liye yaad dilaye
# BLEU: 65.9184, WER: 0.2143, CER: 0.1714
#
# Reference: aaj ke 15 minutes ke study timer ko postpone kare
# Hypothesis: aj 15 minutes study timer ko shuru kare
# BLEU: 21.0698, WER: 0.4000, CER: 0.2857
#
# Reference: 5 minute ke liye timer set kardo
# Hypothesis: 5 minutes ke liye timer set kare
# BLEU: 43.4721, WER: 0.2857, CER: 0.0938
#
# Reference: mai 8 am ko utna chahta hoon
# Hypothesis: mujhe 8 baje ke liye yaad dilaye
# BLEU: 6.5673, WER: 0.8571, CER: 0.7857
#
# Reference: is weekend ke liye Chocolate Tours
# Hypothesis: this weekend ke liye Chocolate Tours
# BLEU: 75.9836, WER: 0.1667, CER: 0.0588
#
# Reference: Please mere daily yoga sessions ke liye alert hata den .
# Hypothesis: Please mere daily yoga sessions ke liye alert remove kare
# BLEU: 68.7528, WER: 0.2727, CER: 0.1964
#
# Reference: agar mai rush hour ke samay Pearlridge se H 1 ke zariye airport tak jaaon to mujhe kitna samay lagega
# Hypothesis: kya rush hour ke liye Pearlridge via H 1 ka airport ke liye kitna time kitna sakta hai
# BLEU: 10.4195, WER: 0.6000, CER: 0.4554
#
# Reference: Muje dog ko feed karne ke liye remind karaye please
# Hypothesis: mujhe dog feed kare please.
# BLEU: 5.4844, WER: 0.8000, CER: 0.5686
#
# Reference: is weekend ka weather forecast kya hai
# Hypothesis: this weekend ke liye weather forecast kya hai?
# BLEU: 31.5598, WER: 0.5714, CER: 0.2368
#
# Reference: Merideth ko Whatsapp par text karo ki we are bringing the side dishes we just need plates and cups
# Hypothesis: Merideth ko text karo on Whatsapp we are bringing the side dishes we just need plates and cups
# BLEU: 68.2414, WER: 0.2105, CER: 0.2041
#
# Reference: mcallen se alamo tak ke liye directions
# Hypothesis: mcallen se alamo ke directions
# BLEU: 30.2851, WER: 0.2857, CER: 0.2308
#
# Reference: kis freeway par sabse kam traffic hai
# Hypothesis: kya freeway ke liye traffic kaisa hai
# BLEU: 8.6430, WER: 0.7143, CER: 0.5135
#
# Reference: please Pandora ko play karna shuru karo
# Hypothesis: Pandora ko play kare please
# BLEU: 28.6419, WER: 0.5714, CER: 0.4615
#
# Reference: agley haftey haircut karne ke liye reminder set kare
# Hypothesis: agley haircut ke liye reminder set kare
# BLEU: 50.2543, WER: 0.2222, CER: 0.2500
#
# Reference: yaha se ghar tak kitna time lagega
# Hypothesis: here ke liye kitna kitna kitna kitna hai
# BLEU: 5.5224, WER: 1.0000, CER: 0.7353
#
# Reference: Please May 9 to 14 ke liye weather search kare ?
# Hypothesis: Please May 9 aur 14 ke liye weather ko search kare?
# BLEU: 39.1819, WER: 0.3636, CER: 0.1458
#
# Reference: har Monday 10 : 30 am ko mera alarm repeat kare
# Hypothesis: mere alarm ko repeat kare every Monday at 10 : 30 am
# BLEU: 27.9016, WER: 1.0909, CER: 0.8723
#
# Reference: the Who ke Greatest Hits bajao
# Hypothesis: Who's Greatest Hits play kare
# BLEU: 17.4917, WER: 0.8333, CER: 0.4667
#
# Reference: sedona tak jane ke liye kitni der lagegi
# Hypothesis: sedona me kitna kitna kitna kitna hai
# BLEU: 5.6930, WER: 0.8750, CER: 0.5500
#
# Reference: Sunday ke liye mere alarms ko dikhao
# Hypothesis: Sunday ke liye mere alarms ko display kare
# BLEU: 68.0375, WER: 0.2857, CER: 0.2500
#
# Reference: kal kitni barf padi ?
# Hypothesis: aj kitna snow kaisa hai?
# BLEU: 8.1167, WER: 1.0000, CER: 0.6667
#
# Reference: Steffani Howells
# Hypothesis: Steffani Howells
# BLEU: 100.0000, WER: 0.0000, CER: 0.0000
#
# Reference: commute kitna samay lagega ye sambhavna hai
# Hypothesis: kya commute ke liye kitna he
# BLEU: 8.1706, WER: 1.0000, CER: 0.6744
#
# === Evaluation Metrics ===
# Average BLEU Score: 29.3392
# Average Word Error Rate: 0.5887
# Average Character Error Rate: 0.3901
# Average Embedding Similarity: 0.0886

# %%
import matplotlib.pyplot as plt

# Data
epochs = list(range(1, 45))
training_loss = [3.681600, 3.006700, 2.770500, 2.590300, 2.495800, 2.384100, 2.259000, 2.153100, 2.079000, 2.034400,
                 1.938100, 1.920300, 1.863200, 1.829100, 1.813700, 1.769100, 1.734600, 1.706300, 1.710400, 1.641000,
                 1.668300, 1.671100, 1.632200, 1.565400, 1.575400, 1.606300, 1.538200, 1.580600, 1.524300, 1.530400,
                 1.520900, 1.515500, 1.517200, 1.454900, 1.430000, 1.434000, 1.496000, 1.457600, 1.474600, 1.465800,
                 1.423000, 1.496600, 1.452200, 1.473700]
validation_loss = [3.024720, 2.622414, 2.417901, 2.282089, 2.164588, 2.076579, 1.982894, 1.908898, 1.851472, 1.797256,
                   1.750794, 1.714936, 1.674309, 1.642020, 1.612759, 1.586208, 1.568624, 1.543831, 1.522732, 1.507442,
                   1.492645, 1.473223, 1.461964, 1.447103, 1.438179, 1.425479, 1.415710, 1.408858, 1.401811, 1.390592,
                   1.384160, 1.376050, 1.370378, 1.367961, 1.362531, 1.357652, 1.352898, 1.348957, 1.345799, 1.343336,
                   1.341641, 1.340179, 1.339212, 1.338731]

# Plot
plt.figure(figsize=(10, 5))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss Over Epochs')
plt.legend()
plt.grid()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
from collections import defaultdict

# Read the text file (ensure the file 't5_small_metric_eval.txt' is in your working directory)
with open('/content/t5_small_metric_eval.txt', 'r', encoding='utf-8') as f:
    data = f.read()

# Each block is assumed to be separated by a blank line
blocks = data.strip().split('\n\n')

rows = []
for block in blocks:
    lines = block.strip().splitlines()
    if len(lines) >= 3:
        # Extract the Reference, Hypothesis, and metric line
        ref_line = lines[0]
        hyp_line = lines[1]
        metric_line = lines[2]
        # Remove the prefix 'Reference:' and 'Hypothesis:'
        ref = re.sub(r'^Reference:\s*', '', ref_line).strip()
        hyp = re.sub(r'^Hypothesis:\s*', '', hyp_line).strip()
        # Use regex to extract BLEU, WER, CER from the metric line
        m = re.findall(r'BLEU:\s*([\d\.]+),\s*WER:\s*([\d\.]+),\s*CER:\s*([\d\.]+)', metric_line)
        if m:
            bleu, wer, cer = map(float, m[0])
        else:
            continue
        rows.append({'Reference': ref, 'Hypothesis': hyp, 'BLEU': bleu, 'WER': wer, 'CER': cer})

# Create a DataFrame from the extracted data
df = pd.DataFrame(rows)

# Tokenize the Reference text into words (convert to lowercase and split on whitespace)
df['ref_tokens'] = df['Reference'].str.lower().str.split()

# Create a dictionary to accumulate metrics for each word appearing in the Reference
word_metrics = defaultdict(lambda: {'wer': [], 'bleu': [], 'cer': [], 'count': 0})

# For each row, add the metric values for each word in the Reference text.
# Here, we count every occurrence. You can modify this if you prefer to use a set.
for _, row in df.iterrows():
    for word in row['ref_tokens']:
        word_metrics[word]['wer'].append(row['WER'])
        word_metrics[word]['bleu'].append(row['BLEU'])
        word_metrics[word]['cer'].append(row['CER'])
        word_metrics[word]['count'] += 1

# Build a DataFrame with average metrics per word
words = []
avg_wer = []
avg_bleu = []
avg_cer = []
counts = []

for word, metrics in word_metrics.items():
    words.append(word)
    avg_wer.append(sum(metrics['wer']) / len(metrics['wer']))
    avg_bleu.append(sum(metrics['bleu']) / len(metrics['bleu']))
    avg_cer.append(sum(metrics['cer']) / len(metrics['cer']))
    counts.append(metrics['count'])

metrics_df = pd.DataFrame({
    'word': words,
    'avg_WER': avg_wer,
    'avg_BLEU': avg_bleu,
    'avg_CER': avg_cer,
    'count': counts
})

# Filter out words that do not appear frequently (set threshold to 5 occurrences)
filtered_df = metrics_df[metrics_df['count'] >= 5].copy()

# Set a Seaborn style for better aesthetics
sns.set(style="whitegrid", font_scale=1.1)

# Visualization 1: Top 20 words associated with high WER
top_wer = filtered_df.sort_values('avg_WER', ascending=False).head(20)
plt.figure(figsize=(12, 6))
sns.barplot(x='avg_WER', y='word', data=top_wer, palette='viridis')
plt.title('Top 20 words associated with high WER (from Reference)')
plt.xlabel('Average WER')
plt.ylabel('Word')
plt.tight_layout()
plt.show()

# Visualization 2: Top 20 words associated with high CER
top_cer = filtered_df.sort_values('avg_CER', ascending=False).head(20)
plt.figure(figsize=(12, 6))
sns.barplot(x='avg_CER', y='word', data=top_cer, palette='rocket')
plt.title('Top 20 words associated with high CER (from Reference)')
plt.xlabel('Average CER')
plt.ylabel('Word')
plt.tight_layout()
plt.show()

# Visualization 3: Top 20 words associated with low BLEU (lower BLEU implies worse quality)
top_low_bleu = filtered_df.sort_values('avg_BLEU', ascending=True).head(20)
plt.figure(figsize=(12, 6))
sns.barplot(x='avg_BLEU', y='word', data=top_low_bleu, palette='mako')
plt.title('Top 20 words associated with low BLEU (from Reference)')
plt.xlabel('Average BLEU')
plt.ylabel('Word')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-17-e1f2cc59957a>:82: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='avg_WER', y='word', data=top_wer, palette='viridis')
# <ipython-input-17-e1f2cc59957a>:92: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='avg_CER', y='word', data=top_cer, palette='rocket')
# <ipython-input-17-e1f2cc59957a>:102: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='avg_BLEU', y='word', data=top_low_bleu, palette='mako')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a bubble chart using the filtered DataFrame (filtered_df from previous code)
plt.figure(figsize=(12, 8))
scatter = plt.scatter(
    filtered_df['avg_WER'],
    filtered_df['avg_BLEU'],
    s=filtered_df['count'] * 10,  # adjust multiplier for better bubble sizes
    c=filtered_df['avg_CER'],
    cmap='viridis',
    alpha=0.7,
    edgecolor='k'
)
plt.xlabel('Average WER')
plt.ylabel('Average BLEU')
plt.title('Bubble Chart: Average WER vs Average BLEU (Bubble Size = Frequency, Color = Avg CER)')
cbar = plt.colorbar(scatter)
cbar.set_label('Average CER')

# Annotate a few high-frequency words for illustration purposes
for _, row in filtered_df.iterrows():
    if row['count'] > 20:  # annotate words that appear very frequently
        plt.annotate(row['word'], (row['avg_WER'], row['avg_BLEU']), fontsize=9, alpha=0.9)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objs as go
from plotly.subplots import make_subplots
from scipy import stats
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Read the data
def parse_metrics_file(file_path):
    metrics = []
    with open(file_path, 'r', encoding='utf-8') as file:
        current_entry = {}
        for line in file:
            line = line.strip()
            if line.startswith('Reference:'):
                current_entry['reference'] = line.replace('Reference: ', '')
            elif line.startswith('Hypothesis:'):
                current_entry['hypothesis'] = line.replace('Hypothesis: ', '')
            elif line.startswith('BLEU:'):
                # Extract numeric values
                bleu = float(line.split('BLEU:')[1].split(',')[0].strip())
                wer = float(line.split('WER:')[1].split(',')[0].strip())
                cer = float(line.split('CER:')[1].strip())

                current_entry['bleu'] = bleu
                current_entry['wer'] = wer
                current_entry['cer'] = cer

                metrics.append(current_entry)
                current_entry = {}

    return pd.DataFrame(metrics)

# Load the data (replace with your file path)
df = parse_metrics_file('/content/t5_small_metric_eval.txt')

# 1. Interactive Correlation Heatmap
def create_correlation_heatmap(df):
    correlation_matrix = df[['bleu', 'wer', 'cer']].corr()

    fig = px.imshow(correlation_matrix,
                    labels=dict(x="Metrics", y="Metrics", color="Correlation"),
                    x=['BLEU', 'WER', 'CER'],
                    y=['BLEU', 'WER', 'CER'],
                    color_continuous_scale='RdBu_r',
                    title='Correlation Between NLP Metrics')
    fig.show()
    return fig

# 2. Distribution of Metrics
def create_metrics_distribution(df):
    fig = make_subplots(rows=1, cols=3,
                        subplot_titles=('BLEU Score Distribution',
                                        'WER Distribution',
                                        'CER Distribution'))

    for i, metric in enumerate(['bleu', 'wer', 'cer'], 1):
        fig.add_trace(
            go.Histogram(x=df[metric], name=metric.upper()),
            row=1, col=i
        )

    fig.update_layout(title_text="Distribution of NLP Metrics")
    fig.show()
    return fig

# 3. Length Impact Analysis
def create_length_impact_analysis(df):
    df['ref_length'] = df['reference'].str.len()
    df['hyp_length'] = df['hypothesis'].str.len()

    fig = make_subplots(rows=1, cols=3,
                        subplot_titles=('Reference Length vs BLEU',
                                        'Reference Length vs WER',
                                        'Reference Length vs CER'))

    # BLEU vs Length
    fig.add_trace(
        go.Scatter(x=df['ref_length'], y=df['bleu'], mode='markers',
                   name='BLEU', marker=dict(color='blue', opacity=0.6)),
        row=1, col=1
    )

    # WER vs Length
    fig.add_trace(
        go.Scatter(x=df['ref_length'], y=df['wer'], mode='markers',
                   name='WER', marker=dict(color='red', opacity=0.6)),
        row=1, col=2
    )

    # CER vs Length
    fig.add_trace(
        go.Scatter(x=df['ref_length'], y=df['cer'], mode='markers',
                   name='CER', marker=dict(color='green', opacity=0.6)),
        row=1, col=3
    )

    fig.update_layout(title_text="Impact of Reference Length on Metrics")
    fig.update_xaxes(title_text="Reference Length")
    fig.update_yaxes(title_text="Metric Value")

    fig.show()
    return fig

# 4. Word Frequency Analysis
def create_word_frequency_analysis(df):
    import re
    from collections import Counter

    def extract_words(text):
        return re.findall(r'\b\w+\b', text.lower())

    # Collect words from references and hypotheses
    ref_words = [word for text in df['reference'] for word in extract_words(text)]
    hyp_words = [word for text in df['hypothesis'] for word in extract_words(text)]

    # Top 20 most frequent words
    ref_word_freq = Counter(ref_words).most_common(20)
    hyp_word_freq = Counter(hyp_words).most_common(20)

    # Create subplots for word frequencies
    fig = make_subplots(rows=1, cols=2,
                        subplot_titles=('Top Words in References',
                                        'Top Words in Hypotheses'))

    # References word frequency
    fig.add_trace(
        go.Bar(x=[word[0] for word in ref_word_freq],
               y=[word[1] for word in ref_word_freq],
               name='Reference Words'),
        row=1, col=1
    )

    # Hypotheses word frequency
    fig.add_trace(
        go.Bar(x=[word[0] for word in hyp_word_freq],
               y=[word[1] for word in hyp_word_freq],
               name='Hypothesis Words'),
        row=1, col=2
    )

    fig.update_layout(title_text="Word Frequency Analysis")
    fig.show()
    return fig

# 5. Advanced Scatter Plot
def create_advanced_scatter(df):
    fig = px.scatter(df, x='wer', y='bleu', color='cer',
                     title='WER vs BLEU Colored by CER',
                     labels={'wer': 'Word Error Rate',
                             'bleu': 'BLEU Score',
                             'cer': 'Character Error Rate'},
                     color_continuous_scale='viridis')
    fig.show()
    return fig

# 6. PCA Visualization
def create_pca_visualization(df):
    # Feature Engineering
    df['ref_unique_words'] = df['reference'].apply(lambda x: len(set(x.split())))
    df['hyp_unique_words'] = df['hypothesis'].apply(lambda x: len(set(x.split())))
    df['ref_word_diversity'] = df['ref_unique_words'] / df['reference'].apply(lambda x: len(x.split()))
    df['hyp_word_diversity'] = df['hyp_unique_words'] / df['hypothesis'].apply(lambda x: len(x.split()))

    # Prepare data for PCA
    features_for_pca = ['bleu', 'wer', 'cer', 'ref_unique_words', 'hyp_unique_words',
                        'ref_word_diversity', 'hyp_word_diversity']

    # Standardize features
    scaler = StandardScaler()
    scaled_features = scaler.fit_transform(df[features_for_pca])

    # PCA
    pca = PCA(n_components=2)
    pca_result = pca.fit_transform(scaled_features)

    # Create DataFrame for plotting
    pca_df = pd.DataFrame(data=pca_result, columns=['PC1', 'PC2'])
    pca_df['BLEU'] = df['bleu']

    # Interactive PCA plot
    fig = px.scatter(pca_df, x='PC1', y='PC2', color='BLEU',
                     title='PCA of NLP Metrics',
                     labels={'PC1': 'First Principal Component',
                             'PC2': 'Second Principal Component'},
                     color_continuous_scale='viridis')

    # Add variance explained annotation
    variance_explained = pca.explained_variance_ratio_
    fig.add_annotation(
        text=f'Variance Explained:<br>PC1: {variance_explained[0]*100:.2f}%<br>PC2: {variance_explained[1]*100:.2f}%',
        xref='paper', yref='paper',
        x=0.05, y=0.95,
        showarrow=False
    )

    fig.show()
    return fig

# Execute all visualizations
print("1. Correlation Heatmap")
create_correlation_heatmap(df)

print("\n2. Metrics Distribution")
create_metrics_distribution(df)

print("\n3. Length Impact Analysis")
create_length_impact_analysis(df)

print("\n4. Word Frequency Analysis")
create_word_frequency_analysis(df)

print("\n5. Advanced Scatter Plot")
create_advanced_scatter(df)

print("\n6. PCA Visualization")
create_pca_visualization(df)

# Print Descriptive Statistics
print("\nDescriptive Statistics:")
print(df[['bleu', 'wer', 'cer']].describe())

# Correlation Analysis
print("\nCorrelation Analysis:")
print(df[['bleu', 'wer', 'cer']].corr())
# Out:
# 1. Correlation Heatmap
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4e6f7672-9465-473b-9b6f-903ff87990f8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4e6f7672-9465-473b-9b6f-903ff87990f8")) {                    Plotly.newPlot(                        "4e6f7672-9465-473b-9b6f-903ff87990f8",                        [{"coloraxis":"coloraxis","name":"0","x":["BLEU","WER","CER"],"y":["BLEU","WER","CER"],"z":[[1.0,-0.7729481286270538,-0.7249160073129496],[-0.7729481286270538,1.0,0.9092665441775278],[-0.7249160073129496,0.9092665441775278,1.0]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"Metrics: %{x}\u003cbr\u003eMetrics: %{y}\u003cbr\u003eCorrelation: %{z}\u003cextra\u003e\u003c\u002fextra\u003e"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar": ...
# 2. Metrics Distribution
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2de3bc50-db8d-426c-951e-92b308c36a37" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2de3bc50-db8d-426c-951e-92b308c36a37")) {                    Plotly.newPlot(                        "2de3bc50-db8d-426c-951e-92b308c36a37",                        [{"name":"BLEU","x":[91.3101,18.3603,14.7596,25.8487,37.9918,66.874,46.3078,11.6439,62.402,15.8487,30.5098,22.9575,27.3768,16.1301,46.0533,23.6435,20.5567,7.1605,9.2115,13.8344,15.1872,100.0,24.4462,30.7394,59.1815,34.9833,6.4313,26.2691,32.6683,13.9428,37.9918,18.0945,32.4668,6.5673,33.7646,10.6822,15.4479,44.3001,15.2072,2.8587,19.9694,15.6197,8.1706,13.5404,36.2885,81.8731,22.6764,41.2491,6.3169,51.6973,10.7868,20.5902,20.548,7.3471,35.6403,86.6878,57.893,26.8354,19.3049,15.1069,30.9838,64.3459,17.4917,33.7646,6.2747,35.4948,26.7087,75.9836,64.3459,100.0,42.7287,6.9794,14.272,19.3577,15.6197,28.6419,15.8271,12.7033,25.3365,84.0896,9.8461,20.5771,4.8966,27.3385,12.7033,30.3265,55.0321,12.2562,43.7481,11.5912,6.9717,6.5518,54.1082,5.5224,42.4639,6.8706,12.5369,19.494,24.4462,24.8805,5.0736,43.4721,9.4612,8.5153,25.5754,24.1772,14.321,42.3837,19.6407,100.0,7.7686,26.2691,11.1615,50.8133,28.9178,10.5527,15.6197,61.4788,66.874,15.6197,44.6324,12.8726,17.3935,54.1082,28.6419,49.6264,100.0,3.6735,13.1345,50.9517,50.2659,10.5527,68.0375,6.8372,10.5118,12.2231,61.4788,26.2691,7.8176,45.6304,19.3049,32.5556,15.1332,41.1134,20.9118,16.4498,57.0282,32.1594,8.5799,21.0224,55.78,8.2908,13.9359,15.2072,26.6543,33.6608,46.3078,18.9959,44.9185,9.3643,16.5158,10.6822,4.4947,11.5912,100.0,18.9959,45.7231,18.394,100.0,37.9918,4.0185,6.5673,12.7033,15.6857,18.6353,7.8098,33.0316,17.3935,100.0,30.8958,41.1134,53.3168,13.1345,14.3231,27.092,15.8811,14.5358,15.1226,10.6933,30.2138,59.4604,21.9728,26.6543,6.8706,6.4372,40.7163,55.9368,100.0,19.6407,17.9652,41.1134,34.6064,21.3644,2.7423,86.334,12.7593,10.6822,4.9324,41.1134,18.9959,5.5224,60.6531,9.601,13.5404,58.5034,32.4668,8.9534,27.4825,12.6007,16.4091,42.7287,19.6407,6.8574,16.0585,44.6831,34.9833,10.5527,10.8243,4.0654,23.6435,31.9472,86.334,13.879,5.5224,21.3644,12.1921,66.874,69.0797,43.4721,100.0,0.0,10.6822,14.794,32.0191,5.6633,7.3798,64.7545,23.6435,12.2231,22.4592,100.0,11.3551,37.685,50.0,59.4604,7.2254,100.0,23.6435,39.7635,14.5358,7.4924,9.601,34.4068,9.2968,27.4825,36.8894,17.9652,26.6473,14.321,80.9107,10.6822,70.1397,32.0191,7.6766,51.1508,100.0,10.5527,39.4322,10.6822,26.2168,39.7635,12.8726,100.0,23.6435,9.6524,46.3078,100.0,80.9107,38.2603,44.3441,6.4372,15.3848,34.1918,22.3162,50.8133,9.8703,14.8071,9.0272,13.1345,12.8598,79.6358,35.3553,45.4802,11.1565,41.1134,19.3049,17.4917,40.8556,10.4006,10.272,13.9587,67.3182,65.8037,43.4721,21.1918,23.6435,7.127,14.5358,12.632,24.8805,16.3412,20.5567,17.0261,22.9575,4.7998,26.7828,8.2579,9.5387,8.1309,42.7287,6.4711,15.9736,52.61,22.871,45.4802,6.8922,8.2764,33.7646,27.6104,37.9918,6.5673,11.033,15.9736,9.2236,76.2466,17.0306,26.0847,7.1754,48.3545,5.6172,13.015,6.495,75.9836,3.7478,11.4175,30.3265,24.4462,13.3991,61.4788,59.4604,31.9129,26.6473,27.0541,13.9913,9.6524,7.2679,18.651,34.7864,39.7635,14.7596,5.4844,32.5556,12.2231,22.0896,22.9575,11.3594,100.0,10.739,100.0,7.3471,36.5555,12.2231,40.2107,2.1477,6.5673,22.3162,12.6007,8.0464,13.1345,24.4462,27.5161,17.0306,66.874,7.8098,27.7581,22.9575,17.4917,34.6681,54.1082,19.0817,80.9107,11.5216,48.8923,7.2679,33.2771,18.0945,25.8487,61.1456,34.9833,42.7287,5.6148,47.7559,14.3172,38.6275,58.1059,25.8487,46.7138,9.747,10.6822,37.7079,19.0708,11.4787,22.7721,8.7458,11.7378,100.0,20.5567,19.0708,19.4331,100.0,39.4322,31.5598,10.4006,43.4721,7.2679,4.0654,27.7762,31.2394,17.3935,19.3577,22.7721,8.1167,28.6487,30.2138,7.4924,6.5673,35.3553 ...
# 3. Length Impact Analysis
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e5775727-43cf-4ec1-9bb3-7b071af9ac9e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e5775727-43cf-4ec1-9bb3-7b071af9ac9e")) {                    Plotly.newPlot(                        "e5775727-43cf-4ec1-9bb3-7b071af9ac9e",                        [{"marker":{"color":"blue","opacity":0.6},"mode":"markers","name":"BLEU","x":[66,53,39,42,28,28,27,91,41,31,44,30,51,46,55,22,45,35,79,74,54,50,43,40,91,31,46,44,44,81,35,47,31,33,48,24,42,60,38,86,49,32,33,36,80,38,91,65,40,52,44,96,32,67,40,37,38,70,32,41,67,33,28,51,49,45,42,35,29,18,27,50,62,31,30,39,68,24,83,37,40,66,95,52,15,15,16,48,69,48,36,82,29,55,70,36,128,43,28,25,55,32,67,28,39,44,30,43,50,29,47,30,125,29,65,48,29,37,25,36,40,46,40,36,33,40,30,68,30,67,53,35,44,52,54,34,25,32,69,70,30,25,66,43,60,38,77,33,68,22,44,44,98,31,41,53,24,21,51,99,37,11,100,47,35,21,72,20,19,30,82,30,22,51,96,29,36,39,18,48,39,46,38,48,59,48,30,60,56,26,29,57,28,31,74,69,62,32,49,31,33,65,63,91,49,34,22,52,30,18,41,50,62,36,68,41,73,28,47,57,26,34,79,50,37,59,29,61,32,26,16,35,52,44,25,41,27,76,29,22,18,31,29,57,87,53,80,23,44,49,26,50,47,9,18,70,22,23,20,25,37,57,58,71,35,36,27,43,33,35,18,36,50,83,39,45,56,25,15,71,25,33,30,24,26,22,25,34,35,56,75,71,49,48,24,46,73,60,47,58,42,22,38,26,36,24,31,65,28,66,40,28,52,32,39,16,69,53,104,22,39,35,43,26,38,58,44,101,57,26,88,12,52,67,36,44,73,40,38,32,38,66,15,48,66,35,38,64,43,91,86,47,28,44,62,17,34,98,35,28,63,44,40,45,14,41,76,64,25,45,53,39,28,32,28,57,52,53,23,62,35,29,69,77,44,31,40,57,43,33,16,33,20,32,46,33,31,16,43,49,42,37,39,37,42,53,42,100,31,23,61,84,45,41,73,37,56,46,22,44,33,33,40,35,49,26,28,45,38,24,25,46,25,32,45,32,47,43,53,33,44,22,80,30,42,42,25,45,32,65,65,33,27,41,93,40,20,70,36,43,26,37,39,51,47,48,58,41,52,18,49,22,31,37,53,30,75,70,49,32,28,34,56,101,51,38,98,39,37,39,52,34,48,47,30,40,36,21,16,43],"y":[91.3101,18.3603,14.7596,25.8487,37.9918,66.874,46.3078,11.6439,62.402,15.8487,30.5098,22.9575,27.3768,16.1301,46.0533,23.6435,20.5567,7.1605,9.2115,13.8344,15.1872,100.0,24.4462,30.7394,59.1815,34.9833,6.4313,26.2691,32.6683,13.9428,37.9918,18.0945,32.4668,6.5673,33.7646,10.6822,15.4479,44.3001,15.2072,2.8587,19.9694,15.6197,8.1706,13.5404,36.2885,81.8731,22.6764,41.2491,6.3169,51.6973,10.7868,20.5902,20.548,7.3471,35.6403,86.6878,57.893,26.8354,19.3049,15.1069,30.9838,64.3459,17.4917,33.7646,6.2747,35.4948,26.7087,75.9836,64.3459,100.0,42.7287,6.9794,14.272,19.3577,15.6197,28.6419,15.8271,12.7033,25.3365,84.0896,9.8461,20.5771,4.8966,27.3385,12.7033,30.3265,55.0321,12.2562,43.7481,11.5912,6.9717,6.5518,54.1082,5.5224,42.4639,6.8706,12.5369,19.494,24.4462,24.8805,5.0736,43.4721,9.4612,8.5153,25.5754,24.1772,14.321,42.3837,19.6407,100.0,7.7686,26.2691,11.1615,50.8133,28.9178,10.5527,15.6197,61.4788,66.874,15.6197,44.6324,12.8726,17.3935,54.1082,28.6419,49.6264,100.0,3.6735,13.1345,50.9517,50.2659,10.5527,68.0375,6.8372,10.5118,12.2231,61.4788,26.2691,7.8176,45.6304,19.3049,32.5556,15.1332,41.1134,20.9118,16.4498,57.0282,32.1594,8.5799,21.0224,55.78,8.2908,13.9359,15.2072,26.6543,33.6608,46.3078,18.9959,44.9185,9.3643,16.5158,10.6822,4.4947,11.5912,100.0,18.9959,45.7231,18.394,100.0,37.9918,4.0185,6.5673,12.7033,15.6857,18.6353,7.8098,33.0316,17.3935,100.0,30.8958,41.1134,53.3168,13.1345,14.3231,27.092,15.8811,14.5358,15.1226,10.6933,30.2138,59.4604,21.9728,26.6543,6.8706,6.4372,40.7163,55.9368,100.0,19.6407,17.9652,41.1134,34.6064,21.3644,2.7423,86.334,12.7593,10.6822,4.9324,41.1134,18.9959,5.5224,60.6531,9.601,13.5404,58.5034,32.4668,8.9534,27.4825,12.6007,16.4091,42.7287,19.6407,6.8574,16.0585,44.6831,34.9833,10.5527,10.8243,4.0654,23.6435,31.9472,86.334,13.879,5.5224,21.3644,12.1921,66.874,69.0797,43.4721,100.0,0. ...
# 4. Word Frequency Analysis
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1ad18813-c9c0-4ae5-bdec-d81029c4f7cc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1ad18813-c9c0-4ae5-bdec-d81029c4f7cc")) {                    Plotly.newPlot(                        "1ad18813-c9c0-4ae5-bdec-d81029c4f7cc",                        [{"name":"Reference Words","x":["ke","liye","hai","ko","me","kya","mujhe","kare","alarm","mere","set","se","tak","par","timer","kitna","is","aaj","traffic","ki"],"y":[226,158,145,144,103,102,75,62,56,53,49,49,46,43,41,36,35,34,33,33],"type":"bar","xaxis":"x","yaxis":"y"},{"name":"Hypothesis Words","x":["ke","liye","kare","hai","ko","kya","me","mujhe","aaj","yaad","kitna","alarm","mere","set","kaisa","raat","timer","dilaye","traffic","please"],"y":[300,271,172,164,149,124,114,79,76,65,61,57,51,50,48,41,41,36,31,29],"type":"bar","xaxis":"x2","yaxis":"y2"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"c ...
# 5. Advanced Scatter Plot
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c6610263-d081-46a7-ba97-f4402629148e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c6610263-d081-46a7-ba97-f4402629148e")) {                    Plotly.newPlot(                        "c6610263-d081-46a7-ba97-f4402629148e",                        [{"hovertemplate":"Word Error Rate=%{x}\u003cbr\u003eBLEU Score=%{y}\u003cbr\u003eCharacter Error Rate=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[0.0455,0.3019,0.3333,0.4762,0.1429,0.0357,0.2222,0.6374,0.1707,0.4516,0.1136,0.9,0.451,0.5652,0.2364,0.2727,0.5778,0.5429,0.4937,0.7432,0.5926,0.02,0.3721,0.225,0.1648,0.1935,0.3913,0.3409,0.2727,0.6173,0.0857,0.4043,0.3548,0.7273,0.125,0.75,0.3095,0.2,0.3684,0.7209,0.6327,0.25,0.6667,0.2778,0.2125,0.2632,0.4835,0.3077,0.6,0.3462,0.4545,0.4062,0.3125,0.7313,0.175,0.1081,0.1316,0.2,0.2188,0.4146,0.2388,0.1818,0.3214,0.2353,0.6531,0.2444,0.4286,0.1714,0.069,0.0,0.1111,0.32,0.5161,0.4194,0.2667,0.2564,0.3382,0.2917,0.7711,0.1081,0.55,0.3788,0.5684,0.3654,0.6,0.6,0.25,0.3542,0.1159,0.4792,0.5833,0.561,0.2414,0.4545,0.2714,0.3056,0.5078,0.3256,0.7143,0.32,0.6364,0.3438,0.7164,0.5714,0.7949,0.3864,0.5,0.1163,0.5,0.0,0.7447,0.3,0.576,0.2414,0.8154,0.4583,0.4138,0.2162,0.08,0.3333,0.325,0.6739,0.35,0.1944,0.303,0.125,0.0,0.6618,0.7,0.1493,0.2642,0.7429,0.0682,0.8654,0.7407,0.7647,0.24,0.25,0.6957,0.4143,0.4333,0.64,0.5,0.1395,0.3,0.3684,0.1558,0.2121,0.6912,0.3182,0.0909,0.3636,0.5408,0.4194,0.439,0.6415,0.2917,0.2857,0.3922,0.6364,0.4595,1.0909,0.75,0.234,0.0,0.2381,0.5139,0.7,0.0,0.1,0.7439,0.7667,0.4545,0.4902,0.5833,0.6897,0.25,0.2821,0.0556,0.125,0.1026,0.3043,0.4737,0.5417,0.6271,0.3958,0.3333,0.35,0.5,0.3846,0.1034,0.7193,0.4286,0.5484,0.5946,0.2899,0.2258,0.0312,0.4286,0.4194,0.2727,0.1846,0.1587,0.6593,0.0408,0.6176,0.4091,0.6538,0.3333,0.3333,0.8293,0.22,0.5645,0.2778,0.0882,0.1707,0.4932,0.25,0.5319,0.4211,0.1538,0.5294,0.6709,0.7,0.1892,0.4237,0.8966,0.5574,1.2188,0.4615,0.375,0.0286,0.6731,0.6364,0.48,0.2195,0.037,0.0921,0.2414,0.0,0.7222,0.6129,0.2069,0.2281,0.6207,0.3019,0.1875,0.1739,0.4773,0.4082,0.0,0.5,0.1277,0.4444,0.2222,0.6857,0.0,0.7391,0.45,0.68,0.6486,0.5088,0.3621,0.5915,0.6286,0.7222,0.3704,0.2326,0.5455,0.0286,0.7778,0.0833,0.26,0.6867,0.1282,0.0,0.1964,0.24,0.9333,0.2113,0.28,0.4848,0.0,0.5417,0.5,0.1818,0.0,0.0294,0.1143,0.3571,0.68,0.338,0.2857,0.4167,0.25,0.5,0.3014,0.5667,0.5532,0.4655,0.0714,0.1364,0.1316,0.5,0.2222,0.375,0.4839,0.1077,0.3929,0.5455,0.475,0.1071,0.0577,0.0938,0.4359,0.625,0.7826,0.3774,0.6442,0.4091,0.2564,0.4857,0.3256,0.4615,0.6316,0.4483,0.5227,0.5248,0.8246,0.1154,0.625,0.8333,0.2115,0.2537,0.3333,0.5227,0.5753,0.25,0.2895,0.0312,0.8421,0.6061,1.1333,0.6042,0.1667,0.3143,0.1579,0.4531,0.2558,0.6923,0.6047,0.617,0.0357,0.7273,0.3871,0.1765,0.2059,0.3878,0.2286,0.1429,0.2063,0.1591,0.175,0.4444,1.0,0.7805,0.5,0.25,0.2,0.2889,0.5472,0.1282,0.8214,0.3125,0.2143,0.5439,0.0,0.5094,0.0,0.6452,0.2286,0.4828,0.3623,0.7013,0.75,0.5484,0.425,0.4211,0.3721,0.4242,0.5625,0.5455,0.2,0.4688,0.2609,0.2121,0.4839,0.0625,0.1163,0.5306,0.0238,0.2432,0.2051,0.4324,0.6667,0.5472,0.2619,0.14,0.2903,0.1304,0.5082,0.4405,0.3778,0.122,0.137,0.4054,0.1071,0.4783,0.4545,0.1364,0.7576,0.4242,0.325,0.6286,0.449,0.0,0.6429,0.4222,0.2368,0.0,0.24,0.1957,0.4,0.2188,0.7556,1.2188,0.2979,0.4884,0.4528,0.2727,0.3409,0.7273,0.4,0.0333,0.4048,0.5,0.04,0.1778,1.0625,0.5385,0.2923,0.0303,0.6667,0.122,0.5806,0.725,0.05,0.5143,0.2778,0.3023,0.5769,0.2973,0.5897,0.1961,0.4468,0.7917,0.5345,0.3415,0.3269,0.2222,0.2245,0.1364,0.1935,0.7568,0.1509,0.2667,0.68,0.1714,0.2857,0.0938,0.7857,0.0588,0.1964,0.4554,0.5686,0.2368,0.2041,0.2308,0.5135,0.4615,0.25,0.7353,0.1458,0.8723,0.4667 ...
# 6. PCA Visualization
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9d12792b-1c6b-41e1-a480-51ed86d2279d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9d12792b-1c6b-41e1-a480-51ed86d2279d")) {                    Plotly.newPlot(                        "9d12792b-1c6b-41e1-a480-51ed86d2279d",                        [{"hovertemplate":"First Principal Component=%{x}\u003cbr\u003eSecond Principal Component=%{y}\u003cbr\u003eBLEU=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[91.3101,18.3603,14.7596,25.8487,37.9918,66.874,46.3078,11.6439,62.402,15.8487,30.5098,22.9575,27.3768,16.1301,46.0533,23.6435,20.5567,7.1605,9.2115,13.8344,15.1872,100.0,24.4462,30.7394,59.1815,34.9833,6.4313,26.2691,32.6683,13.9428,37.9918,18.0945,32.4668,6.5673,33.7646,10.6822,15.4479,44.3001,15.2072,2.8587,19.9694,15.6197,8.1706,13.5404,36.2885,81.8731,22.6764,41.2491,6.3169,51.6973,10.7868,20.5902,20.548,7.3471,35.6403,86.6878,57.893,26.8354,19.3049,15.1069,30.9838,64.3459,17.4917,33.7646,6.2747,35.4948,26.7087,75.9836,64.3459,100.0,42.7287,6.9794,14.272,19.3577,15.6197,28.6419,15.8271,12.7033,25.3365,84.0896,9.8461,20.5771,4.8966,27.3385,12.7033,30.3265,55.0321,12.2562,43.7481,11.5912,6.9717,6.5518,54.1082,5.5224,42.4639,6.8706,12.5369,19.494,24.4462,24.8805,5.0736,43.4721,9.4612,8.5153,25.5754,24.1772,14.321,42.3837,19.6407,100.0,7.7686,26.2691,11.1615,50.8133,28.9178,10.5527,15.6197,61.4788,66.874,15.6197,44.6324,12.8726,17.3935,54.1082,28.6419,49.6264,100.0,3.6735,13.1345,50.9517,50.2659,10.5527,68.0375,6.8372,10.5118,12.2231,61.4788,26.2691,7.8176,45.6304,19.3049,32.5556,15.1332,41.1134,20.9118,16.4498,57.0282,32.1594,8.5799,21.0224,55.78,8.2908,13.9359,15.2072,26.6543,33.6608,46.3078,18.9959,44.9185,9.3643,16.5158,10.6822,4.4947,11.5912,100.0,18.9959,45.7231,18.394,100.0,37.9918,4.0185,6.5673,12.7033,15.6857,18.6353,7.8098,33.0316,17.3935,100.0,30.8958,41.1134,53.3168,13.1345,14.3231,27.092,15.8811,14.5358,15.1226,10.6933,30.2138,59.4604,21.9728,26.6543,6.8706,6.4372,40.7163,55.9368,100.0,19.6407,17.9652,41.1134,34.6064,21.3644,2.7423,86.334,12.7593,10.6822,4.9324,41.1134,18.9959,5.5224,60.6531,9.601,13.5404,58.5034,32.4668,8.9534,27.4825,12.6007,16.4091,42.7287,19.6407,6.8574,16.0585,44.6831,34.9833,10.5527,10.8243,4.0654,23.6435,31.9472,86.334,13.879,5.5224,21.3644,12.1921,66.874,69.0797,43.4721,100.0,0.0,10.6822,14.794,32.0191,5.6633,7.3798,64.7545,23.6435,12.2231,22.4592,100.0,11.3551,37.685,50.0,59.4604,7.2254,100.0,23.6435,39.7635,14.5358,7.4924,9.601,34.4068,9.2968,27.4825,36.8894,17.9652,26.6473,14.321,80.9107,10.6822,70.1397,32.0191,7.6766,51.1508,100.0,10.5527,39.4322,10.6822,26.2168,39.7635,12.8726,100.0,23.6435,9.6524,46.3078,100.0,80.9107,38.2603,44.3441,6.4372,15.3848,34.1918,22.3162,50.8133,9.8703,14.8071,9.0272,13.1345,12.8598,79.6358,35.3553,45.4802,11.1565,41.1134,19.3049,17.4917,40.8556,10.4006,10.272,13.9587,67.3182,65.8037,43.4721,21.1918,23.6435,7.127,14.5358,12.632,24.8805,16.3412,20.5567,17.0261,22.9575,4.7998,26.7828,8.2579,9.5387,8.1309,42.7287,6.4711,15.9736,52.61,22.871,45.4802,6.8922,8.2764,33.7646,27.6104,37.9918,6.5673,11.033,15.9736,9.2236,76.2466,17.0306,26.0847,7.1754,48.3545,5.6172,13.015,6.495,75.9836,3.7478,11.4175,30.3265,24.4462,13.3991,61.4788,59.4604,31.9129,26.6473,27.0541,13.9913,9.6524,7.2679,18.651,34.7864,39.7635,14.7596,5.4844,32.5556,12.2231,22.0896,22.9575,11.3594,100.0,10.739,100.0,7.3471,36.5555,12.2231,40.2107,2.1477,6.5673,22.3162,12.6007,8.0464,13.1345,24.4462,27.5161,17.0306,66.874,7.8098,27.7581,22.9575,17.4917,34.6681,54.1082,19.0817,80.9107,11.5216,48.8923,7.2679,33.2771,18.0945,25.8487,61.1456,34.9833,42.7287,5.6148,47.7559,14.3172,38.6275,58.1059,25.8487,46.7138,9.747,10.6822,37.7079,19.0708,11.4787,22.7 ...
# Descriptive Statistics:
#              bleu         wer         cer
# count  500.000000  500.000000  500.000000
# mean    29.339180    0.588726    0.390058
# std     23.637337    0.295379    0.233640
# min      0.000000    0.000000    0.000000
# 25%     11.510875    0.375000    0.212400
# 50%     22.202900    0.600000    0.371250
# 75%     40.337100    0.777800    0.550000
# max    100.000000    2.000000    1.218800
#
# Correlation Analysis:
#           bleu       wer       cer
# bleu  1.000000 -0.772948 -0.724916
# wer  -0.772948  1.000000  0.909267
# cer  -0.724916  0.909267  1.000000

# %% [markdown]
# # Comprehensive Analysis of NLP Metrics Visualizations
#
# ## 1. Correlation Heatmap
# ### What it Represents:
# The correlation heatmap shows the statistical relationship between BLEU, WER (Word Error Rate), and CER (Character Error Rate) scores.
#
# #### Key Insights:
# - **Color Interpretation**:
#   - Red indicates negative correlation
#   - Blue indicates positive correlation
#   - Darker colors represent stronger correlations
#   - White or light colors suggest weak or no correlation
#
# #### Possible Scenarios:
# - A strong negative correlation between BLEU and WER would suggest that as Word Error Rate increases, BLEU score decreases
# - Moderate correlations might indicate complex interactions between metrics
# - Weak correlations suggest the metrics capture different aspects of translation quality
#
# ## 2. Metrics Distribution
# ### What it Represents:
# This visualization shows the frequency distribution of BLEU, WER, and CER scores.
#
# #### Key Insights:
# - **Shape of Distribution**:
#   - Normal (bell-curve) distribution suggests consistent performance
#   - Skewed distribution indicates bias in translation quality
#   - Multiple peaks might suggest distinct performance groups
#
# #### Interpretation:
# - Peak location shows the most common score range
# - Width of distribution indicates performance variability
# - Outliers represent exceptional cases of very good or poor translations
#
# ## 3. Length Impact Analysis
# ### What it Represents:
# Explores how text length affects different NLP metrics (BLEU, WER, CER).
#
# #### Key Insights:
# - **Relationship Between Length and Metrics**:
#   - Clustering of points suggests consistent performance
#   - Scattered points indicate high variability
#   - Trend lines (if visible) show how metrics change with text length
#
# #### Potential Observations:
# - Do longer texts have more consistent or more variable metrics?
# - Is there a sweet spot for text length that yields optimal performance?
# - How do different metrics respond to text length?
#
# ## 4. Word Frequency Analysis
# ### What it Represents:
# Displays the most frequently occurring words in references and hypotheses.
#
# #### Key Insights:
# - **Linguistic Patterns**:
#   - Common words across references and hypotheses
#   - Differences in word usage between reference and hypothesis
#   - Potential impact of frequent words on translation quality
#
# #### Potential Analysis:
# - Identify most challenging words for translation
# - Understand vocabulary complexity
# - Detect potential systematic translation errors
#
# ## 5. Advanced Scatter Plot (WER vs BLEU)
# ### What it Represents:
# A multi-dimensional view of Word Error Rate, BLEU Score, and Character Error Rate.
#
# #### Key Insights:
# - **Color Gradient**:
#   - Represents Character Error Rate
#   - Darker/lighter colors show variation in CER
# - **Point Distribution**:
#   - Clustering indicates consistent performance
#   - Spread suggests high variability
#
# #### Interpretation:
# - Relationship between translation accuracy (WER)
# - Impact of character-level errors on overall translation quality
# - Identifying optimal performance regions
#
# ## 6. PCA (Principal Component Analysis) Visualization
# ### What it Represents:
# Reduces multiple metrics to two principal components to show underlying patterns.
#
# #### Key Insights:
# - **Dimension Reduction**:
#   - Combines multiple features into two principal components
#   - Shows how different metrics interrelate
# - **Color Coding**:
#   - BLEU score represented by color gradient
#   - Helps identify patterns in translation quality
#
# #### Potential Discoveries:
# - Hidden relationships between different metrics
# - Clustering of translation performance
# - Variance explained by principal components
#
# ## Descriptive Statistics Interpretation
#
# ### Mean (Average):
# - Provides central tendency of metrics
# - Indicates overall translation performance
#
# ### Standard Deviation:
# - Measures variation in metrics
# - High deviation suggests inconsistent translation quality
#
# ### Minimum and Maximum:
# - Identifies extreme cases
# - Shows the range of translation performance
#
# ## Correlation Analysis
# ### What it Represents:
# Numerical representation of relationships between metrics.
#
# #### Interpretation:
# - Values close to 1 or -1 indicate strong correlation
# - Values near 0 suggest weak or no correlation
# - Helps understand how different metrics interact
#
# ## Research-Worthy Insights
# 1. **Performance Variability**: Analyze factors causing metric fluctuations
# 2. **Linguistic Complexity**: Understand how text characteristics impact translation
# 3. **Metric Interdependence**: Explore relationships between different evaluation metrics
# 4. **Error Pattern Recognition**: Identify systematic translation challenges
